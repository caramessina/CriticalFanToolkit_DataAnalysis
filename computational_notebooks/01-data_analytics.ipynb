# %% [markdown]
# ## Data Analytics: Computational Temporal Analysis
#
# Cara Marta Messina <br/>
# Northeastern University<br/>
# messina [dot] c [at] husky [dot] neu [dot] edu
#
# This notebook takes data collected from <em>Archive of Our Own</em>, a popular fanfiction repository, and sets it up to be analyzed. The data was collected using [this AO3 python scraper](https://github.com/radiolarian/AO3Scraper). The corpus consists of <em>The Legend of Korra</em> and <em>Game of Thrones</em> fanfics, from the first one published on AO3 to 2019.
#
# <em>This notebook is part of the Critical Fan Toolkit, Cara Marta Messina's public + digital dissertation</em>

# %%
#pandas for working with dataframes
import pandas as pd

#regular expression library
import re

#numpy specifically works with numbers
import numpy as np

from nltk import word_tokenize

import string
punctuations = list(string.punctuation)

#has the nice counter feature for counting tags
import collections
from collections import Counter 

#for making a string of elements separated by commas into a list
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktLanguageVars 

#visualizations
import plotly as py
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots

#calling my plotly thing
import chart_studio
chart_studio.tools.set_credentials_file(username='caramessina', api_key='IdA4LjtaqYKmFJnfS8Uv')

# %% [markdown]
# ## Reading and Prepping the Data

# %%
korra = pd.read_csv('./data/group_month/allkorra_months.csv')
korra.head(3)
# Out:
#      month                   rating  \
# 0  2011-02              not rated,
# 1  2011-04      general audiences,
# 2  2011-05  teen and up audiences,
#
#                                      additional tags category  \
# 0                   original characters - freeform,   multi,
# 1                          family, angst, one shot,     gen,
# 2  completely au, written pre-canon, rated for la...    gen,
#
#                                         relationship  \
# 0  mai/zuko (avatar), sokka/suki (avatar), aang (...
# 1                             aang (avatar)/katara,
# 2                                                NaN
#
#                                                 body  count
# 0  when kato listens to his father's war stories,...      1
# 1  his father shows tenzin where the flowers grow...      1
# 2    \n \nthe earthbender's answer was not what s...      1

# %%
korra_full = pd.read_csv('./data/tlok_clean.csv')
korra_full.head(2)
# Out:
#    Unnamed: 0   work_id                                             title  \
# 0           0   6388009  noatak (avatar), tarrlok (avatar), amon (avatar)
# 1           1  13974048                       korra (avatar), lin beifong
#
#     published                   rating  \
# 0  2016-03-28      general audiences,
# 1  2018-03-14  teen and up audiences,
#
#                                           character         relationship  \
# 0  noatak (avatar), tarrlok (avatar), amon (avatar)                  NaN
# 1                       korra (avatar), lin beifong  lin beifong/korra,
#
#                                      additional tags category  \
# 0                               alternate universe,     gen,
# 1  just a quick one-shot i never posted properly,...    f/f,
#
#                                                 body    month
# 0  he's forgotten how to be warm. the thought wou...  2016-03
# 1  "korra." somewhere distant.  someone holding h...  2018-03

# %%
got0 = pd.read_csv(r'./data/group_month/got_1.csv')
got1 = pd.read_csv(r'./data/group_month/got_2.csv')
got2 = pd.read_csv(r'./data/group_month/got_3.csv')
got3 = pd.read_csv(r'./data/group_month/got_4.csv')

merged_got = pd.concat([got0, got1, got2, got3])
merged_got.head(5)
# Out:
#      month                                      rating  \
# 0  2006-08                     teen and up audiences,
# 1  2007-02                         general audiences,
# 2  2007-05                     teen and up audiences,
# 3  2007-06             mature, teen and up audiences,
# 4  2007-12  teen and up audiences, general audiences,
#
#                                      additional tags    category  \
# 0                                   incest, dreams,        m/m,
# 1                                  possible incest,          NaN
# 2  tragedy, canonical character death, suicide, b...       f/m,
# 3  alternate universe, infidelity, unrequited lov...  f/m, f/m,
# 4     romance, action/adventure, incest, maleslash,   f/m, m/m,
#
#                                         relationship  \
# 0                              jon snow/robb stark,
# 1                                                NaN
# 2  rhaegar targaryen/lyanna stark, robert barathe...
# 3  cersei lannister/oberyn martell, petyr baelish...
# 4  brienne/jaime lannister, jaime lannister/rhaeg...
#
#                                                 body  count
# 0  up on the wall it is impossible to be warm and...      1
# 1  the last time jon had seen his half-sister san...      1
# 2  it is far too easy, to slip away. lyanna is kn...      1
# 3  the vase shatters beautifully against the wall...      2
# 4  asshai is the end of the world. the valaryians...      2

# %% [markdown]
# ## Creating Basic Bar Chart for Published Rates
#
# These next two cells create a basic bar chart using the rate of fanfics published during specific years and maps it onto a bar graph. It's a basic image, but provides a context for why particular times and publishing date is important.

# %%
korra_timelinefig = px.line(korra, x='month', y='count')

korra_timelinefig.update_layout(
    title='The Legend of Korra Fanfic Publishing Rates Across Time'
)

# korra_timelinefig.update_traces(marker_color='indigo')

korra_timelinefig.write_html('images/TLOK-history.html', auto_open=True)

# %%
got_timelinefig = px.line(merged_got, x='month', y='count')
got_timelinefig.update_layout(
    title='Game of Thrones Fanfic Publishing Rates Across Time')
# got_timelinefig.update_traces(marker_color='indigo')

got_timelinefig.write_html('images/GOT-history.html', auto_open=True)

# %% [markdown]
# ## Data Analytics on the Fic Metadata
#
# created a function that will take the different tags (which are phrased as characterA/characterB, characterA/characterB, etc in the data) and count the most common relationships to then output it as the most common relationship tags used.

# %%
def column_to_list(df,columnName):
    '''
    this function takes all the information from a specific column, joins it to a string, and then tokenizes & cleans that string.
    input: the name of the dataframe and the column name
    output: the tokenized list of the text with all lower case, punctuation removed, and no stop words
    '''
    df[columnName] = df[columnName].replace(np.nan,'',regex=True) 
    string = ' '.join(df[columnName].tolist())
    return string

# %%
def clean_tokens(string):    
    stopwords = ['i', 'me', 'my', 'myself', "“", "”", 'we', 'our', '’', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", "would", "could", 'won', "won't", 'wouldn', "wouldn't"]
    text_lc = [word.lower() for word in string]
    text_tokens_clean = [word for word in text_lc if word not in stopwords]
    text_tokens_clean = [word for word in text_tokens_clean if word not in punctuations]
    return text_tokens_clean
    print(text_tokens_clean[:20])

# %%
def TagsAnalyzer(df, monthBegin, monthEnd, columnName):
    '''
    input: the index month+year, such as '2012-04', and the specific metadata, such as 'additional tags'
    output: a tupple of the count of tags in a specific month/year
    
    load in the proper data into a string'''
    
    #choose the months to analyze
    months_df = df.loc[monthBegin:monthEnd, :]
    
    #replace empty values & make a list of all the words
    string = column_to_list(months_df, columnName)
    
    #the function to tokenize, or put each value as an element in a list
    class CommaPoint(PunktLanguageVars):
        sent_end_chars = (',') 
    tokenizer = PunktSentenceTokenizer(lang_vars = CommaPoint())
    
    #tokenizing the list of strings based on the COMMA, not the white space (as seen in the CommaPoint above)
    ListOfTags = tokenizer.tokenize(string)
    length = len(ListOfTags)
    
    #the "Counter" function is from the collections library
    allCounter=collections.Counter(ListOfTags)
    
    #return 
    return allCounter.most_common()

    
#     TO MAKE IT A RATION
#     li = []
#     #returning a dictionary in which the keys are all the tags, and the items are the counts
#     for word0,word1 in allCounter.most_common(300):
#         li.append((word0, (word1/length)*100))

# #     #return
#     return li

# %%
def TagsAnalyzer_noMonth(df, columnName, num):
    '''
    Input: the dataframe, the column you want to analyze, and the number of most common tags/phrases
    Output: A tupple of the most common tags in a column
    
    Description: this separates tags by commas, counts the most frequent tags, and will show you the most common
    '''
     #replace empty values & make a list of all the words using the column_to_list function
    string = column_to_list(df, columnName)
    
    #the function to tokenize, or put each value as an element in a list
    class CommaPoint(PunktLanguageVars):
        sent_end_chars = (',') 
    tokenizer = PunktSentenceTokenizer(lang_vars = CommaPoint())
    
    #tokenizing the list of strings based on the COMMA, not the white space (as seen in the CommaPoint above)
    ListOfTags = tokenizer.tokenize(string)
        
    #the "Counter" function is from the collections library
    allCounter=collections.Counter(ListOfTags)

    #returning a dictionary in which the keys are all the tags, and the items are the counts
    return allCounter.most_common()

# %% [markdown]
# ### Creating TXT Files of Additional Tags
#
# First I want to create .txt files of all the additional tags used. This way, I can upload them to Voyant if I want. I use regular expressions to tranform a list of tags with commas between each tag and spaces separating words to a list of tags with commas and spaces separating each tag and all tag spaces are replaced with '_'. This way, tools like Voyant, which look at spaces, will not separate the tags.
#
# So now this (a, list of, tags may, look like this)
# becomes this (a, list_of, tags_may, look_like_this)

# %%
lokAT = column_to_list(korra,'additional tags')
lokAT = lokAT.replace(", ",",")
lokAT = lokAT.replace(", ",",")
lokAT = lokAT.replace(" ","_")
lokATfinal = re.sub('(\,)(\w)', '\g<1> \g<2>', lokAT)
lokATfinal
    
filepath = open("data/TLOK_additional_tags.txt","w")
filepath.write(lokATfinal) 
filepath.close()

# %%
#reading in multiple csv files, since one large one breaks my kernels 

gotmonth0 = pd.read_csv('data/group_month/got_1.csv')
gotmonth1 = pd.read_csv('data/group_month/got_2.csv')
gotmonth2 = pd.read_csv('data/group_month/got_3.csv')
gotmonth3 = pd.read_csv('data/group_month/got_4.csv')

got_all = pd.concat([gotmonth0, gotmonth1, gotmonth2, gotmonth3]).set_index('month')
got_all.head(5)
# Out:
#                                              rating  \
# month
# 2006-08                     teen and up audiences,
# 2007-02                         general audiences,
# 2007-05                     teen and up audiences,
# 2007-06             mature, teen and up audiences,
# 2007-12  teen and up audiences, general audiences,
#
#                                            additional tags    category  \
# month
# 2006-08                                   incest, dreams,        m/m,
# 2007-02                                  possible incest,          NaN
# 2007-05  tragedy, canonical character death, suicide, b...       f/m,
# 2007-06  alternate universe, infidelity, unrequited lov...  f/m, f/m,
# 2007-12     romance, action/adventure, incest, maleslash,   f/m, m/m,
#
#                                               relationship  \
# month
# 2006-08                              jon snow/robb stark,
# 2007-02                                                NaN
# 2007-05  rhaegar targaryen/lyanna stark, robert barathe...
# 2007-06  cersei lannister/oberyn martell, petyr baelish...
# 2007-12  brienne/jaime lannister, jaime lannister/rhaeg...
#
#                                                       body  count
# month
# 2006-08  up on the wall it is impossible to be warm and...      1
# 2007-02  the last time jon had seen his half-sister san...      1
# 2007-05  it is far too easy, to slip away. lyanna is kn...      1
# 2007-06  the vase shatters beautifully against the wall...      2
# 2007-12  asshai is the end of the world. the valaryians...      2

# %%
gotAT = column_to_list(got_all,'additional tags')
gotAT = gotAT.replace(", ",",")
gotAT = gotAT.replace(", ",",")
gotAT = gotAT.replace(" ","_")
gotATfinale = re.sub('(\,)(\w)', '\g<1> \g<2>', gotAT)
gotATfinale

filepath = open("data/GOT_additional_tags.txt","w")
filepath.write(gotATfinale) 
filepath.close()

# %% [markdown]
# ### Korra Tags

# %%
#First, set 'month' as index

korra_all = korra.set_index('month')

# %%
korra_preKArel = TagsAnalyzer(korra_all,'2011-01','2014-05','relationship')
korra_subKArel = TagsAnalyzer(korra_all,'2014-06','2014-11','relationship')
korra_postKArel = TagsAnalyzer(korra_all,'2014-12','2015-07','relationship')

print('Pre-Korrasami')
print(korra_preKArel[:10])
print('\n Korrasami Subtext')
print(korra_subKArel[:10])
print('\n Post-Korrasami')
print(korra_postKArel[:10])
# Out:
# Pre-Korrasami
# [('korra/mako (avatar),', 305), ('bolin/korra (avatar),', 91), ('korra/asami sato,', 90), ('amon/lieutenant (avatar),', 68), ('amon/korra (avatar),', 48), ('korra/tahno (avatar),', 44), ('tahno/korra,', 40), ('pema/tenzin (avatar),', 39), ('lin bei fong/tenzin,', 39), ('korra/tarrlok (avatar),', 37)]
#
#  Korrasami Subtext
# [('korra/asami sato,', 281), ('korra/mako (avatar),', 63), ('varrick/zhu li,', 19), ('mako/prince wu,', 18), ('amon/korra (avatar),', 17), ('lin bei fong/tenzin,', 13), ('amon | noatak/korra,', 12), ('mako/asami sato,', 11), ('korrasami,', 11), ('aang/katara (avatar),', 11)]
#
#  Post-Korrasami
# [('korra/asami sato,', 1250), ('bolin/opal (avatar),', 120), ('korra/mako (avatar),', 96), ('baatar jr./kuvira (avatar),', 94), ('korra/kuvira,', 45), ('korrasami,', 44), ('jinora/kai (avatar),', 41), ('lin beifong/kya ii,', 40), ('mako/prince wu (avatar),', 33), ('lin beifong/tenzin,', 33)]
# /Users/caramessina/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#SAVING AS A DATAFRAME FOR THE FUTURE
korra_preKAdf = pd.DataFrame(korra_preKArel, columns =['Pairing', 'Appearance']) 
korra_preKAdf.to_csv('data/counting_csvs/TLOK/relationships/preKA_relationships.csv')

korra_subKAdf = pd.DataFrame(korra_subKArel, columns =['Pairing', 'Appearance']) 
korra_subKAdf.to_csv('data/counting_csvs/TLOK/relationships/subKA_relationships.csv')

korra_postKA = pd.DataFrame(korra_postKArel, columns =['Pairing', 'Appearance']) 
korra_postKA.to_csv('data/counting_csvs/TLOK/relationships/postKA_relationships.csv')

# %%
preKAtags = TagsAnalyzer(korra_all,'2011-02','2014-05','additional tags')
subKAtags = TagsAnalyzer(korra_all,'2014-06','2014-11','additional tags')
postKAtags = TagsAnalyzer(korra_all,'2014-12','2015-07','additional tags')

print(preKAtags[:10])
print(subKAtags[:10])
print(postKAtags[:10])
# Out:
# /Users/caramessina/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [('romance,', 145), ('angst,', 109), ('friendship,', 92), ('family,', 72), ('fluff,', 67), ('alternate universe,', 63), ('established relationship,', 62), ('smut,', 46), ('au,', 46), ('hurt/comfort,', 43)]
# [('fluff,', 63), ('romance,', 54), ('angst,', 43), ('alternate universe,', 33), ('alternate universe - modern setting,', 30), ('friendship,', 24), ('smut,', 22), ('hurt/comfort,', 22), ('humor,', 19), ('au,', 14)]
# [('fluff,', 229), ('romance,', 213), ('angst,', 145), ('alternate universe - modern setting,', 126), ('korrasami - freeform,', 126), ('alternate universe,', 89), ('canon compliant,', 81), ('friendship,', 74), ('post-finale,', 62), ('post-canon,', 56)]

# %%
#SAVING AS A DATAFRAME FOR THE FUTURE 
korra_preKA_tags_df = pd.DataFrame(preKAtags, columns =['Tags', 'Appearance']) 
korra_preKA_tags_df.to_csv('data/counting_csvs/TLOK/tags/preKA_tags.csv')

korra_subKA_tags_df = pd.DataFrame(subKAtags, columns =['Tags', 'Appearance']) 
korra_subKA_tags_df.to_csv('data/counting_csvs/TLOK/tags/subKA_tags.csv')

korra_postKA_tags_df = pd.DataFrame(postKAtags, columns =['Tags', 'Appearance']) 
korra_postKA_tags_df.to_csv('data/counting_csvs/TLOK/tags/postKA_tags.csv')

# %%
korra_preKAcat = TagsAnalyzer(korra_all,'2011-02','2014-05','category')
korra_subKAcat = TagsAnalyzer(korra_all,'2014-06','2014-11','category')
korra_postKAcat = TagsAnalyzer(korra_all,'2014-12','2015-07','category')

print('Pre-Korrasami')
print(korra_preKAcat[:5])
print('\n Korrasami Subtext')
print(korra_subKAcat[:5])
print('\n Post-Korrasami')
print(korra_postKAcat[:5])
# Out:
# Pre-Korrasami
# [('f/m,', 40.95904095904096), ('gen,', 30.81918081918082), ('m/m,', 12.137862137862138), ('f/f,', 9.990009990009991), ('multi,', 4.545454545454546)]
#
#  Korrasami Subtext
# [('f/f,', 43.007915567282325), ('f/m,', 23.7467018469657), ('gen,', 22.427440633245382), ('m/m,', 6.596306068601583), ('multi,', 2.638522427440633)]
#
#  Post-Korrasami
# [('f/f,', 55.596707818930035), ('f/m,', 20.16460905349794), ('gen,', 14.238683127572017), ('m/m,', 4.938271604938271), ('multi,', 3.4156378600823043)]
# /Users/caramessina/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Game of Thrones Metadata
#
# #### Relationship Tags

# %%
#seasons 1 and 2 – season 3 starts March 2013
got1_2relationship = TagsAnalyzer(got_all,'2006-08','2013-02','relationship')
print('\n Seasons 1 and 2')
print(got1_2relationship)

#seasons 3 and 4 – season 5 starts April 2015
got3_4relationship = TagsAnalyzer(got_all,'2013-03','2015-03','relationship')
print('\n Seasons 3 and 4')
print(got3_4relationship)

#seasons 5 and 6 – season 7 starts July 2017
got5_6relationship = TagsAnalyzer(got_all,'2015-07','2017-06','relationship')
print('\n Seasons 5 and 6')
print(got5_6relationship)

#season 7 – seasons 8 starts April 2019
got7relationship = TagsAnalyzer(got_all,'2017-07','2019-03','relationship')
print('\n Season 7')
print(got7relationship)

#season 7 – seasons 8 starts April 2019
got8relationship = TagsAnalyzer(got_all,'2019-04','2019-09','relationship')
print('\n Season 8')
print(got8relationship)
# Out:
# /Users/caramessina/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  Seasons 1 and 2
# [('jaime lannister/brienne of tarth,', 147), ('arya stark/gendry waters,', 100), ('sandor clegane/sansa stark,', 76), ('cersei lannister/jaime lannister,', 71), ('theon greyjoy/robb stark,', 68), ('renly baratheon/loras tyrell,', 67), ('jon snow/robb stark,', 61), ('catelyn stark/ned stark,', 60), ('gendry/arya stark,', 49), ('jon snow/sansa stark,', 29), ('jorah mormont/daenerys targaryen,', 28), ('robb stark/jeyne westerling,', 25), ('sansa stark/willas tyrell,', 22), ('lyanna stark/rhaegar targaryen,', 21), ('joffrey baratheon/sansa stark,', 21), ('jon snow/daenerys targaryen,', 20), ('jon snow/ygritte,', 20), ('myrcella baratheon/robb stark,', 19), ('jaime lannister/sansa stark,', 19), ('petyr baelish/sansa stark,', 16), ('robert baratheon/cersei lannister,', 15), ('stannis baratheon/davos seaworth,', 15), ('theon greyjoy/jon snow,', 14), ('jon snow/arya stark,', 14), ('sansa stark/margaery tyrell,', 12), ("jaqen h'ghar/arya stark,", 12), ('cersei lannister/ned stark,', 11), ('tyrion lannister/sansa stark,', 11), ('arya stark/aegon vi targaryen,', 11), ('jon snow/val,', 11), ('robert baratheon/lyanna stark,', 9), ('daenerys targaryen/doreah (asoiaf),', 9), ('khal drogo/daenerys targaryen,', 9), ('theon greyjoy/sansa stark,', 9), ('tywin lannister/arya stark,', 9), ('brandon stark/catelyn stark,', 8), ('dacey mormont/robb stark,', 8), ('jon snow/samwell tarly,', 8), ('ashara dayne/ned stark,', 8), ('shireen baratheon/rickon stark,', 8), ('meera reed/bran stark,', 8), ('cersei lannister/sansa stark,', 7), ('asha greyjoy/theon greyjoy,', 7), ('robb stark/margaery tyrell,', 7), ('stannis baratheon/sansa stark,', 7), ('erik lehnsherr/charles xavier,', 6), ('elia martell/rhaegar targaryen,', 6), ('cersei lannister/lancel lannister,', 6), ('petyr baelish/catelyn stark,', 5), ('robb stark/daenerys targaryen,', 5), ('renly baratheon/margaery tyrell,', 5), ('daenerys targaryen/viserys targaryen,', 5), ('aegon vi targaryen/daenerys targaryen,', 5), ('joanna lannister/tywin lannister,', 5), ('jaime lannister/robb stark,', 5), ('melisandre of asshai/stannis baratheon,', 5), ('robb stark/sansa stark,', 5), ('loras tyrell/renly baratheon,', 5), ('jon snow/catelyn stark,', 5), ('kit harington/richard madden,', 5), ('stannis baratheon/jon snow,', 5), ('myrcella baratheon/jon snow,', 5), ('petyr baelish/lysa tully arryn,', 4), ('blaine anderson/kurt hummel,', 4), ('myrcella baratheon/trystane martell,', 4), ('sandor clegane & sansa stark,', 4), ('harrold hardyng/sansa stark,', 4), ('ambiguous or implied pairing,', 4), ('dacey mormont/jon snow,', 4), ('brandon stark/lyanna stark,', 4), ('roslin frey/edmure tully,', 4), ('sansa stark/aegon vi targaryen,', 4), ('edric dayne/arya stark,', 4), ('arianne martell/edmure tully,', 4), ('brienne/jaime lannister,', 3), ('sean bean/aidan gillen,', 3), ('jaime lannister/jon snow,', 3), ('theon greyjoy/jon snow/robb stark,', 3), ('joffrey baratheon/margaery tyrell,', 3), ('gendry/sansa stark,', 3), ('barbrey dustin/brandon stark,', 3), ('robert baratheon/ned stark,', 3), ('elia martell/oberyn martell,', 3), ('jon snow/jeyne westerling,', 3), ('catelyn stark/jaime lannister,', 3), ('jaime lannister/ned stark,', 3), ('sansa stark/mya stone,', 3), ('sean bean/viggo mortensen,', 3), ('ashara dayne/brandon stark,', 3), ('arya stark/sansa stark,', 3), ('lynesse hightower/jorah mormont,', 3), ('oberyn martell/ellaria sand,', 3), ('robb stark/original character,', 3), ('jon snow/sansa stark/val,', 3), ('agron/nasir,', 3), ('roslin frey/robb stark,', 3), ('jon snow/margaery tyrell,', 3), ('jaime lannister/arya stark,', 3), ('shae/tyrion lannister,', 3), ('cersei lannister/rhaegar targaryen,', 3), ('derek hale/stiles stilinski,', 3), ('shireen baratheon/aegon vi targaryen,', 3), ('robert "sweetrobin" arryn/tommen baratheon,', 3), ('stannis baratheon/asha greyjoy,', 3), ('jaime lannister/catelyn stark,', 2), ('daenerys/doreah,', 2), ('jon/sansa,', 2), ('merlin/arthur pendragon,', 2), ('ned stark/petyr baelish,', 2) ...
#  Seasons 3 and 4
# [('jaime lannister/brienne of tarth,', 541), ('arya stark/gendry waters,', 520), ('sandor clegane/sansa stark,', 433), ('catelyn stark/ned stark,', 263), ('sansa stark/margaery tyrell,', 217), ('cersei lannister/jaime lannister,', 203), ('theon greyjoy/robb stark,', 186), ('renly baratheon/loras tyrell,', 175), ('jon snow/sansa stark,', 161), ('petyr baelish/sansa stark,', 156), ('ramsay bolton/theon greyjoy,', 150), ('sandor clegane & sansa stark,', 142), ('jon snow/ygritte,', 132), ('jon snow/robb stark,', 126), ('lyanna stark/rhaegar targaryen,', 110), ('joffrey baratheon/sansa stark,', 94), ('robb stark/jeyne westerling,', 88), ('tyrion lannister/sansa stark,', 84), ('ramsay bolton/reek,', 84), ('sansa stark/willas tyrell,', 70), ('robert baratheon/cersei lannister,', 65), ('jojen reed/bran stark,', 64), ('myrcella baratheon/robb stark,', 63), ('elia martell/rhaegar targaryen,', 60), ('jon snow/daenerys targaryen,', 52), ('robb stark/sansa stark,', 52), ('stannis baratheon/davos seaworth,', 52), ('shireen baratheon/rickon stark,', 51), ('theon greyjoy/jon snow,', 50), ('robert baratheon/lyanna stark,', 49), ('khal drogo/daenerys targaryen,', 48), ('robb stark/margaery tyrell,', 46), ('oberyn martell/ellaria sand,', 46), ("jaqen h'ghar/arya stark,", 45), ('joffrey baratheon/margaery tyrell,', 44), ('ramsay bolton/theon greyjoy/reek,', 44), ('arya stark/aegon vi targaryen,', 41), ('meera reed/bran stark,', 38), ('jaime lannister/sansa stark,', 37), ('jorah mormont/daenerys targaryen,', 34), ('jon snow/arya stark,', 33), ('arya stark & sansa stark,', 33), ('derek hale/stiles stilinski,', 31), ('theon greyjoy/sansa stark,', 29), ('melisandre of asshai/stannis baratheon,', 28), ('talisa maegyr/robb stark,', 28), ('gilly (asoiaf)/samwell tarly,', 27), ('tywin lannister/sansa stark,', 26), ('ashara dayne/ned stark,', 25), ('theon greyjoy/jeyne poole,', 25), ('joanna lannister/tywin lannister,', 24), ('other relationship tags to be added,', 24), ('jon snow/samwell tarly,', 23), ('brandon stark/catelyn stark,', 22), ('jon snow & arya stark,', 20), ('satin flowers/jon snow,', 20), ('aerys ii targaryen/rhaella targaryen,', 20), ('ramsay bolton/jeyne poole,', 20), ('grenn (asoiaf)/pypar (asoiaf),', 20), ('castiel/dean winchester,', 19), ('arya stark & gendry waters,', 18), ('cersei lannister/ned stark,', 18), ('tyrion lannister & sansa stark,', 18), ('roslin frey/edmure tully,', 17), ('tyrion lannister/shae,', 17), ('sansa stark/aegon vi targaryen,', 17), ('oberyn martell/sansa stark,', 16), ('arthur dayne/elia martell,', 15), ('petyr baelish/lysa tully arryn,', 15), ('ashara dayne/brandon stark,', 15), ('jon snow & sansa stark,', 15), ('roose bolton/theon greyjoy,', 15), ('bilbo baggins/thorin oakenshield,', 14), ('renly baratheon/margaery tyrell,', 14), ('cersei lannister/sansa stark,', 14), ('ramsay bolton/roose bolton,', 14), ('myrcella baratheon/trystane martell,', 14), ('harrold hardyng/sansa stark,', 14), ('tywin lannister/aerys ii targaryen,', 13), ('sansa stark/brienne of tarth,', 13), ('roose bolton/walda frey,', 13), ('oberyn martell/lyanna stark,', 13), ('cersei lannister/margaery tyrell,', 13), ('tywin lannister/arya stark,', 12), ('aegon vi targaryen/daenerys targaryen,', 12), ('minor or background relationship(s),', 12), ('ambiguous or implied relationship(s),', 12), ('podrick payne/sansa stark,', 12), ('jon snow & robb stark,', 12), ('cersei lannister/rhaegar targaryen,', 12), ('ramsay bolton/myranda (game of thrones),', 12), ('daenerys targaryen/viserys targaryen,', 11), ('theon greyjoy/jon snow/robb stark,', 11), ('enjolras/grantaire,', 11), ('edric dayne/arya stark,', 11), ('sansa stark/daenerys targaryen,', 11), ('davos seaworth/marya seaworth,', 11), ('jaime lannister/arya stark,', 11), ('sansa stark/gendry waters,', 11), ('tommen baratheon/margaery tyrell,', 11), ('hyle hunt/brienne of tarth,', 10), ('sherlock holmes/john watson,', 10), ('selyse baratheon/stannis baratheon,', 10), ('jaime lannister/daenerys targa ...
#  Seasons 5 and 6
# [('jon snow/sansa stark,', 1015), ('jaime lannister/brienne of tarth,', 663), ('sandor clegane/sansa stark,', 481), ('arya stark/gendry waters,', 366), ('petyr baelish/sansa stark,', 269), ('catelyn stark/ned stark,', 259), ('sansa stark/margaery tyrell,', 248), ('cersei lannister/jaime lannister,', 173), ('theon greyjoy/robb stark,', 169), ('jon snow/ygritte,', 166), ('lyanna stark/rhaegar targaryen,', 157), ('renly baratheon/loras tyrell,', 152), ('sandor clegane & sansa stark,', 147), ('jon snow/daenerys targaryen,', 144), ('ramsay bolton/theon greyjoy,', 126), ('jon snow/robb stark,', 122), ('minor or background relationship(s),', 102), ('jon snow/arya stark,', 94), ('stannis baratheon/sansa stark,', 89), ('joffrey baratheon/sansa stark,', 82), ('shireen baratheon/rickon stark,', 76), ('jojen reed/bran stark,', 73), ('tyrion lannister/sansa stark,', 72), ('jon snow & sansa stark,', 70), ('elia martell/rhaegar targaryen,', 66), ('robb stark/margaery tyrell,', 65), ('meera reed/bran stark,', 63), ('jon snow & arya stark,', 61), ('robb stark/sansa stark,', 61), ('arya stark & sansa stark,', 60), ('robert baratheon/cersei lannister,', 59), ('khal drogo/daenerys targaryen,', 58), ('tormund giantsbane/brienne of tarth,', 58), ('ramsay bolton/reek,', 52), ('ramsay bolton/sansa stark,', 51), ('theon greyjoy/sansa stark,', 51), ('gilly (asoiaf)/samwell tarly,', 49), ('oberyn martell/ellaria sand,', 49), ('myrcella baratheon/robb stark,', 48), ('robb stark/jeyne westerling,', 48), ('sansa stark/willas tyrell,', 46), ('other relationship tags to be added,', 43), ('arya stark & gendry waters,', 42), ('stannis baratheon/davos seaworth,', 42), ('tyrion lannister/shae,', 40), ('jon snow & robb stark,', 39), ('jorah mormont/daenerys targaryen,', 38), ('robert baratheon/lyanna stark,', 38), ('talisa maegyr/robb stark,', 37), ("jaqen h'ghar/arya stark,", 37), ('jaime lannister/sansa stark,', 36), ('jaime lannister & brienne of tarth,', 34), ('theon greyjoy/jon snow,', 34), ('ashara dayne/ned stark,', 31), ('ramsay bolton/theon greyjoy/reek,', 30), ('arya stark/daenerys targaryen,', 30), ('joffrey baratheon/margaery tyrell,', 27), ('oberyn martell/willas tyrell,', 27), ('tormund giantsbane/jon snow,', 27), ('oberyn martell/sansa stark,', 25), ('yara greyjoy/daenerys targaryen,', 25), ('tyrion lannister & sansa stark,', 24), ('jon snow/original female character(s),', 24), ('tywin lannister/sansa stark,', 24), ('brandon stark/catelyn stark,', 24), ('bronn/margaery tyrell,', 24), ('myrcella baratheon/trystane martell,', 23), ('ashara dayne/brandon stark,', 22), ('sandor clegane/original female character(s),', 22), ('podrick payne/arya stark,', 22), ('jon snow & daenerys targaryen,', 21), ('robb stark/daenerys targaryen,', 21), ('melisandre of asshai/stannis baratheon,', 21), ('theon greyjoy & robb stark,', 21), ('robb stark/original female character(s),', 20), ('jon snow & ned stark,', 20), ('sandor clegane & arya stark,', 20), ('podrick payne & brienne of tarth,', 20), ('harrold hardyng/sansa stark,', 19), ('jon snow/samwell tarly,', 19), ('ramsay bolton/jon snow,', 19), ('petyr baelish/lysa tully arryn,', 19), ('arya stark/aegon vi targaryen,', 18), ('sansa stark/daenerys targaryen,', 18), ('clarke griffin/lexa,', 18), ('jon snow/val,', 18), ('jon snow/robb stark/sansa stark,', 17), ('grey worm/missandei,', 16), ('petyr baelish & sansa stark,', 16), ('podrick payne/sansa stark,', 16), ('robb stark & sansa stark,', 16), ('jon snow/margaery tyrell,', 16), ('theon greyjoy/jon snow/robb stark,', 16), ('elia martell/lyanna stark/rhaegar targaryen,', 16), ('tommen baratheon/margaery tyrell,', 15), ('ramsay bolton/roose bolton,', 15), ('arthur dayne/elia martell,', 15), ('tyrion lannister/tysha,', 15), ('daario naharis/daenerys targaryen,', 15), ('jojen reed/sansa stark,', 15), ('sansa stark/aegon vi targaryen,', 14), ('roose bolton/walda frey,', 14), ('theon greyjoy & sansa stark,', 14), ('ramsay bolton/beric dondarrion,', 14), ('jaime lannister/or ...
#  Season 7
# [('jon snow/sansa stark,', 2196), ('jon snow/daenerys targaryen,', 1288), ('jaime lannister/brienne of tarth,', 879), ('arya stark/gendry waters,', 690), ('sandor clegane/sansa stark,', 472), ('catelyn stark/ned stark,', 396), ('petyr baelish/sansa stark,', 292), ('cersei lannister/jaime lannister,', 263), ('lyanna stark/rhaegar targaryen,', 253), ('sandor clegane & sansa stark,', 219), ('theon greyjoy/robb stark,', 196), ('minor or background relationship(s),', 184), ('sansa stark/margaery tyrell,', 176), ('robb stark/margaery tyrell,', 161), ('jon snow/ygritte,', 152), ('jon snow & sansa stark,', 148), ('arya stark & sansa stark,', 143), ('jon snow & arya stark,', 142), ('tyrion lannister/sansa stark,', 132), ('jaime lannister/sansa stark,', 130), ('jon snow/arya stark,', 126), ('jon snow & daenerys targaryen,', 112), ('renly baratheon/loras tyrell,', 111), ('sansa stark/daenerys targaryen,', 100), ('theon greyjoy/sansa stark,', 99), ('ashara dayne/ned stark,', 97), ('robert baratheon/cersei lannister,', 94), ('theon greyjoy/jon snow,', 93), ('meera reed/bran stark,', 91), ('elia martell/rhaegar targaryen,', 88), ('gilly (asoiaf)/samwell tarly,', 84), ('jon snow/robb stark,', 84), ('ramsay bolton/theon greyjoy,', 84), ('tormund giantsbane/brienne of tarth,', 81), ('khal drogo/daenerys targaryen,', 77), ('arya stark & gendry waters,', 76), ('grey worm/missandei,', 72), ('other relationship tags to be added,', 70), ('joffrey baratheon/sansa stark,', 67), ('robb stark/original female character(s),', 63), ('talisa maegyr/robb stark,', 62), ('jon snow & robb stark,', 58), ('oberyn martell/ellaria sand,', 58), ('jorah mormont/daenerys targaryen,', 55), ('robb stark/jeyne westerling,', 55), ('ramsay bolton/reader,', 55), ('myrcella baratheon/robb stark,', 54), ('jaime lannister & brienne of tarth,', 54), ('jon snow/original female character(s),', 53), ('ramsay bolton/sansa stark,', 52), ("jaqen h'ghar/arya stark,", 50), ('robert baratheon/lyanna stark,', 46), ('bronn/jaime lannister,', 46), ('arya stark/sansa stark,', 45), ('stannis baratheon/sansa stark,', 45), ('sansa stark/willas tyrell,', 44), ('jon snow/val,', 41), ('brandon stark/catelyn stark,', 40), ('joffrey baratheon/margaery tyrell,', 40), ('sansan - relationship,', 40), ('arianne martell/jon snow,', 39), ('elia martell/lyanna stark/rhaegar targaryen,', 38), ('yara greyjoy/daenerys targaryen,', 36), ('jon snow/rhaenys targaryen,', 36), ('sandor clegane/original female character(s),', 36), ('arya stark/daenerys targaryen,', 36), ('shireen baratheon/rickon stark,', 35), ('robb stark/sansa stark,', 35), ('jon snow/margaery tyrell,', 35), ('sandor clegane/arya stark,', 34), ('jon snow/reader,', 33), ('jaime lannister & tyrion lannister,', 32), ('petyr baelish/lysa tully arryn,', 32), ('oberyn martell/sansa stark,', 32), ('ramsay bolton/reek,', 30), ('robb stark/daenerys targaryen,', 30), ('jojen reed/bran stark,', 29), ('aerys ii targaryen/rhaella targaryen,', 29), ('sandor clegane & arya stark,', 28), ('jon snow/gendry waters,', 27), ('tyrion lannister/shae,', 27), ('jaime lannister/original female character(s),', 26), ('joanna lannister/tywin lannister,', 26), ('arya stark/aegon vi targaryen,', 26), ('ramsay bolton & reader,', 25), ('arya stark & bran stark,', 25), ('cersei lannister/ned stark,', 25), ('jon snow/aegon vi targaryen,', 25), ('podrick payne/sansa stark,', 25), ('sansa stark/brienne of tarth,', 25), ('arthur dayne/lyanna stark,', 25), ('harrold hardyng/sansa stark,', 24), ('elia martell/lyanna stark,', 24), ('robb stark & sansa stark,', 24), ('petyr baelish & sansa stark,', 23), ('tyrion lannister & sansa stark,', 23), ('jaime lannister/daenerys targaryen,', 23), ('theon greyjoy & robb stark,', 22), ('myrcella baratheon/trystane martell,', 22), ('jon snow & ned stark,', 22), ('arthur dayne/elia martell,', 21), ('sansa stark & margaery tyrell,', 21), ('theon greyjoy & sansa stark,', 21), ('jon arryn/lysa tully arryn,', 21), ('edric dayne/arya stark,', 21), ('ra ...
#  Season 8
# [('jaime lannister/brienne of tarth,', 1343), ('arya stark/gendry waters,', 1337), ('jon snow/daenerys targaryen,', 841), ('jon snow/sansa stark,', 709), ('theon greyjoy/sansa stark,', 304), ('sandor clegane/sansa stark,', 250), ('cersei lannister/jaime lannister,', 212), ('catelyn stark/ned stark,', 190), ('tormund giantsbane/jon snow,', 184), ('minor or background relationship(s),', 183), ('tyrion lannister/sansa stark,', 169), ('arya stark & sansa stark,', 160), ('arya stark & gendry waters,', 146), ('sansa stark/margaery tyrell,', 141), ('jon snow & arya stark,', 118), ('jon snow/ygritte,', 110), ('theon greyjoy/robb stark,', 108), ('grey worm/missandei,', 107), ('jorah mormont/daenerys targaryen,', 101), ('sansa stark/daenerys targaryen,', 95), ('lyanna stark/rhaegar targaryen,', 90), ('jon snow & daenerys targaryen,', 89), ('jon snow & sansa stark,', 88), ('robb stark/margaery tyrell,', 87), ('jaime lannister & brienne of tarth,', 86), ('jaime lannister/sansa stark,', 74), ('sandor clegane & sansa stark,', 72), ('petyr baelish/sansa stark,', 69), ('meera reed/bran stark,', 67), ('podrick payne/sansa stark,', 59), ('sandor clegane & arya stark,', 59), ('yara greyjoy/daenerys targaryen,', 57), ('talisa maegyr/robb stark,', 53), ('jaime lannister & tyrion lannister,', 50), ('jon snow/arya stark,', 49), ('renly baratheon/loras tyrell,', 49), ('theon greyjoy & sansa stark,', 48), ('gilly (asoiaf)/samwell tarly,', 47), ('robert baratheon/cersei lannister,', 46), ('tyrion lannister & sansa stark,', 44), ('arya stark & bran stark,', 44), ('ramsay bolton/theon greyjoy,', 43), ('sansa stark & brienne of tarth,', 41), ('jon snow/robb stark,', 39), ('joffrey baratheon/sansa stark,', 39), ('jon snow/original female character(s),', 38), ('podrick payne & brienne of tarth,', 38), ('tormund giantsbane/brienne of tarth,', 36), ('elia martell/rhaegar targaryen,', 35), ('jon snow/rhaenys targaryen,', 34), ('robb stark/jeyne westerling,', 33), ('tyrion lannister/shae,', 30), ('khal drogo/daenerys targaryen,', 30), ('arya stark/daenerys targaryen,', 28), ('jon snow & robb stark,', 28), ('ashara dayne/ned stark,', 28), ('theon greyjoy/jon snow,', 27), ('jojen reed/bran stark,', 27), ("jaqen h'ghar/arya stark,", 27), ('stannis baratheon/sansa stark,', 27), ('theon greyjoy & robb stark,', 25), ('oberyn martell/ellaria sand,', 25), ('jon snow/margaery tyrell,', 25), ('sandor clegane/original female character(s),', 24), ('theon greyjoy & yara greyjoy,', 24), ('jon snow/val,', 24), ('arianne martell/jon snow,', 24), ('ramsay bolton/sansa stark,', 22), ('other relationship tags to be added,', 22), ('sandor clegane/arya stark,', 22), ('daario naharis/daenerys targaryen,', 22), ('aegon vi targaryen/daenerys targaryen,', 22), ('jaime lannister/original female character(s),', 21), ('sansa stark/brienne of tarth,', 21), ('tywin lannister/sansa stark,', 21), ('myrcella baratheon/robb stark,', 21), ('jon snow/aegon vi targaryen,', 21), ('missandei & daenerys targaryen,', 20), ('jon snow & bran stark,', 20), ('theon greyjoy & jon snow,', 20), ('elia martell/lyanna stark/rhaegar targaryen,', 20), ('bran stark & sansa stark,', 20), ('robb stark/original female character(s),', 19), ('tormund giantsbane & jon snow,', 19), ('petyr baelish & sansa stark,', 18), ('robb stark/daenerys targaryen,', 17), ('jaime lannister & sansa stark,', 17), ('shireen baratheon/rickon stark,', 17), ('brandon stark/catelyn stark,', 17), ('harrold hardyng/sansa stark,', 17), ('lyanna mormont/rickon stark,', 17), ('sansa stark & margaery tyrell,', 17), ('davos seaworth & gendry waters,', 16), ('cersei lannister & jaime lannister,', 16), ('sansa stark/original male character(s),', 16), ('stannis baratheon & sansa stark,', 16), ('cersei lannister/ned stark,', 15), ('robb stark & sansa stark,', 15), ('jon snow & ned stark,', 15), ('ramsay bolton/reader,', 15), ('sansa stark/willas tyrell,', 14), ('aerys ii targaryen/rhaella targaryen,', 14), ('arya stark/sansa stark,', 14), ('arya stark ...

# %%
#SEASONS 1–2
got1_2relationshipDF = pd.DataFrame(got1_2relationship, columns =['Pairing', 'Appearance']) 
got1_2relationshipDF.to_csv('data/counting_csvs/GOT/relationships/got1-2_relationships.csv')

#SEASONS 3–4
got3_4relationshipDF = pd.DataFrame(got3_4relationship, columns =['Pairing', 'Appearance']) 
got3_4relationshipDF.to_csv('data/counting_csvs/GOT/relationships/got3-4_relationships.csv')

#SEASONS 5–6
got5_6relationshipDF = pd.DataFrame(got5_6relationship, columns =['Pairing', 'Appearance']) 
got5_6relationshipDF.to_csv('data/counting_csvs/GOT/relationships/got5-6_relationships.csv')

#SEASON 7
got7relationshipDF = pd.DataFrame(got7relationship, columns =['Pairing', 'Appearance']) 
got7relationshipDF.to_csv('data/counting_csvs/GOT/relationships/got7_relationships.csv')

#SEASON 8
got8relationshipDF = pd.DataFrame(got8relationship, columns =['Pairing', 'Appearance']) 
got8relationshipDF.to_csv('data/counting_csvs/GOT/relationships/got8_relationships.csv')

# %%
got_all_AT = TagsAnalyzer_noMonth(got_all,'additional tags', 20)
got_all_AT
# Out:
# [('alternate universe - modern setting,', 5302),
#  ('alternate universe - canon divergence,', 3098),
#  ('fluff,', 2968),
#  ('angst,', 2750),
#  ('romance,', 1712),
#  ('smut,', 1598),
#  ('alternate universe,', 1420),
#  ('slow burn,', 1070),
#  ('hurt/comfort,', 1029),
#  ('r plus l equals j,', 898),
#  ('explicit sexual content,', 892),
#  ('oral sex,', 820),
#  ('fluff and angst,', 820),
#  ('one shot,', 689),
#  ('arranged marriage,', 644),
#  ('fluff and smut,', 635),
#  ('canon compliant,', 615),
#  ('sibling incest,', 610),
#  ('sexual content,', 589),
#  ('incest,', 566),
#  ('jon snow is a targaryen,', 555),
#  ('love,', 549),
#  ('canon-typical violence,', 525),
#  ('humor,', 522),
#  ('fix-it,', 522),
#  ('family,', 519),
#  ('other additional tags to be added,', 517),
#  ('modern au,', 514),
#  ('cunnilingus,', 508),
#  ('drabble,', 503),
#  ('violence,', 503),
#  ('angst with a happy ending,', 503),
#  ('first time,', 492),
#  ('anal sex,', 485),
#  ('post-canon,', 480),
#  ('plot what plot/porn without plot,', 480),
#  ('established relationship,', 466),
#  ('character death,', 442),
#  ('emotional hurt/comfort,', 439),
#  ('eventual smut,', 439),
#  ('au,', 437),
#  ('friends to lovers,', 433),
#  ('alternate universe - college/university,', 423),
#  ('friendship,', 416),
#  ('pregnancy,', 415),
#  ('ramsay is his own warning,', 412),
#  ('drama,', 398),
#  ('falling in love,', 392),
#  ('rough sex,', 388),
#  ('sex,', 382),
#  ('jealousy,', 378),
#  ('future fic,', 365),
#  ('older man/younger woman,', 356),
#  ('crossover,', 347),
#  ('dragons,', 345),
#  ('shameless smut,', 336),
#  ('happy ending,', 336),
#  ('war,', 328),
#  ('masturbation,', 325),
#  ('dubious consent,', 321),
#  ('cousin incest,', 315),
#  ('alternate universe - high school,', 313),
#  ('mutual pining,', 311),
#  ('explicit language,', 309),
#  ('first kiss,', 308),
#  ('dirty talk,', 306),
#  ('kissing,', 305),
#  ('past abuse,', 295),
#  ('winterfell,', 292),
#  ('half-sibling incest,', 290),
#  ('blow jobs,', 288),
#  ('pining,', 286),
#  ('post-traumatic stress disorder - ptsd,', 284),
#  ('light angst,', 281),
#  ('implied/referenced rape/non-con,', 279),
#  ('crack,', 272),
#  ('modern westeros,', 269),
#  ('eventual romance,', 258),
#  ('canonical character death,', 255),
#  ('rape/non-con elements,', 255),
#  ('sansan,', 255),
#  ('sexual tension,', 253),
#  ('jonerys,', 249),
#  ('alternate universe - game of thrones fusion,', 248),
#  ('marriage,', 247),
#  ('torture,', 242),
#  ('loss of virginity,', 240),
#  ('death,', 239),
#  ('jonsa,', 239),
#  ('minor character death,', 238),
#  ('fluff and humor,', 235),
#  ('house stark,', 234),
#  ('politics,', 234),
#  ('vaginal fingering,', 234),
#  ('unresolved sexual tension,', 233),
#  ('grief/mourning,', 231),
#  ('murder,', 225),
#  ('magic,', 225),
#  ('character study,', 223),
#  ('love confessions,', 219),
#  ('domestic fluff,', 219),
#  ('reunions,', 217),
#  ('spoilers,', 216),
#  ('game of thrones references,', 215),
#  ('tooth-rotting fluff,', 213),
#  ('friendship/love,', 204),
#  ('spanking,', 203),
#  ('gendrya - freeform,', 200),
#  ('porn with plot,', 199),
#  ('family feels,', 199),
#  ('past rape/non-con,', 198),
#  ('revenge,', 197),
#  ('jon and sansa are not related,', 196),
#  ('secret relationship,', 195),
#  ('angst and hurt/comfort,', 195),
#  ('vaginal sex,', 194),
#  ('pre-canon,', 193),
#  ('modern era,', 191),
#  ('inspired by game of thrones,', 191),
#  ('slow build,', 188),
#  ('sansa-centric,', 188),
#  ('anal fingering,', 186),
#  ('implied sexual content,', 185),
#  ('pov multiple,', 183),
#  ('alpha/beta/omega dynamics,', 181),
#  ('femslash,', 180),
#  ('forbidden love,', 178),
#  ('action/adventure,', 177),
#  ('original character(s),', 176),
#  ('unrequited love,', 175),
#  ('game of thrones - freeform,', 175),
#  ('porn with feelings,', 175),
#  ('blood,', 174),
#  ('abuse,', 173),
#  ('season/series 08,', 173),
#  ('idiots in love,', 172),
#  ('age difference,', 170),
#  ('time travel,', 169),
#  ('missing scene,', 168),
#  ('fix-it of sorts,', 168),
#  ('hand jobs,', 167),
#  ('alternate universe - fantasy,', 167),
#  ('weddings,', 160),
#  ('family drama,', 159),
#  ('tumblr prompt,', 157),
#  ('alternate universe - historical,', 156),
#  ('teasing,', 155),
#  ('voyeurism,', 154),
#  ("i don't even know,", 154),
#  ('queen daenerys,', 154),
#  ('implied/referenced character death,', 154),
#  ('ficlet,', 151),
#  ('dark jon snow,', 150),
#  ('jon snow knows something,', 149),
#  ('season 8,', 147),
#  ('fantasy,', 146),
#  ('alternate universe - soulmates,', 146),
#  ('aged-up character(s),', 144),
#  ('not beta read,', 142),
#  ('angst and fluff and smut,', 141),
#  ('queen sansa,', 140),
#  ('pre-a game of thrones,', 137),
#  ('unplanned pregnancy,', 137),
#  ('angst and feels,', 136),
#  ('blood and gore,', 136),
#  ('heavy angst,', 136),
#  ('dark,', 135),
#  ('flirting,', 134),
#  ('enemies to friends to lovers,', 133),
#  ('possessive behavior,', 132),
#  ('dom/sub,', 131),
#  ('developing relationship,', 131),
#  ('not canon compliant,', 131),
#  ('underage sex,', 130),
#  ("don't copy to another site,", 130),
#  ('implied/referenced incest,', 130),
#  ('sansa stark is queen in the north,', 130),
#  ('past relationship(s),', 129),
#  ('family fluff,', 129),
#  ('house targaryen,', 128),
#  ('jon snow knows nothing,', 127),
#  ('drabble collection,', 125),
#  ('true love,', 125),
#  ('drama & romance,', 125),
#  ('sharing a bed,', 124),
#  ('short one shot,', 124),
#  ('infidelity,', 122),
#  ('flashbacks,', 122),
#  ('game of thrones spoilers,', 122),
#  ('no english,', 121),
#  ('forced marriage,', 121),
#  ('comfort,', 121),
#  ('robb stark is a gift,', 120),
#  ('rape,', 119),
#  ('prompt fill,', 119),
#  ('first meetings,', 118),
#  ('jon and the starks are not related,', 118),
#  ('i will go down with this ship,', 117),
#  ('kidnapping,', 116),
#  ('fake/pretend relationship,', 116),
#  ('swearing,', 116),
#  ('sibling bonding,', 115),
#  ('christmas,', 115),
#  ('rimming,', 114),
#  ('marriage proposal,', 114),
#  ('aunt/nephew incest,', 113),
#  ('house lannister,', 112),
#  ('pwp,', 112),
#  ('alternate universe - rhaegar won,', 112),
#  ('pov female character,', 111),
#  ('asoiaf kink meme,', 111),
#  ('canon divergence,', 111),
#  ('polyamory,', 111),
#  ('alternate universe - canon,', 110),
#  ('alternate universe - medieval,', 110),
#  ('soulmates,', 110),
#  ('emotional/psychological abuse,', 110),
#  ('game of thrones au,', 108),
#  ('light dom/sub,', 108),
#  ('fluff and crack,', 107),
#  ('unresolved romantic tension,', 107),
#  ('bdsm,', 107),
#  ('daddy kink,', 105),
#  ('nightmares,', 105),
#  ('depression,', 105),
#  ('the author regrets nothing,', 105),
#  ('introspection,', 105),
#  ('sibling love,', 104),
#  ('eventual happy ending,', 104),
#  ('jon snow is a stark,', 104),
#  ('bondage,', 103),
#  ('queen in the north,', 103),
#  ('cheating,', 103),
#  ('dom/sub undertones,', 103),
#  ('jon snow is king in the north,', 103),
#  ('twincest,', 102),
#  ('pov alternating,', 102),
#  ('mpreg,', 102),
#  ('guilt,', 102),
#  ('mildly dubious consent,', 102),
#  ('betrayal,', 101),
#  ('post season 7,', 101),
#  ('what-if,', 100),
#  ('power dynamics,', 100),
#  ('implied/referenced torture,', 99),
#  ('enemies to lovers,', 99),
#  ('female jon snow,', 98),
#  ('post-canon fix-it,', 98),
#  ('somali,', 96),
#  ('warging,', 96),
#  ('sort of,', 96),
#  ('white walkers,', 96),
#  ('humiliation,', 95),
#  ('siblings,', 95),
#  ('childbirth,', 94),
#  ('threesome - f/m/m,', 94),
#  ('light bondage,', 94),
#  ('cute,', 94),
#  ('game of thrones-esque,', 94),
#  ('adventure,', 93),
#  ('love/hate,', 93),
#  ('stockholm syndrome,', 93),
#  ('mental health issues,', 93),
#  ('post - a dance with dragons,', 92),
#  ('post-war,', 92),
#  ('semi-public sex,', 92),
#  ('crack treated seriously,', 92),
#  ('prompt fic,', 91),
#  ('mild language,', 91),
#  ('wedding night,', 91),
#  ('badass arya,', 91),
#  ('suicidal thoughts,', 90),
#  ('physical abuse,', 90),
#  ('married couple,', 89),
#  ('alternate universe - arranged marriage,', 89),
#  ('pre-relationship,', 88),
#  ('feels,', 87),
#  ('resurrection,', 87),
#  ('implied/referenced abuse,', 87),
#  ('canon universe,', 87),
#  ('fanart,', 86),
#  ('brother-sister relationships,', 86),
#  ('threesome - f/f/m,', 86),
#  ('drinking,', 86),
#  ('westeros,', 86),
#  ('romantic fluff,', 86),
#  ('soulmate-identifying marks,', 86),
#  ("robert's rebellion,", 85),
#  ('alternate universe - gender changes,', 85),
#  ('healing,', 85),
#  ('rare pairings,', 85),
#  ('past cersei lannister/jaime lannister,', 85),
#  ('pov arya stark,', 85),
#  ('crossover pairings,', 84),
#  ('attempted rape/non-con,', 84),
#  ('fingerfucking,', 83),
#  ('babies,', 83),
#  ('secrets,', 83),
#  ('attempt at humor,', 83),
#  ('banter,', 82),
#  ('pre-series,', 82),
#  ('mild sexual content,', 82),
#  ('comedy,', 82),
#  ('manipulation,', 82),
#  ('underage drinking,', 82),
#  ('pov jaime lannister,', 82),
#  ('father-daughter relationship,', 81),
#  ('reincarnation,', 81),
#  ('alternate universe - hogwarts,', 81),
#  ('blood and violence,', 81),
#  ('misunderstandings,', 81),
#  ('gendry is a baratheon,', 81),
#  ('jon snow is not called aegon,', 81),
#  ('dysfunctional family,', 80),
#  ('love triangles,', 80),
#  ('emotional manipulation,', 80),
#  ('bittersweet,', 79),
#  ('public sex,', 79),
#  ('dark sansa,', 78),
#  ('miscarriage,', 77),
#  ('crossovers & fandom fusions,', 77),
#  ('biting,', 77),
#  ('5+1 things,', 77),
#  ('christmas fluff,', 77),
#  ('pov sansa stark,', 77),
#  ('past character death,', 76),
#  ('minor arya stark/gendry waters,', 76),
#  ('slash,', 75),
#  ('sister-sister relationship,', 75),
#  ('sexual fantasy,', 75),
#  ('psychological torture,', 75),
#  ('halloween,', 75),
#  ('brienne is the best,', 75),
#  ('dreams,', 74),
#  ('alternate universe - fusion,', 74),
#  ('direwolves,', 74),
#  ('prostitution,', 74),
#  ('drug use,', 74),
#  ('threats of rape/non-con,', 74),
#  ('i wrote this instead of sleeping,', 74),
#  ('brother/sister incest,', 74),
#  ('texting,', 74),
#  ('female friendship,', 73),
#  ('high school,', 73),
#  ('kid fic,', 73),
#  ('heartbreak,', 73),
#  ('out of character,', 73),
#  ('post-series,', 73),
#  ('implied/referenced child abuse,', 73),
#  ('pov jon snow,', 73),
#  ('tragedy,', 72),
#  ('family secrets,', 72),
#  ('horror,', 72),
#  ('first love,', 72),
#  ('domestic violence,', 71),
#  ('alternate universe - future,', 71),
#  ('abusive relationships,', 71),
#  ('confessions,', 71),
#  ('trauma,', 71),
#  ('poetry,', 71),
#  ('hurt,', 70),
#  ('supernatural elements,', 70),
#  ('porn,', 70),
#  ('past torture,', 70),
#  ('alcohol,', 70),
#  ('past sexual abuse,', 70),
#  ('ghosts,', 69),
#  ('psychological trauma,', 69),
#  ('alternate canon,', 69),
#  ('asoiaf,', 69),
#  ('mild smut,', 69),
#  ('alternate universe - everyone lives/nobody dies,', 69),
#  ('lesbian sex,', 69),
#  ('the long night,', 69),
#  ('seduction,', 68),
#  ('dancing,', 68),
#  ('adultery,', 68),
#  ('cuddling & snuggling,', 68),
#  ('alternate universe - coffee shops & cafes,', 68),
#  ('canon divergence - red wedding,', 68),
#  ('internalized homophobia,', 67),
#  ('alternate universe - fairy tale,', 67),
#  ('best friends,', 67),
#  ('accidental voyeurism,', 67),
#  ('suicide attempt,', 67),
#  ("king's landing,", 67),
#  ('rhaegar lives,', 67),
#  ('outdoor sex,', 66),
#  ('declarations of love,', 66),
#  ('feelings,', 66),
#  ('sorry not sorry,', 66),
#  ('kind of,', 66),
#  ('robb lives,', 66),
#  ('minor violence,', 65),
#  ('orgasm delay/denial,', 65),
#  ('marriage of convenience,', 64),
#  ('oneshot,', 64),
#  ('awkwardness,', 64),
#  ('songfic,', 64),
#  ('jon snow is not a targaryen,', 64),
#  ('alternate universe - royalty,', 63),
#  ('pain,', 63),
#  ('meet-cute,', 63),
#  ('reader-insert,', 63),
#  ('post season 8,', 63),
#  ('protectiveness,', 62),
#  ('period-typical sexism,', 62),
#  ('complicated relationships,', 62),
#  ('bathing/washing,', 61),
#  ('sad,', 61),
#  ('essos,', 61),
#  ('threats of violence,', 61),
#  ('background relationships,', 61),
#  ('alternate universe - time travel,', 61),
#  ('post-season/series 08 finale,', 61),
#  ('threesome,', 60),
#  ('prophecy,', 60),
#  ('episode related,', 60),
#  ('alternate universe - reincarnation,', 60),
#  ('choking,', 60),
#  ('alpha/omega,', 60),
#  ('children,', 60),
#  ('love at first sight,', 60),
#  ('panic attacks,', 60),
#  ('mystery,', 60),
#  ('dorne,', 60),
#  ('pov daenerys,', 60),
#  ('implied relationships,', 59),
#  ('frottage,', 59),
#  ('protective siblings,', 59),
#  ('bullying,', 59),
#  ('memories,', 59),
#  ('alternate universe - a song of ice and fire,', 59),
#  ('alcohol abuse/alcoholism,', 59),
#  ('winter,', 59),
#  ('teacher-student relationship,', 59),
#  ('pov sansa,', 59),
#  ('season/series 07,', 59),
#  ('threesome - m/m/m,', 58),
#  ('child abuse,', 58),
#  ('drabbles,', 58),
#  ('rating may change,', 58),
#  ('got,', 58),
#  ('past child abuse,', 58),
#  ('poor theon,', 58),
#  ('character death fix,', 58),
#  ('thramsay - freeform,', 58),
#  ('angst and porn,', 58),
#  ('axgweek,', 58),
#  ('time travel fix-it,', 58),
#  ('lyanna stark lives,', 58),
#  ('king jon snow,', 58),
#  ('fanvids,', 57),
#  ('hopeful ending,', 57),
#  ("i'm sorry,", 57),
#  ('denial of feelings,', 57),
#  ('alternative universe,', 57),
#  ('romantic comedy,', 57),
#  ('war of the five kings,', 57),
#  ('wedding,', 57),
#  ('ambiguous/open ending,', 57),
#  ('sex toys,', 57),
#  ('redemption,', 57),
#  ('canon era,', 57),
#  ('originally posted on tumblr,', 57),
#  ("i'm bad at tagging,", 57),
#  ('no incest,', 57),
#  ('pre-slash,', 56),
#  ('woman on top,', 56),
#  ('sexual abuse,', 56),
#  ('alternate ending,', 56),
#  ('consensual underage sex,', 56),
#  ('recreational drug use,', 56),
#  ('anger,', 56),
#  ('red wedding,', 56),
#  ('slice of life,', 56),
#  ('post-episode: s08e03 the long night,', 56),
#  ('ptsd,', 55),
#  ('slavery,', 55),
#  ('scars,', 55),
#  ('rough oral sex,', 55),
#  ('family dynamics,', 55),
#  ('kinda,', 55),
#  ('strangers to lovers,', 55),
#  ('unreliable narrator,', 54),
#  ('pov male character,', 54),
#  ('parent/child incest,', 54),
#  ('parody,', 54),
#  ('aftermath of torture,', 54),
#  ('alternate universe - harry potter setting,', 54),
#  ('braavos,', 54),
#  ('late night conversations,', 54),
#  ('arya-centric,', 54),
#  ('bechdel test fail,', 54),
#  ('targaryen restoration,', 54),
#  ('mild gore,', 53),
#  ('anal play,', 53),
#  ('one shot collection,', 53),
#  ('werewolves,', 53),
#  ('sweet,', 52),
#  ('canon - tv,', 52),
#  ('friends with benefits,', 52),
#  ('childhood friends,', 52),
#  ('battle,', 52),
#  ('pseudo-incest,', 52),
#  ('witches,', 52),
#  ('vampires,', 51),
#  ('growing up,', 51),
#  ('motherhood,', 51),
#  ('wolves,', 51),
#  ('slow romance,', 51),
#  ('political alliances,', 51),
#  ('the king in the north,', 51),
#  ('jealous jon snow,', 51),
#  ('suicide,', 50),
#  ('crossdressing,', 50),
#  ('canon divergence - the battle of the blackwater,', 50),
#  ('exhibitionism,', 50),
#  ('female-centric,', 50),
#  ('house baratheon,', 50),
#  ('kings & queens,', 50),
#  ('praise kink,', 50),
#  ('period-typical homophobia,', 50),
#  ('coming of age,', 49),
#  ('complete,', 49),
#  ('pegging,', 49),
#  ('dragonstone,', 49),
#  ('braime - freeform,', 49),
#  ('lesbian sansa stark,', 49),
#  ('work in progress,', 48),
#  ('kink meme,', 48),
#  ('sadism,', 48),
#  ('gay sex,', 48),
#  ('femdom,', 48),
#  ('lust,', 48),
#  ('arguing,', 48),
#  ('lesbian character,', 48),
#  ('pov first person,', 48),
#  ('resolved sexual tension,', 48),
#  ('sequel,', 48),
#  ('mother-son relationship,', 48),
#  ('father-son relationship,', 48),
#  ('obsession,', 48),
#  ('royalty,', 48),
#  ('eventual fluff,', 48),
#  ('scheming,', 48),
#  ('women being awesome,', 47),
#  ('sisters,', 47),
#  ('short,', 47),
#  ('nudity,', 47),
#  ('loss,', 47),
#  ('gore,', 47),
#  ('mind games,', 47),
#  ('afterlife,', 47),
#  ('parenthood,', 47),
#  ('reunion,', 47),
#  ('bisexuality,', 47),
#  ('eventual relationships,', 47),
#  ('pov brienne of tarth,', 47),
#  ('inspired by a song of ice and fire,', 47),
#  ('drunk sex,', 46),
#  ('bonding,', 46),
#  ('fingering,', 46),
#  ('homophobia,', 46),
#  ('secret identity,', 46),
#  ('self-esteem issues,', 46),
#  ('whipping,', 46),
#  ('alternate universe - vampire,', 46),
#  ('self-harm,', 46),
#  ('family issues,', 46),
#  ('short & sweet,', 46),
#  ('recovery,', 46),
#  ('canon disabled character,', 46),
#  ('alternate universe - regency,', 46),
#  ('rough kissing,', 46),
#  ('faceless arya,', 46),
#  ("don't like don't read,", 46),
#  ('erotica,', 45),
#  ('awkward sexual situations,', 45),
#  ('hate sex,', 45),
#  ('starkcest,', 45),
#  ('alternate universe - crack,', 45),
#  ("valentine's day,", 45),
#  ('genderbending,', 45),
#  ('punishment,', 45),
#  ('dreams and nightmares,', 45),
#  ('married life,', 45),
#  ('letters,', 45),
#  ('conversations,', 45),
#  ('r plus l does not equal j,', 45),
#  ('intrigue,', 44),
#  ('sibling rivalry,', 44),
#  ('daddy issues,', 44),
#  ('dominance,', 44),
#  ('wildlings - freeform,', 44),
#  ('mental instability,', 44),
#  ('one-shot,', 44),
#  ('graphic description,', 44),
#  ('femslash february,', 44),
#  ('podfic,', 44),
#  ('light bdsm,', 44),
#  ('holidays,', 44),
#  ('past joffrey baratheon/sansa stark,', 44),
#  ('joffrey baratheon is his own warning,', 44),
#  ('post 8x03,', 44),
#  ('action,', 43),
#  ('pov third person,', 43),
#  ('non-graphic violence,', 43),
#  ('mother-daughter relationship,', 43),
#  ('unresolved emotional tension,', 43),
#  ('tragic romance,', 43),
#  ('my first fanfic,', 43),
#  ('fights,', 43),
#  ('crushes,', 43),
#  ('fighting,', 43),
#  ('anxiety,', 43),
#  ('morally ambiguous character,', 43),
#  ('roleplay,', 42),
#  ('drunkenness,', 42),
#  ('making out,', 42),
#  ('organized crime,', 42),
#  ('identity issues,', 42),
#  ('crying,', 42),
#  ('submission,', 42),
#  ('minor original character(s),', 42),
#  ('minor lyanna stark/rhaegar targaryen,', 42),
#  ('bamf jon snow,', 42),
#  ('season 7,', 42),
#  ('relationship(s),', 41),
#  ('cross-posted on fanfiction.net,', 41),
#  ('male-female friendship,', 41),
#  ('double penetration,', 41),
#  ('wall sex,', 41),
#  ('canon divergent,', 41),
#  ('comfort/angst,', 41),
#  ('tourney at harrenhal,', 41),
#  ('alternate universe - always a different sex,', 41),
#  ('modern royalty,', 41),
#  ('getting together,', 41),
#  ("tywin lannister's a+ parenting,", 41),
#  ('jonerys week,', 41),
#  ('female protagonist,', 40),
#  ('house martell,', 40),
#  ('hair-pulling,', 40),
#  ('major character injury,', 40),
#  ('video,', 40),
#  ('pregnant sex,', 40),
#  ('matchmaking,', 40),
#  ('funny,', 40),
#  ('forgiveness,', 40),
#  ('regret,', 40),
#  ('beautiful golden fools,', 40),
#  ('child death,', 40),
#  ('older woman/younger woman,', 40),
#  ('college,', 40),
#  ('memory loss,', 40),
#  ('internal conflict,', 40),
#  ('awkward flirting,', 40),
#  ('unhealthy relationships,', 40),
#  ('dark!jon,', 40),
#  ('how do i tag,', 40),
#  ('dark daenerys targaryen,', 40),
#  ('married sex,', 39),
#  ('power play,', 39),
#  ('angry sex,', 39),
#  ('break up,', 39),
#  ('fluff and hurt/comfort,', 39),
#  ('sexual violence,', 39),
#  ('extremely dubious consent,', 39),
#  ('consensual sex,', 39),
#  ('dialogue heavy,', 39),
#  ('minor cersei lannister/jaime lannister,', 39),
#  ('injury,', 38),
#  ('nipple play,', 38),
#  ('travel,', 38),
#  ('what was i thinking?,', 38),
#  ('loyalty,', 38),
#  ('cousins,', 38),
#  ('drugs,', 38),
#  ('road trips,', 38),
#  ('no plot/plotless,', 38),
#  ('rape recovery,', 38),
#  ('attempted sexual assault,', 38),
#  ('implied/referenced suicide,', 38),
#  ('strong female characters,', 38),
#  ('coming out,', 38),
#  ('post-season/series 07,', 38),
#  ('eventual jon snow/daenerys targaryen,', 38),
#  ('pov second person,', 37),
#  ('canon - book,', 37),
#  ('ust,', 37),
#  ('rpf,', 37),
#  ('goodbyes,', 37),
#  ('stark family,', 37),
#  ('strap-ons,', 37),
#  ('romantic friendship,', 37),
#  ('non-canon relationship,', 37),
#  ('tattoos,', 37),
#  ('doggy style,', 37),
#  ('sadness,', 37),
#  ('mentions of past abuse,', 37),
#  ('denial,', 37),
#  ('bittersweet ending,', 37),
#  ('i blame tumblr,', 37),
#  ('miscommunication,', 37),
#  ('fear,', 37),
#  ('grief,', 37),
#  ('sad ending,', 37),
#  ('childhood memories,', 37),
#  ('wargs,', 37),
#  ('bisexual female character,', 37),
#  ('period typical attitudes,', 37),
#  ("unbeta'd,", 37),
#  ('theon-centric,', 37),
#  ('bloodplay,', 36),
#  ('teenagers,', 36),
#  ('mutual masturbation,', 36),
#  ('angst and humor,', 36),
#  ('mutilation,', 36),
#  ('knights - freeform,', 36),
#  ('mating cycles/in heat,', 36),
#  ('implied/referenced underage sex,', 36),
#  ('family bonding,', 36),
#  ('inspired by music,', 36),
#  ('face-sitting,', 36),
#  ('the north remembers,', 36),
#  ('audio format: streaming,', 36),
#  ('developing friendships,', 36),
#  ('the faceless men,', 36),
#  ('one-sided attraction,', 36),
#  ('making love,', 36),
#  ('blood and injury,', 36),
#  ('no smut,', 36),
#  ('warg jon snow,', 36),
#  ('major character death - freeform,', 35),
#  ('period-typical underage,', 35),
#  ("i can't believe i wrote this,", 35),
#  ('ooc,', 35),
#  ('size kink,', 35),
#  ('dubious morality,', 35),
#  ('house tyrell,', 35),
#  ('swordfighting,', 35),
#  ('angst and tragedy,', 35),
#  ('shower sex,', 35),
#  ('dragon riders,', 35),
#  ('jaime/brienne appreciation week,', 35),
#  ('dry humping,', 34),
#  ('stalking,', 34),
#  ('attempted murder,', 34),
#  ('gift fic,', 34),
#  ('pov outsider,', 34),
#  ('loss of innocence,', 34),
#  ('hospitals,', 34),
#  ('awkward conversations,', 34),
#  ('nsfw,', 34),
#  ('cuddling,', 34),
#  ('wedding fluff,', 34),
#  ('mentions of rape,', 34),
#  ('some humor,', 34),
#  ('emotional hurt,', 34),
#  ('blood drinking,', 34),
#  ('the author regrets everything,', 34),
#  ('original character death(s),', 34),
#  ('fairy tale elements,', 34),
#  ('tags may change,', 34),
#  ('some angst,', 34),
#  ('post-season/series 06,', 34),
#  ('vignette,', 33),
#  ('post - a game of thrones,', 33),
#  ('multiple orgasms,', 33),
#  ('begging,', 33),
#  ('fire,', 33),
#  ('headcanon,', 33),
#  ('suspense,', 33),
#  ('knifeplay,', 33),
#  ('snow,', 33),
#  ('sansa stark - freeform,', 33),
#  ('aryaxgendry week,', 33),
#  ('women in power,', 33),
#  ('young love,', 33),
#  ('tags are hard,', 33),
#  ('blood magic,', 33),
#  ('audio format: mp3,', 33),
#  ('implied/referenced drug use,', 33),
#  ('alternate universe - post-canon,', 33),
#  ('roommates,', 33),
#  ('westerosi politics,', 33),
#  ('elia martell lives,', 33),
#  ('fuck d&d,', 33),
#  ('master/slave,', 32),
#  ('a song of ice and fire - freeform,', 32),
#  ('captivity,', 32),
#  ('canon,', 32),
#  ('one night stands,', 32),
#  ('insecurity,', 32),
#  ('alternate universe - superheroes/superpowers,', 32),
#  ('art,', 32),
#  ('jon snow - freeform,', 32),
#  ('drunken shenanigans,', 32),
#  ('modern,', 32),
#  ('singing,', 32),
#  ('collars,', 32),
#  ('dothraki,', 32),
#  ('mild hurt/comfort,', 32),
#  ('ned stark lives,', 32),
#  ('alternate universe - office,', 32),
#  ('prophetic dreams,', 32),
#  ('omega verse,', 32),
#  ('rape aftermath,', 32),
#  ('sorry - freeform,', 32),
#  ('tension,', 32),
#  ('first time blow jobs,', 32),
#  ('unhealthy coping mechanisms,', 32),
#  ('may/december relationship,', 32),
#  ('sneaking around,', 32),
#  ('breeding,', 32),
#  ('jonsa smut week,', 32),
#  ('post-episode: s08e06 the iron throne,', 32),
#  ('twins,', 31),
#  ('cannibalism,', 31),
#  ('sexy times,', 31),
#  ('older woman/younger man,', 31),
#  ('reconciliation,', 31),
#  ('alternate universe - magic,', 31),
#  ('what have i done,', 31),
#  ('witchcraft,', 31),
#  ('flaying,', 31),
#  ('secret crush,', 31),
#  ('humour,', 31),
#  ('families of choice,', 31),
#  ('sexual slavery,', 31),
#  ('face-fucking,', 31),
#  ('based on a tumblr post,', 31),
#  ('pov gendry,', 31),
#  ('longing,', 31),
#  ('tumblr ask box fic,', 31),
#  ('post-battle,', 31),
#  ('robb stark is king in the north,', 31),
#  ('sister/sister incest,', 31),
#  ('political jon,', 31),
#  ('breathplay,', 30),
#  ('sexual experimentation,', 30),
#  ('childhood,', 30),
#  ('adwd spoilers,', 30),
#  ('blackmail,', 30),
#  ('morning after,', 30),
#  ('religion,', 30),
#  ('alternate universe - western,', 30),
#  ('language,', 30),
#  ('teen pregnancy,', 30),
#  ('alternate universe - dark,', 30),
#  ('wish fulfillment,', 30),
#  ('consensual kink,', 30),
#  ('mental breakdown,', 30),
#  ('post-finale,', 30),
#  ('body worship,', 30),
#  ('alternate universe - mob,', 30),
#  ('meta,', 30),
#  ('deception,', 30),
#  ('madness,', 30),
#  ('song lyrics,', 30),
#  ('alternate universe - victorian,', 30),
#  ('alternate universe - westeros,', 30),
#  ('extramarital affairs,', 30),
#  ('lies,', 30),
#  ('dorks in love,', 30),
#  ('self-indulgent,', 30),
#  ('fun,', 30),
#  ('bickering,', 30),
#  ('the prince that was promised,', 30),
#  ("canon divergence - robert's rebellion,", 30),
#  ('jonsa summer challenge,', 30),
#  ('targaryen incest,', 30),
#  ('season/series 08 spoilers,', 30),
#  ('foreplay,', 29),
#  ('canon gay relationship,', 29),
#  ('barebacking,', 29),
#  ('knotting,', 29),
#  ('trust issues,', 29),
#  ('courtship,', 29),
#  ('car sex,', 29),
#  ('bromance,', 29),
#  ('polygamy,', 29),
#  ('rescue,', 29),
#  ('house greyjoy,', 29),
#  ('slut shaming,', 29),
#  ('winter is coming,', 29),
#  ('music,', 29),
#  ('pirates,', 29),
#  ('escape,', 29),
#  ('execution,', 29),
#  ('starklings,', 29),
#  ('past violence,', 29),
#  ('i guess,', 29),
#  ('lemon,', 29),
#  ('adventure & romance,', 29),
#  ('older arya,', 29),
#  ('pov sandor,', 29),
#  ('episode: s08e03 the long night,', 29),
#  ("the night's watch,", 28),
#  ('zombies,', 28),
#  ('canon gay character,', 28),
#  ('religious imagery & symbolism,', 28),
#  ('ot3,', 28),
#  ('misogyny,', 28),
#  ('enemies to friends,', 28),
#  ('non-linear narrative,', 28),
#  ('so much fluff,', 28),
#  ('modern setting,', 28),
#  ('anal,', 28),
#  ('drunken confessions,', 28),
#  ('implied/referenced domestic violence,', 28),
#  ('tenderness,', 28),
#  ('alternate universe - modern with magic,', 28),
#  ('teen romance,', 28),
#  ('childhood trauma,', 28),
#  ('blood kink,', 28),
#  ('smoking,', 28),
#  ('first dates,', 28),
#  ('king robb,', 28),
#  ('forced orgasm,', 28),
#  ('public humiliation,', 28),
#  ('self-hatred,', 28),
#  ('alternate universe - pre-canon,', 28),
#  ('worldbuilding,', 28),
#  ('episode: s08e04 the last of the starks,', 28),
#  ('feelings realization,', 28),
#  ('post-season 7,', 28),
#  ('episode fix-it,', 28),
#  ('jonsa drabble fest,', 28),
#  ('post-battle of winterfell,', 28),
#  ('somali only,', 27),
#  ('character development,', 27),
#  ('queen arya,', 27),
#  ('the wall - freeform,', 27),
#  ('animal death,', 27),
#  ('homophobic language,', 27),
#  ('silly,', 27),
#  ('show canon,', 27),
#  ('you have been warned,', 27),
#  ('bechdel test pass,', 27),
#  ('huddling for warmth,', 27),
#  ('castle black,', 27),
#  ('implied jaime lannister/brienne of tarth,', 27),
#  ('stark family feels,', 27),
#  ('princes & princesses,', 27),
#  ('my first work in this fandom,', 27),
#  ('hope,', 27),
#  ('mostly fluff,', 27),
#  ('hate to love,', 27),
#  ('gratuitous smut,', 27),
#  ("additional warnings in author's note,", 27),
#  ('battle of winterfell,', 27),
#  ('embedded video,', 26),
#  ('verbal abuse,', 26),
#  ('prequel,', 26),
#  ('male slash,', 26),
#  ('fanfiction,', 26),
#  ('tower of joy,', 26),
#  ('therapy,', 26),
#  ('domestic,', 26),
#  ('5 times,', 26),
#  ('imprisonment,', 26),
#  ('sexting,', 26),
#  ('blind date,', 26),
#  ('survivor guilt,', 26),
#  ('post canon,', 26),
#  ('post - red wedding,', 26),
#  ('political marriage,', 26),
#  ('talking,', 26),
#  ('implied/referenced sexual assault,', 26),
#  ('uncle/niece incest,', 26),
#  ('plot twists,', 26),
#  ('not a fix-it,', 26),
#  ('implied/referenced alcohol abuse/alcoholism,', 26),
#  ('loss of parent(s),', 26),
#  ('why did i write this?,', 26),
#  ('trust,', 26),
#  ('everyone is alive,', 26),
#  ('family reunions,', 26),
#  ('king rhaegar,', 26),
#  ('self-insert,', 26),
#  ('post-war for the dawn,', 26),
#  ('post battle of winterfell,', 26),
#  ('sexual assault,', 25),
#  ('speculation,', 25),
#  ('kink,', 25),
#  ('brotherly love,', 25),
#  ('godswood,', 25),
#  ('affairs,', 25),
#  ('brothers,', 25),
#  ('alternate universe - werewolf,', 25),
#  ('amnesia,', 25),
#  ('triggers,', 25),
#  ('ficlet collection,', 25),
#  ('blindfolds,', 25),
#  ('triple drabble,', 25),
#  ('morning sex,', 25),
#  ('survival,', 25),
#  ('divorce,', 25),
#  ...]

# %% [markdown]
# #### Additional Tags

# %%
#seasons 1 and 2 – season 3 starts March 2013
got1_2AT = TagsAnalyzer(got_all,'2006-08','2013-02','additional tags')
print('\n Seasons 1 and 2')
print(got1_2AT)

#seasons 3 and 4 – season 5 starts April 2015
got3_4AT = TagsAnalyzer(got_all,'2013-03','2015-03','additional tags')
print('\n Seasons 3 and 4')
print(got3_4AT)

#seasons 5 and 6 – season 7 starts July 2017
got5_6AT = TagsAnalyzer(got_all,'2015-07','2017-06','additional tags')
print('\n Seasons 5 and 6')
print(got5_6AT)

#season 7 – seasons 8 starts April 2019
got7AT = TagsAnalyzer(got_all,'2017-07','2019-03','additional tags')
print('\n Season 7')
print(got7AT)

#season 7 – seasons 8 starts April 2019
got8AT = TagsAnalyzer(got_all,'2019-04','2019-09','additional tags')
print('\n Season 8')
print(got8AT)
# Out:
# /Users/caramessina/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  Seasons 1 and 2
# [('no english,', 108), ('angst,', 96), ('alternate universe - modern setting,', 95), ('alternate universe,', 91), ('somali,', 85), ('romance,', 67), ('sibling incest,', 56), ('alternate universe - canon divergence,', 50), ('sexual content,', 50), ('fluff,', 47), ('future fic,', 44), ('first time,', 36), ('incest,', 31), ('family,', 31), ('crossover,', 30), ('friendship,', 30), ('alternate universe - canon,', 29), ('oral sex,', 27), ('hurt/comfort,', 26), ('drabble,', 26), ('cunnilingus,', 26), ('somali only,', 24), ('half-sibling incest,', 24), ('au,', 23), ('dubious consent,', 22), ('pre-canon,', 20), ('pov female character,', 20), ('blow jobs,', 18), ('slash,', 18), ('arranged marriage,', 18), ('masturbation,', 16), ('unrequited love,', 15), ('character study,', 15), ('drama,', 15), ('canon compliant,', 15), ('canonical character death,', 14), ('first kiss,', 14), ('kink meme,', 14), ('personal,', 14), ('love,', 14), ('dirty talk,', 14), ('prompt fic,', 14), ('unresolved sexual tension,', 13), ('smut,', 13), ('personal use,', 13), ('hand jobs,', 13), ("don't copy to another site,", 13), ('fluff and angst,', 13), ('action/adventure,', 12), ('pregnancy,', 12), ('explicit sexual content,', 12), ('preseries,', 12), ('friendship/love,', 11), ('alternate canon,', 11), ('violence,', 11), ('humor,', 11), ('established relationship,', 11), ('crack,', 11), ('kissing,', 11), ("robert's rebellion,", 10), ('one shot,', 10), ('spoilers,', 10), ('asoiaf kink meme,', 10), ('falling in love,', 10), ('ficlet,', 10), ('alternate universe - fantasy,', 10), ('gen fic,', 9), ('older man/younger woman,', 9), ('canon - tv,', 9), ('canon het relationship,', 9), ('canon gay relationship,', 9), ('alternate universe - high school,', 9), ('voyeurism,', 9), ('infidelity,', 8), ('alternate universe - fusion,', 8), ('rough sex,', 8), ('pre-series,', 8), ('fanvids,', 8), ('pov second person,', 8), ('age difference,', 8), ('siblings,', 8), ('character death,', 8), ('adwd spoilers,', 8), ('mild sexual content,', 8), ('femslash,', 7), ('female protagonist,', 7), ('twincest,', 7), ('spanking,', 7), ('wordcount: 100-1.000,', 7), ('canon - book,', 7), ('het,', 7), ('pov third person,', 7), ('threesome - f/f/m,', 7), ('pov male character,', 7), ('canon gay character,', 7), ('threesome - f/m/m,', 7), ('plot what plot,', 7), ('secret relationship,', 7), ('sexual tension,', 7), ('alternate universe - historical,', 7)]
#
#  Seasons 3 and 4
# [('alternate universe - modern setting,', 980), ('alternate universe - canon divergence,', 397), ('fluff,', 356), ('angst,', 354), ('alternate universe,', 268), ('romance,', 220), ('sexual content,', 146), ('oral sex,', 141), ('sibling incest,', 119), ('au,', 114), ('smut,', 114), ('first time,', 102), ('hurt/comfort,', 102), ('future fic,', 101), ('violence,', 98), ('one shot,', 95), ('explicit sexual content,', 94), ('fluff and angst,', 92), ('alternate universe - college/university,', 91), ('humor,', 89), ('anal sex,', 89), ('incest,', 85), ('alternate universe - high school,', 85), ('masturbation,', 81), ('character death,', 79), ('family,', 79), ('crossover,', 77), ('friendship,', 75), ('arranged marriage,', 70), ('plot what plot/porn without plot,', 70), ('dubious consent,', 70), ('asoiaf kink meme,', 70), ('crack,', 67), ('drabble,', 66), ('modern au,', 64), ('r plus l equals j,', 63), ('older man/younger woman,', 62), ('fluff and smut,', 62), ('torture,', 61), ('slow burn,', 59), ('drama,', 58), ('ramsay is his own warning,', 55), ('post - a dance with dragons,', 55), ('half-sibling incest,', 54), ('canon-typical violence,', 53), ('sansan,', 51), ('love,', 51), ('first kiss,', 50), ('unresolved sexual tension,', 50), ('house stark,', 50), ('jealousy,', 48), ('alternate universe - game of thrones fusion,', 48), ('abuse,', 47), ('murder,', 47), ('cunnilingus,', 46), ('rough sex,', 46), ('death,', 45), ('kissing,', 44), ('rape/non-con elements,', 44), ('established relationship,', 43), ('canon compliant,', 43), ('war,', 43), ('friends to lovers,', 43), ('pre-a game of thrones,', 42), ('prompt fill,', 39), ('spanking,', 38), ('slow build,', 38), ('other additional tags to be added,', 38), ('emotional hurt/comfort,', 37), ('dirty talk,', 37), ('post-traumatic stress disorder - ptsd,', 37), ('sex,', 36), ('rape,', 36), ('alternate universe - future,', 36), ('blow jobs,', 35), ('stockholm syndrome,', 35), ('canonical character death,', 35), ('sexual tension,', 35), ('friendship/love,', 34), ('loss of virginity,', 34), ('pre-canon,', 33), ('hand jobs,', 33), ('revenge,', 33), ('blood,', 32), ('explicit language,', 32), ('queen sansa,', 32), ('marriage,', 32), ('pwp,', 31), ('falling in love,', 31), ('grief/mourning,', 31), ('femslash,', 30), ('winterfell,', 30), ('fluff and crack,', 30), ('house lannister,', 29), ('game of thrones - freeform,', 29), ('past abuse,', 29), ('unrequited love,', 28), ('drabble collection,', 28), ('spoilers,', 28), ('pregnancy,', 28)]
#
#  Seasons 5 and 6
# [('alternate universe - modern setting,', 1230), ('fluff,', 659), ('alternate universe - canon divergence,', 597), ('angst,', 578), ('romance,', 384), ('smut,', 363), ('alternate universe,', 280), ('r plus l equals j,', 246), ('explicit sexual content,', 220), ('hurt/comfort,', 208), ('slow burn,', 192), ('oral sex,', 190), ('fluff and angst,', 180), ('one shot,', 162), ('sexual content,', 151), ('arranged marriage,', 141), ('love,', 137), ('violence,', 133), ('family,', 132), ('fluff and smut,', 127), ('other additional tags to be added,', 122), ('ramsay is his own warning,', 120), ('humor,', 120), ('canon-typical violence,', 119), ('anal sex,', 119), ('sibling incest,', 116), ('modern au,', 113), ('drama,', 105), ('drabble,', 104), ('plot what plot/porn without plot,', 103), ('older man/younger woman,', 103), ('first time,', 100), ('cunnilingus,', 97), ('friends to lovers,', 97), ('jon snow is a targaryen,', 96), ('character death,', 95), ('cousin incest,', 94), ('au,', 94), ('alternate universe - college/university,', 92), ('emotional hurt/comfort,', 92), ('implied/referenced rape/non-con,', 91), ('incest,', 89), ('falling in love,', 87), ('explicit language,', 85), ('canon compliant,', 83), ('friendship,', 83), ('dubious consent,', 82), ('sex,', 82), ('jealousy,', 79), ('established relationship,', 78), ('angst with a happy ending,', 77), ('rape/non-con elements,', 77), ('eventual smut,', 77), ('crossover,', 73), ('masturbation,', 73), ('rough sex,', 72), ('war,', 71), ('torture,', 71), ('death,', 69), ('pregnancy,', 69), ('dragons,', 69), ('half-sibling incest,', 68), ('minor character death,', 67), ('marriage,', 66), ('dirty talk,', 66), ('future fic,', 64), ('sansan,', 63), ('modern westeros,', 63), ('crack,', 63), ('kissing,', 62), ('past abuse,', 62), ('alternate universe - high school,', 61), ('femslash,', 59), ('shameless smut,', 59), ('fluff and humor,', 57), ('happy ending,', 57), ('post-canon,', 57), ('house stark,', 56), ('spanking,', 56), ('sexual tension,', 54), ('winterfell,', 53), ('friendship/love,', 53), ('unresolved sexual tension,', 52), ('revenge,', 51), ('post-traumatic stress disorder - ptsd,', 51), ('blood,', 49), ('canonical character death,', 48), ('pov multiple,', 48), ('alternate universe - game of thrones fusion,', 48), ('loss of virginity,', 47), ('light angst,', 47), ('game of thrones references,', 46), ('alpha/beta/omega dynamics,', 46), ('modern era,', 46), ('politics,', 46), ('blow jobs,', 46), ('first kiss,', 46), ('action/adventure,', 46), ('magic,', 45), ('past rape/non-con,', 45)]
#
#  Season 7
# [('alternate universe - modern setting,', 1833), ('alternate universe - canon divergence,', 1112), ('fluff,', 1070), ('angst,', 895), ('smut,', 682), ('romance,', 582), ('alternate universe,', 449), ('slow burn,', 446), ('r plus l equals j,', 412), ('explicit sexual content,', 360), ('hurt/comfort,', 320), ('fluff and angst,', 283), ('oral sex,', 276), ('jon snow is a targaryen,', 273), ('arranged marriage,', 268), ('fluff and smut,', 256), ('cunnilingus,', 243), ('one shot,', 240), ('incest,', 237), ('canon compliant,', 223), ('sibling incest,', 208), ('modern au,', 204), ('eventual smut,', 199), ('post-canon,', 199), ('other additional tags to be added,', 197), ('plot what plot/porn without plot,', 196), ('angst with a happy ending,', 195), ('canon-typical violence,', 193), ('drabble,', 191), ('love,', 190), ('established relationship,', 186), ('jonsa,', 174), ('anal sex,', 171), ('humor,', 170), ('rough sex,', 170), ('pregnancy,', 167), ('jealousy,', 165), ('violence,', 157), ('falling in love,', 157), ('cousin incest,', 155), ('jonerys,', 152), ('emotional hurt/comfort,', 150), ('ramsay is his own warning,', 149), ('friends to lovers,', 149), ('family,', 145), ('sex,', 143), ('sexual content,', 142), ('dragons,', 141), ('mutual pining,', 141), ('drama,', 138), ('shameless smut,', 136), ('dirty talk,', 134), ('alternate universe - college/university,', 131), ('modern westeros,', 130), ('au,', 127), ('pining,', 127), ('war,', 126), ('blow jobs,', 124), ('friendship,', 123), ('character death,', 122), ('jon and sansa are not related,', 119), ('older man/younger woman,', 118), ('vaginal fingering,', 118), ('winterfell,', 116), ('light angst,', 116), ('first time,', 112), ('past abuse,', 109), ('first kiss,', 107), ('eventual romance,', 107), ('half-sibling incest,', 107), ('alternate universe - game of thrones fusion,', 106), ('implied/referenced rape/non-con,', 105), ('explicit language,', 104), ('happy ending,', 104), ('post-traumatic stress disorder - ptsd,', 103), ('kissing,', 103), ('masturbation,', 102), ('love confessions,', 101), ('alternate universe - high school,', 99), ('sexual tension,', 98), ('loss of virginity,', 95), ('game of thrones references,', 94), ('forbidden love,', 94), ('post season 7,', 94), ('crossover,', 93), ('tooth-rotting fluff,', 93), ('vaginal sex,', 91), ('sansan,', 91), ('inspired by game of thrones,', 90), ('minor character death,', 90), ('fluff and humor,', 89), ('murder,', 86), ('dubious consent,', 86), ('future fic,', 83), ('crack,', 83), ('magic,', 83), ('domestic fluff,', 82), ('angst and hurt/comfort,', 81), ('rape/non-con elements,', 81), ('dark jon snow,', 81)]
#  Season 8
# [('alternate universe - modern setting,', 980), ('alternate universe - canon divergence,', 866), ('angst,', 767), ('fluff,', 766), ('romance,', 420), ('fix-it,', 416), ('smut,', 404), ('slow burn,', 358), ('hurt/comfort,', 352), ('alternate universe,', 287), ('canon compliant,', 248), ('fluff and angst,', 243), ('angst with a happy ending,', 200), ('post-canon,', 196), ('explicit sexual content,', 190), ('fluff and smut,', 180), ('oral sex,', 172), ('one shot,', 167), ('jon snow is a targaryen,', 158), ('r plus l equals j,', 154), ('emotional hurt/comfort,', 152), ('happy ending,', 152), ('season/series 08,', 152), ('other additional tags to be added,', 147), ('canon-typical violence,', 141), ('love,', 138), ('arranged marriage,', 137), ('eventual smut,', 136), ('first time,', 134), ('friends to lovers,', 134), ('established relationship,', 131), ('mutual pining,', 130), ('character death,', 130), ('pregnancy,', 130), ('gendrya - freeform,', 127), ('family,', 119), ('modern au,', 117), ('sex,', 116), ('incest,', 113), ('humor,', 112), ('fix-it of sorts,', 111), ('dragons,', 108), ('light angst,', 104), ('shameless smut,', 103), ('pining,', 103), ('drabble,', 102), ('sibling incest,', 100), ('plot what plot/porn without plot,', 99), ('falling in love,', 98), ('anal sex,', 95), ('season 8,', 95), ('post-canon fix-it,', 95), ('friendship,', 94), ('cunnilingus,', 93), ('eventual romance,', 93), ('grief/mourning,', 91), ('jonerys,', 91), ('first kiss,', 87), ('violence,', 86), ('post-traumatic stress disorder - ptsd,', 86), ('winterfell,', 86), ('past abuse,', 85), ('spoilers,', 85), ('canonical character death,', 85), ('sexual content,', 85), ('angst and hurt/comfort,', 84), ('alternate universe - college/university,', 83), ('missing scene,', 82), ('character study,', 82), ('rough sex,', 80), ('love confessions,', 80), ('reunions,', 79), ('explicit language,', 79), ('not canon compliant,', 79), ('fluff and humor,', 77), ('idiots in love,', 77), ('kissing,', 76), ('sansa stark is queen in the north,', 76), ('jealousy,', 75), ('politics,', 74), ('war,', 73), ('drama,', 71), ('queen daenerys,', 67), ('au,', 66), ('jon snow knows something,', 66), ('porn with feelings,', 66), ('ramsay is his own warning,', 64), ('marriage,', 64), ('resurrection,', 64), ('modern westeros,', 64), ('magic,', 64), ('blow jobs,', 62), ('future fic,', 62), ('crossover,', 61), ('family feels,', 61), ('vaginal sex,', 60), ('game of thrones spoilers,', 60), ('vaginal fingering,', 60), ('domestic fluff,', 60), ('dark jon snow,', 59)]

# %%
#SEASONS 1–2
got1_2relationshipDF = pd.DataFrame(got1_2relationship, columns =['Pairing', 'Appearance']) 
got1_2relationshipDF.to_csv('data/counting_csvs/GOT/relationships/got1-2_relationships.csv')

#SEASONS 3–4
got3_4relationshipDF = pd.DataFrame(got3_4relationship, columns =['Pairing', 'Appearance']) 
got3_4relationshipDF.to_csv('data/counting_csvs/GOT/relationships/got3-4_relationships.csv')

#SEASONS 5–6
got5_6relationshipDF = pd.DataFrame(got5_6relationship, columns =['Pairing', 'Appearance']) 
got5_6relationshipDF.to_csv('data/counting_csvs/GOT/relationships/got5-6_relationships.csv')

#SEASON 7
got7relationshipDF = pd.DataFrame(got7relationship, columns =['Pairing', 'Appearance']) 
got7relationshipDF.to_csv('data/counting_csvs/GOT/relationships/got7_relationships.csv')

#SEASON 8
got8relationshipDF = pd.DataFrame(got8relationship, columns =['Pairing', 'Appearance']) 
got8relationshipDF.to_csv('data/counting_csvs/GOT/relationships/got8_relationships.csv')

# %% [markdown]
# #### Category (sexual pairing)

# %%
#seasons 1 and 2 – season 3 starts March 2013
got1_2cat = TagsAnalyzer(got_all,'2006-08','2013-02','category')
print('\n Seasons 1 and 2')
print(got1_2cat)

#seasons 3 and 4 – season 5 starts April 2015
got3_4cat = TagsAnalyzer(got_all,'2013-03','2015-03','category')
print('\n Seasons 3 and 4')
print(got3_4cat)

#seasons 5 and 6 – season 7 starts July 2017
got5_6cat = TagsAnalyzer(got_all,'2015-07','2017-06','category')
print('\n Seasons 5 and 6')
print(got5_6cat)

#season 7 – seasons 8 starts April 2019
got7cat = TagsAnalyzer(got_all,'2017-07','2019-03','category')
print('\n Season 7')
print(got7cat)

#season 7 – seasons 8 starts April 2019
got8cat = TagsAnalyzer(got_all,'2019-04','2019-09','category')
print('\n Season 8')
print(got8cat)
# Out:
# /Users/caramessina/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  Seasons 1 and 2
# [('f/m,', 808), ('m/m,', 316), ('gen,', 282), ('f/f,', 68), ('multi,', 65), ('other,', 10)]
#
#  Seasons 3 and 4
# [('f/m,', 2920), ('m/m,', 1127), ('gen,', 1020), ('f/f,', 424), ('multi,', 286), ('other,', 87)]
#
#  Seasons 5 and 6
# [('f/m,', 4189), ('m/m,', 1096), ('gen,', 893), ('f/f,', 591), ('multi,', 411), ('other,', 124)]
#
#  Season 7
# [('f/m,', 7216), ('m/m,', 1234), ('gen,', 1096), ('f/f,', 865), ('multi,', 600), ('other,', 183)]
#
#  Season 8
# [('f/m,', 5205), ('gen,', 845), ('m/m,', 764), ('f/f,', 579), ('multi,', 373), ('other,', 158)]

# %% [markdown]
# ## Visualizations and Analytics
#
# For the first portion, I have to take the tuples I made above to then transform them into dataframes so that they may be analyzed. First, I will do the categories for both GoT and TLoK.

# %%
def tuple_to_df(tup, column_name_seasons, column_name_data):
    '''
    Description: Takes a list of tupples and turns it into a dataframe
    
    Input: A list of tupples, like the ones created above and a new column name based on the "Season" or whatever data
    Output: A dataframe with a the c
    '''
    newdf = pd.DataFrame(list(tup))
    newdf[column_name_seasons] = newdf[1]
    newdf[column_name_data] = newdf[0]
    finalDF= newdf[[column_name_seasons,column_name_data]]
    return finalDF

# %%
#TAKING THE RELATIONSHIP CATEGORY TUPLE AND MAKING IT A MERGED DATAFRAME
gotcat1 = tuple_to_df(got1_2cat, "Seasons 1 and 2", 'pairings')
gotcat2 = tuple_to_df(got3_4cat, "Seasons 3 and 4", 'pairings')
gotcat3 = tuple_to_df(got5_6cat, "Seasons 5 and 6", 'pairings')
gotcat4 = tuple_to_df(got7cat, "Season 7", 'pairings')
gotcat5 = tuple_to_df(got8cat, "Season 8", 'pairings')

#MERGING
gotcat_all = gotcat1.merge(gotcat2)
gotcat_all = gotcat_all.merge(gotcat3)
gotcat_all = gotcat_all.merge(gotcat4)
gotcat_all = gotcat_all.merge(gotcat5)

#REPLACING 
gotcat_all = gotcat_all.replace('f/m,','F/M').replace('gen,','GEN').replace('f/f,','F/F').replace('m/m,','M/M').replace('multi,','MULTI').replace('other,','OTHER')
gotcat_all
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-211096a197f0> in <module>
#       1 #TAKING THE RELATIONSHIP CATEGORY TUPLE AND MAKING IT A MERGED DATAFRAME
# ----> 2 gotcat1 = tuple_to_df(got1_2cat, "Seasons 1 and 2", 'pairings')
#       3 gotcat2 = tuple_to_df(got3_4cat, "Seasons 3 and 4", 'pairings')
#       4 gotcat3 = tuple_to_df(got5_6cat, "Seasons 5 and 6", 'pairings')
#       5 gotcat4 = tuple_to_df(got7cat, "Season 7", 'pairings')
#
# NameError: name 'got1_2cat' is not defined

# %%
#TAKING THE RELATIONSHIP CATEGORY TUPLE AND MAKING IT A MERGED DATAFRAME
korracat1 = tuple_to_df(korra_preKAcat, "Pre-Korrasami", 'pairings')
korracat2 = tuple_to_df(korra_subKAcat, "Subtext Korrasami", 'pairings')
korracat3 = tuple_to_df(korra_postKAcat, "Post Korrasami", 'pairings')

#MERGING
korracat_all = korracat1.merge(korracat2)
korracat_all = korracat_all.merge(korracat3)

#REPLACING PAIRING TITLES
korracat_all = korracat_all.replace('f/m,','F/M').replace('gen,','GEN').replace('f/f,','F/F').replace('m/m,','M/M').replace('multi,','MULTI').replace('other,','OTHER')
korracat_all
# Out:
#    Pre-Korrasami pairings  Subtext Korrasami  Post Korrasami
# 0      40.959041      F/M          23.746702       20.164609
# 1      30.819181      GEN          22.427441       14.238683
# 2      12.137862      M/M           6.596306        4.938272
# 3       9.990010      F/F          43.007916       55.596708
# 4       4.545455    MULTI           2.638522        3.415638
# 5       1.548452    OTHER           1.583113        1.646091

# %%
fig = go.Figure(data=[
    go.Bar(name='Seasons 1 and 2', x=gotcat_all['pairings'], y=gotcat_all['Seasons 1 and 2']),
    go.Bar(name='Seasons 3 and 4', x=gotcat_all['pairings'], y=gotcat_all['Seasons 3 and 4']),
    go.Bar(name='Seasons 5 and 6', x=gotcat_all['pairings'], y=gotcat_all['Seasons 5 and 6']),
    go.Bar(name='Season 7', x=gotcat_all['pairings'], y=gotcat_all['Season 7']),
    go.Bar(name='Season 8', x=gotcat_all['pairings'], y=gotcat_all['Season 8'])
])

fig.update_layout(barmode='group')

figTLOK.update_layout(
    title='Game of Thrones Romantic Pairing Trends'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-6c64f6892c9b> in <module>
#       1 fig = go.Figure(data=[
# ----> 2     go.Bar(name='Seasons 1 and 2', x=gotcat_all['pairings'], y=gotcat_all['Seasons 1 and 2']),
#       3     go.Bar(name='Seasons 3 and 4', x=gotcat_all['pairings'], y=gotcat_all['Seasons 3 and 4']),
#       4     go.Bar(name='Seasons 5 and 6', x=gotcat_all['pairings'], y=gotcat_all['Seasons 5 and 6']),
#       5     go.Bar(name='Season 7', x=gotcat_all['pairings'], y=gotcat_all['Season 7']),
#
# NameError: name 'gotcat_all' is not defined

# %%
figGOT = go.Figure(data=[
    go.Bar(name='Seasons 1 and 2', x=gotcat_all['pairings'], y=gotcat_all['Seasons 1 and 2'], marker_color='#C0C0C0'),
    go.Bar(name='Seasons 3 and 4', x=gotcat_all['pairings'], y=gotcat_all['Seasons 3 and 4'], marker_color='#808080'),
    go.Bar(name='Seasons 5 and 6', x=gotcat_all['pairings'], y=gotcat_all['Seasons 5 and 6'], marker_color='#585858'),
    go.Bar(name='Season 7', x=gotcat_all['pairings'], y=gotcat_all['Season 7'], marker_color='#383838'),
    go.Bar(name='Season 8', x=gotcat_all['pairings'], y=gotcat_all['Season 8'], marker_color='#181818')
])

figGOT.update_layout(barmode='group')

figGOT.update_layout(
    title='Game of Thrones Romantic Pairing Trends', plot_bgcolor='#ffffff'
)


figGOT.write_html('images/GoT-Romantic-Pairings.html', auto_open=True)

# %%
figGOT = make_subplots(
    rows=2, cols=3,
    shared_yaxes=True,
    shared_xaxes=True,
    subplot_titles=("Seasons 1–2", "Seasons 3–4", "Seasons 5–6", "Season 7", "Season 8 and Beyond"))

figGOT.add_trace(go.Bar(
    y=gotcat1[1], 
    x=gotcat1[0], 
    name="Seasons 1–2"), 
    row=1, 
    col=1)

figGOT.add_trace(go.Bar(y=gotcat2[1], x=gotcat2[0], name="Seasons 3–4"), row=1, col=2)
figGOT.add_trace(go.Bar(y=gotcat3[1], x=gotcat3[0], name="Seasons 5–6"), row=1, col=3)
figGOT.add_trace(go.Bar(y=gotcat4[1], x=gotcat4[0], name="Seasons 7"), row=2, col=1)
figGOT.add_trace(go.Bar(y=gotcat5[1], x=gotcat5[0], name="Seasons 8"), row=2, col=2)

figGOT.update_layout(
    title='Game of Thrones Romantic Pairing Trends'
)

figGOT.update_xaxes(ticks="inside")

figGOT.write_html('images/GoT-Romantic-Pairings.html', auto_open=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-fac7a98b823c> in <module>
#       6
#       7 figGOT.add_trace(go.Bar(
# ----> 8     y=gotcat1[1],
#       9     x=gotcat1[0],
#      10     name="Seasons 1–2"),
#
# NameError: name 'gotcat1' is not defined

# %% [markdown]
# ### The Legend of Korra Visualizations

# %%
korra_rel_fig = go.Figure(data=[
    go.Bar(name='Pre-Korrasami (2011–05/2014)', x=korra_preKAdf['Pairing'][:5], y=korra_preKAdf['Appearance'],marker_color='#C0C0C0'),
    go.Bar(name='Subtext Korrasami (06/2014–11/2014)', x=korra_subKAdf['Pairing'][:5], y=korra_subKAdf['Appearance'], marker_color='#585858'),
    go.Bar(name='Post Korrasami (12/2014–07/2015)', x=korra_postKA['Pairing'][:5], y=korra_postKA['Appearance'], marker_color='#181818')
])

#I don't like this one cause it's only the top 5 and the top five changes quite frequently

korra_rel_fig.update_layout(barmode='group',)

korra_rel_fig.update_layout(
    title='The Legend of Korra Romantic Pairing Trends', plot_bgcolor='#ffffff'
)

korra_rel_fig.write_html('images/TLoK-Romantic-Pairings.html', auto_open=True)

# %%
Korra_fig = go.Figure(data=[
    go.Bar(name='Pre-Korrasami (2011–05/2014)', x=korracat_all['pairings'], y=korracat_all['Pre-Korrasami'],marker_color='#C0C0C0'),
    go.Bar(name='Subtext Korrasami (06/2014–11/2014)', x=korracat_all['pairings'], y=korracat_all['Subtext Korrasami'], marker_color='#585858'),
    go.Bar(name='Post Korrasami (12/2014–07/2015)', x=korracat_all['pairings'], y=korracat_all['Post Korrasami'], marker_color='#181818')
])

Korra_fig.update_layout(barmode='group',)

Korra_fig.update_layout(
    title='The Legend of Korra Romantic Pairing Trends', plot_bgcolor='#ffffff'
)


Korra_fig.write_html('images/TLoK-Romantic-Pairings.html', auto_open=True)

# %%
figTLOK = make_subplots(
    rows=1, cols=3,
    shared_yaxes=True,
    shared_xaxes=True,
    subplot_titles=("Before Korrasami", "Korrasami Subtext", "Post Korrasami"))

figTLOK.add_trace(go.Bar(
    y=korracat1[1], 
    x=korracat1[0], 
    name='Up To July 2014'), 
              row=1, 
              col=1)

figTLOK.add_trace(go.Bar(y=korracat2[1], x=korracat2[0], name='August–November 2014'), row=1, col=2)

figTLOK.add_trace(go.Bar(y=korracat3[1], x=korracat3[0], name='December 2014 and Beyond'), row=1, col=3)

figTLOK.update_layout(
    title='The Legend of Korra Romantic Pairing Trends'
)

figTLOK.write_html('images/TLoK-Romantic-Pairings.html', auto_open=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-76b70c5afcc2> in <module>
#       6
#       7 figTLOK.add_trace(go.Bar(
# ----> 8     y=korracat1[1],
#       9     x=korracat1[0],
#      10     name='Up To July 2014'),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
