# %% [markdown]
# # Data Analytics: Exploring Specific Tags
#
# Cara Marta Messina <br/>
# Northeastern University<br/>
# messina [dot] c [at] husky [dot] neu [dot] edu
#
# This notebook takes data collected from <em>Archive of Our Own</em>, a popular fanfiction repository, and sets it up to be analyzed. The data was collected using [this AO3 python scraper](https://github.com/radiolarian/AO3Scraper). The corpus consists of <em>The Legend of Korra</em> and <em>Game of Thrones</em> fanfics, from the first one published on AO3 to 2019.
#
# <em>This notebook is part of the Critical Fan Toolkit, Cara Marta Messina's public + digital dissertation</em>

# %%
#pandas for working with dataframes
import pandas as pd

#regular expression library
import re

#numpy specifically works with numbers
import numpy as np

from nltk import word_tokenize

import string
punctuations = list(string.punctuation)

#has the nice counter feature for counting tags
import collections
from collections import Counter 

#for making a string of elements separated by commas into a list
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktLanguageVars 

#visualizations
#import plotly as py
#import plotly.express as px
#import plotly.graph_objs as go
#from plotly.subplots import make_subplots

#calling my plotly thing
#import chart_studio
#chart_studio.tools.set_credentials_file(username='caramessina', api_key='IdA4LjtaqYKmFJnfS8Uv')

# %% [markdown]
# ## Reading and Prepping the Data

# %%
korra_all = pd.read_csv('./data/allkorra.csv')
korra_all.head(3)
# Out:
#    Unnamed: 0   work_id                 title                 rating category  \
# 0           0   6388009  A More Perfect Union      General Audiences      Gen
# 1           1  13974048                let go  Teen And Up Audiences      F/F
# 2           2  13720947     Is This Your Dog?      General Audiences      F/F
#
#                     fandom       relationship  \
# 0  Avatar: Legend of Korra                NaN
# 1  Avatar: Legend of Korra  Lin Beifong/Korra
# 2  Avatar: Legend of Korra   Korra/Asami Sato
#
#                                            character  \
# 0   Noatak (Avatar), Tarrlok (Avatar), Amon (Avatar)
# 1                        Korra (Avatar), Lin Beifong
# 2  Korra (Avatar), Asami Sato, Tonraq (Avatar), M...
#
#                                      additional tags language  ...     status  \
# 0                                 Alternate Universe  English  ...    Updated
# 1  just a quick one-shot i never posted properly,...  English  ...  Completed
# 2  Alternate Universe - College/University, Alter...  English  ...    Updated
#
#   status date words  chapters comments  kudos  bookmarks    hits  \
# 0  2018-03-14  8139       4/?     11.0   27.0        4.0   286.0
# 1  2018-03-14   996       1/1      NaN    NaN        NaN    41.0
# 2  2018-03-14  7585       5/?    111.0  318.0       18.0  3637.0
#
#                                                 body    month
# 0  He's forgotten how to be warm. The thought wou...  2016-03
# 1  "Korra." Somewhere distant.  Someone holding h...  2018-03
# 2  Korra's father kneeled down in front of her so...  2018-02
#
# [3 rows x 21 columns]

# %%
#reading in multiple csv files, since one large one breaks my kernels 

got0 = pd.read_csv(r'./data/got_data_clean/got0.csv')
got1 = pd.read_csv(r'./data/got_data_clean/got1.csv')
got2 = pd.read_csv(r'./data/got_data_clean/got2.csv')
got3 = pd.read_csv(r'./data/got_data_clean/got3.csv')

merged_got = pd.concat([got0, got1, got2, got3])
merged_got.head(3)
# Out:
#    Unnamed: 0   work_id              title   published  \
# 0           0  19289563  game of thrones,   2019-06-20
# 1           1  17179712  game of thrones,   2018-12-27
# 2           2   2352779  game of thrones,   2014-09-24
#
#                     rating                                          character  \
# 0               explicit,   arya stark, bella, gendry baratheon - characte...
# 1  teen and up audiences,   jon snow | aegon targaryen, arya stark, sansa ...
# 2  teen and up audiences,                                                 NaN
#
#                                         relationship  \
# 0  gendry baratheon/arya stark, gendry baratheon/...
# 1  jon snow/daenerys targaryen, arya stark/gendry...
# 2                              xander harris/spike,
#
#                                      additional tags category  \
# 0                                                NaN  multi,
# 1  armies and allies, war, romance, eventual happ...    f/m,
# 2                established relationship, drabble,     m/m,
#
#                                                 body    month
# 0  authors note: this is really short but i promi...  2019-06
# 1  arya's chambers still felt different.\n\n \n\n...  2018-12
# 2  "it's asking again". \n\n"then press the blood...  2014-09

# %%
merged_got.count()
# Out:
# Unnamed: 0         29897
# work_id            29897
# title              29897
# published          29897
# rating             29896
# character          28913
# relationship       27733
# additional tags    27118
# category           28472
# body               29897
# month              29897
# dtype: int64

# %% [markdown]
# ## Creating the Functions: Extracting Metadata
#
# created a function that will take the different tags (which are phrased as characterA/characterB, characterA/characterB, etc in the data) and count the most common relationships to then output it as the most common relationship tags used.

# %%
def column_to_list(df,columnName):
    '''
    this function takes all the information from a specific column, joins it to a string, and then tokenizes & cleans that string.
    input: the name of the dataframe and the column name
    output: the tokenized list of the text with all lower case, punctuation removed, and no stop words
    '''
    df[columnName] = df[columnName].replace(np.nan,'',regex=True) 
    string = ' '.join(df[columnName].tolist())
    return string

# %%
def clean_tokens(string):    
    stopwords = ['i', 'me', 'my', 'myself', "“", "”", 'we', 'our', '’', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", "would", "could", 'won', "won't", 'wouldn', "wouldn't"]
    text_lc = [word.lower() for word in string]
    text_tokens_clean = [word for word in text_lc if word not in stopwords]
    text_tokens_clean = [word for word in text_tokens_clean if word not in punctuations]
    return text_tokens_clean
    print(text_tokens_clean[:20])

# %%
def TagsAnalyzer(df, columnName):
    '''
    input: the index month+year, such as '2012-04', and the specific metadata, such as 'additional tags'
    output: a tupple of the count of tags in a specific month/year
    
    load in the proper data into a string'''
    
    #replace empty values & make a list of all the words
    string = column_to_list(df, columnName)
    
    #the function to tokenize, or put each value as an element in a list
    class CommaPoint(PunktLanguageVars):
        sent_end_chars = (',') 
    tokenizer = PunktSentenceTokenizer(lang_vars = CommaPoint())
    
    #tokenizing the list of strings based on the COMMA, not the white space (as seen in the CommaPoint above)
    ListOfTags = tokenizer.tokenize(string)
    
    #the "Counter" function is from the collections library
    allCounter=collections.Counter(ListOfTags)
    
    li = []
    #returning a dictionary in which the keys are all the tags, and the items are the counts
    for word0,word1 in allCounter.most_common(300):
        li.append((word0, (word1/length)*100))

#     #return
    return li

# %%
def extract_tags(dictionary,search_term,count):
    '''
    input: a dictionary to be searched, the term you want to search, and the total number of tags or whatever you count
    output: all the items in which your specific term appears and the ratio of times each one appears
    '''
    for tag, number in dictionary.items():    # for name, age in dictionary.iteritems():  (for Python 2.x)
        if search_term in tag:
            print(tag, number, (number/count)*100)

# %% [markdown]
# ## The Legend of Korra: Exploring Additional Tags
#
# I've already done some of this work, but I want to add more potential writers to the list. What is really interesting about these tags, though, is there are many less of them. I wonder, because Korra/Asami is the "norm", if there needs to be a labeling of difference. For example, Korrasami/KorraxKuvira is much more used than other relationships in this fandom, so being explicitly open about its queerness isn't important. Tags don't need to be used to define race/queerness because these identities are already so embedded in both the show and the fanfics.
#
# For example, feminism and pointing to feminism does <em>not</em> really happen.
#
# ### Race
# - canon character of color
# - male character of color
# - character of color
# - lgbtq female characters of color
# - 'of color' is a tag to look at
#
# ### Queer/Lesbian/Gay/Gender
# - socially awkward queer girls
# - genderqueer korra
# - okay it would be smut but i started writing a lesbian adventure romcom
# - kya being a horribly flirtatious lesbian
# - nonbinary lesbians
# - gaycation all i ever wanted
# - everyone's gay/everyone is gay
# - idk how else to describe this but gay gay gay
# - older gays giving advice to younger gays
# - drag queen/drag queens
# - trans
# - trans female character
# - trans characters
# - trans!korraxasami
# - pre-transition
# - for trans!korra to help dysphoria the other way around
# - genderqueer
# - gender dysphoria/euphoria
# - gender queer characters

# %%
tlok_AT_count = korra_all['additional tags'].str.len().sum()

# %%
#All of the Additional Tags used in the Game of Thrones fandom
tlok_AT = TagsAnalyzer(korra_all,'additional tags')

# %%
extract_tags(tlok_AT,'color',tlok_AT_count)
extract_tags(tlok_AT,'race',tlok_AT_count) #...master race?
extract_tags(tlok_AT,'queer',tlok_AT_count)
extract_tags(tlok_AT,'lesbian',tlok_AT_count)
extract_tags(tlok_AT,'gay',tlok_AT_count)
extract_tags(tlok_AT,'drag',tlok_AT_count)
extract_tags(tlok_AT,'bisex',tlok_AT_count)
extract_tags(tlok_AT,'trans',tlok_AT_count)
extract_tags(tlok_AT,'feminis',tlok_AT_count) #less feminist tags coming up–FASCINATING
extract_tags(tlok_AT,'gender',tlok_AT_count)
# Out:
# seeing your soul mate makes you see in color, 1 0.00019161823515773054
# Waterbending master race, 2 0.00038323647031546107
# water tribe master race, 1 0.00019161823515773054
# Watertribe master race Mako - Freeform, 1 0.00019161823515773054
# Korracentric howrra, 1 0.00019161823515773054
# Korracentric  Embarrassment, 1 0.00019161823515773054
# Katara the queer uniter, 1 0.00019161823515773054
# useless queers, 1 0.00019161823515773054
# useless queers Yuri, 1 0.00019161823515773054
# queer  Alternate Universe - Canon Divergence, 1 0.00019161823515773054
# queer, 4 0.0007664729406309221
# Genderqueer, 5 0.0009580911757886527
# Genderqueer Korra, 2 0.00038323647031546107
# other queer characters, 1 0.00019161823515773054
# Surfing AU Genderqueer Korra, 1 0.00019161823515773054
# Genderqueer bolin Red Lotus Korra, 1 0.00019161823515773054
# gender queer character, 1 0.00019161823515773054
# queer dorks, 1 0.00019161823515773054
# Genderqueer Character Pre-Canon, 1 0.00019161823515773054
# Genderqueer Character  Fluff, 1 0.00019161823515773054
# Genderqueer Character Canon Queer Character, 1 0.00019161823515773054
# Genderqueer Character, 3 0.0005748547054731917
# Season 3 Finale Alternate Universe - Modern Setting Genderqueer, 1 0.00019161823515773054
# Science Fiction  Genderqueer, 1 0.00019161823515773054
# okay it WOULD be smut but i started writing a lesbian adventure romcom, 1 0.00019161823515773054
# nonbinary lesbians, 1 0.00019161823515773054
# Kya being a horribly flirtatious lesbian, 1 0.00019161823515773054
# magical lesbian spawn Post-Finale, 1 0.00019161823515773054
# lesbian kinky, 1 0.00019161823515773054
# flawless lesbian queens, 1 0.00019161823515773054
# useless lesbian Korra, 1 0.00019161823515773054
# AU the only reason for this is lesbians, 1 0.00019161823515773054
# mako is an oblivious ass and bad at his job the only reason for this is lesbians Reunions, 1 0.00019161823515773054
# it's gonna be really gay, 1 0.00019161823515773054
# Transformation Older gays giving advice to younger gays, 1 0.00019161823515773054
# Game Night gays have a meet-cute, 1 0.00019161823515773054
# sort of gays being gay, 1 0.00019161823515773054
# Rimming Originally Posted on FanFiction.Net super gay, 1 0.00019161823515773054
# extremely gay, 1 0.00019161823515773054
# but oh so gay, 1 0.00019161823515773054
# gay as fuck, 1 0.00019161823515773054
# gay couples, 2 0.00038323647031546107
# One Shot gay wei, 1 0.00019161823515773054
# korra and asami are super gay together and have sex, 1 0.00019161823515773054
# Equalist Asami Sato   pretty gay, 1 0.00019161823515773054
# like really pretty gay, 1 0.00019161823515773054
# idk how else to describe this but gay gay gay, 1 0.00019161823515773054
# embarrassed gay mess Asami, 1 0.00019161823515773054
# everything you love is gay, 1 0.00019161823515773054
# its gay ok Fluff, 1 0.00019161823515773054
# so much gay, 1 0.00019161823515773054
# pure disgusting fluff soft gay, 1 0.00019161823515773054
# gay bars, 1 0.00019161823515773054
# Dubious Consent its barely kyalin they aren't together in it but they talk and its vaguely gay?? Family, 1 0.00019161823515773054
# Everyone's gay, 1 0.00019161823515773054
# a bit creepy toph - Freeform cute gay bbys, 1 0.00019161823515773054
# a single gay slur, 1 0.00019161823515773054
# my gay dorks, 1 0.00019161823515773054
# but i dragged him anyway, 1 0.00019161823515773054
# dragons make everything better Canon Disabled Character, 1 0.00019161823515773054
# kyalin dragon age au   Lesbian Sex, 1 0.00019161823515773054
# dragon - Freeform, 2 0.00038323647031546107
# avatar wanxoc  air temple island dragnet, 1 0.00019161823515773054
# Ejaculation  zuko's dragon - Freeform, 1 0.00019161823515773054
# but i'm not even sure if it warrants the tag in this context I cut this off because I felt like I was dragging it out, 1 0.00019161823515773054
# asami is a useless bisexual Original Character(s), 1 0.00019161823515773054
# bisexual korra, 2 0.00038323647031546107
# bisexual asami, 2 0.00038323647031546107
# useless bisexual vampire, 1 0.00019161823515773054
# bisexuals, 2 0.00038323647031546107
# useless bisexuals, 1 0.00019161823515773054
# bisexuality doesn't exist Book 3, 1 0.00019161823515773054
# bisexual women Alternate Universe - Canon Divergence, 1 0.00019161823515773054
# bisexual bolin, 1 0.00019161823515773054
# canon bisexual couple, 1 0.00019161823515773054
# Sokka is bisexual, 1 0.00019161823515773054
# for trans!Korra to help dysphoria the other way around, 1 0.00019161823515773054
# transphobic language, 1 0.00019161823515773054
# Friendships that transthrough lifetimes, 1 0.00019161823515773054
# not sensation transmitting, 1 0.00019161823515773054
# friendships that transcend lifetimes korrasami month 2016, 1 0.00019161823515773054
# discussion of transphobia Welcome to crossover hell pal, 1 0.00019161823515773054
# trans!Bolin, 1 0.00019161823515773054
# trans guy! Mako Spirit World Vacation, 1 0.00019161823515773054
# sensation transmitting strap-on, 1 0.00019161823515773054
# pre-transition  Smut, 1 0.00019161823515773054
# some friendships are so strong they can transcend lifetimes AU, 1 0.00019161823515773054
# Asami POV  Pangender, 1 0.00019161823515773054
# differing gender expression, 1 0.00019161823515773054
# Agender Character, 1 0.00019161823515773054
# Agender Malia Tate Smut, 1 0.00019161823515773054
# Bigender Korra Fluff, 1 0.00019161823515773054
# genderfluid pidge, 1 0.00019161823515773054
# Bigender Korra, 1 0.00019161823515773054
# gender bending, 1 0.00019161823515773054
# Transgender, 3 0.0005748547054731917
# gender queer character, 1 0.00019161823515773054
# Pangender Avatar Incest, 1 0.00019161823515773054
# Pangender Avatar    Capital Punishment, 1 0.00019161823515773054
# Bigender Character, 1 0.00019161823515773054
# Pangender Avatar Multiple other characters that don't speak in this chapter., 1 0.00019161823515773054
# Pangender Avatar Romance, 1 0.00019161823515773054

# %% [markdown]
# ## Game of Thrones: Exploring Additional Tags
#
# In order to better discover <em>Game of Thrones</em> fanfics that are thinking about race, sexuality, and gender in nuanced ways, I will first search for particular tags that are used and create a list of tags here that I will be using to then chose the particular fics I want to read.
#
# ### Race
# - female character of color
# - character of color
# - <strong>pov character of color</strong>
# - <strong>bisexual female character of color</strong>
# - <strong>canon character of color</strong>
# - <strong>canon queer character of color</strong>
# - lesbian character of color
# - lgbtq character(s) of color
# - <strong>male character of color</strong>
# - characters of color
# - lgbtq character of color
# - <strong>race relations</strong>
# - <strong>racebending</strong>
# - race
# - alternate universe - race changes
# - <strong>reference to race relations</strong>
# - different races (not interesting)
#
# ### Racism
# - fantastic racism
# - racism
# - period-typical racism
# - magical racism (not interesting)
# - racism allegory
# - just a little bit of valyrian racism
#
# ### Gender
# - gender issues
# - genderfuck
# - <strong>genderfluid character</strong>
# - gender roles
# - gender equality
# - gender confusion
# - transgender
# - gender identity
# - arya is genderqueer
# - gender neutrality
# - gender dysphoria
# - <strong>oberyn gives zero fucks about your gendered shit</strong>
# - gender-neutral pronouns
# - genderqueer jon
# - <strong>masculine presenting gender neutral jon</strong>
# - transgender teens
# - <strong>fuck gender roles</strong>
#
# ### Queer
# - queer character
# - <strong>original character is an autistic queer woman of colour</strong>
# - cersei and jaime are genderqueer
# - queer
# - queer themes
# - <strong>canon queer character of color</strong>
# - canon queer character
# - pov queer character
# - everyone is queer
# - arya is queer
# - <strong>almost everyone is queer</strong>
# - queer characters
# - queer youth
# - queer identity
# - queer friendships
# - canon queer relationship
# - queer queens
# - bisexual jaime is here and queer
# - queer daenerys
# - queer culture
# - <strong>trans character</strong>
# - transphobic language
# - canon lgbtq female character
# - <strong>jon is a trans man please stop telling me to tag this 'female jon snow'</strong>
# - jon snow is trans
# - <strong>alternate universe - trans</strong>
# - trans! margaery
# - trans!jon snow
# - <strong>trans!tywin lannister</strong>
# - trans daenerys
# - i edited it to make it trans inclusive
# - trans female character
# - <strong>trans!arya stark</strong>
# - trans loras
#
# ### Lesbian
# There are a lot of results here. I think just keeping "lesbian" and "queer" as basic search terms already pulls up what I need it to.
#
# ### Fem/Masc (and feminism)
# - <strong>feminist themes</strong>
# - female sexuality
# - female-centric
# - strong female characters
# - bisexual female character
# - trans female character
# - lack of female rights
# - <strong>calling the show out on its overuse of female nudity</strong>
# - <strong>there's not enough femslash here</strong>
# - female jon snow is also autistic
# - feminist wives everywhere
# - <strong>the idealization of violence makes for shitty feminism</strong>
# - feminism
# - <strong>my response to 'female characters can only have growth through physical pain</strong>
# - feminism. idk.
# - <strong>because fuck d&d and their offending representation of female relationships</strong>
# - <strong>au in which female characters have agency</strong>
# - <strong>tyrion lannister is a feminist icon</strong>
# - <strong>robb stark doesn't have time for your hypermasculine bullshit</strong>
# - toxic masculinity
# - <strong>tormund is my feminist</strong>
#
# ### Consent
# - <strong>explicit description of consent because that's important y'all</strong>
# - <strong>explicit consent</strong>
# - consensual non-consent
# - enthusiastic consent
# - so much consent
# - dubious consent due to identity issues
# - consentual sex
# - consenting adults
# - consent is v important folks
# - consent is sexy
# - <strong>look d&d you can't consent when you're that drunk</strong>
# - <strong>jaime has a consent kink</strong>
# - consent is sexy kids
# - but everyone consents
# - comment on consent (hmm what is this one)
#
# ### Loras
# - loras' pov
# - fem!loras
# - <strong>loras is king of coming out parties</strong>
# - pov loras tyrell
# - <strong>loras doesn't get the recognition he deserves</strong>
#
# ### Missandei/Grey Worm
# - <strong>missandei deserved better</strong>
# - <strong>bisexual missandei</strong>
# - daenerys targaryen/missandei
# - <strong>inspired by grey worm and missandei goodbye scene</strong>
# - <strong>dany's army now waiting for missandei's word</strong>
# - <strong>i haven't coped with missandei's death</strong>
# - <strong>a fix it fic because its what missandei deserves goddamnit</strong>
# - missandei is an angel
# - missandei is a precious angel who must be protected
# - daenerys and missandei have to say goodbye
# - brotp arya & missandei (instead of OTP, it's a friendship pairing)
# - <strong>grey worm deserved better</strong>
# - <strong>y'all need to write stories about the trauma grey worm is going through</strong>
#
# ### Misc
# - <strong>slavery abolition</strong>
# - non-romanticized slavery – not GOT
# - there is no canon to diverge from anymore-freedom is now (no idea what this means, but interested)

# %%
merged_got.count()
# Out:
# Unnamed: 0         29897
# work_id            29897
# title              29897
# published          29897
# rating             29896
# relationship       27733
# additional tags    29897
# category           28472
# body               29897
# month              29897
# dtype: int64

# %%
got_AT_count = merged_got['additional tags'].str.len().sum()

# %%
#All of the Additional Tags used in the Game of Thrones fandom
got_AT = TagsAnalyzer(merged_got,'additional tags')

# %%
extract_tags(got_AT,'color',got_AT_count)
extract_tags(got_AT,'race',got_AT_count)
extract_tags(got_AT,'racism',got_AT_count)
extract_tags(got_AT,'black people',got_AT_count)
extract_tags(got_AT,'gender',got_AT_count)
extract_tags(got_AT,'queer',got_AT_count)
extract_tags(got_AT,'lesbian',got_AT_count)
extract_tags(got_AT,'gay',got_AT_count)
extract_tags(got_AT,'nonbinary',got_AT_count)
extract_tags(got_AT,'genderqueer',got_AT_count)
extract_tags(got_AT,'missandei',got_AT_count)
extract_tags(got_AT,'grey worm',got_AT_count)
extract_tags(got_AT,'dothraki',got_AT_count)
extract_tags(got_AT,'khal',got_AT_count)
extract_tags(got_AT,'dysphoria',got_AT_count)
extract_tags(got_AT,'slave',got_AT_count)
extract_tags(got_AT,'drag ',got_AT_count)
extract_tags(got_AT,'abolition',got_AT_count)
extract_tags(got_AT,'freedom',got_AT_count)
extract_tags(got_AT,'revolution',got_AT_count)
extract_tags(got_AT,'rebellion',got_AT_count)
extract_tags(got_AT,"y'all",got_AT_count)
extract_tags(got_AT,"consent",got_AT_count)
extract_tags(got_AT,"trans",got_AT_count)
extract_tags(got_AT,"loras",got_AT_count)
extract_tags(got_AT,"fem",got_AT_count)
extract_tags(got_AT,"masc",got_AT_count)
extract_tags(got_AT,"feminis",got_AT_count)
extract_tags(got_AT,"heterono",got_AT_count)
extract_tags(got_AT,"autistic",got_AT_count)
# Out:
# canon character of color, 6 0.00014151741100500712
# canon queer character of color, 2 4.717247033500237e-05
# lgbtq character of color, 3 7.075870550250356e-05
# character(s) of color, 5 0.00011793117583750594
# female character of color, 11 0.000259448586842513
# pov character of color, 4 9.434494067000474e-05
# eye color, 1 2.3586235167501186e-05
# colorblind soulmate au, 1 2.3586235167501186e-05
# color of blood, 1 2.3586235167501186e-05
# rose colored glasses fic, 1 2.3586235167501186e-05
# sandor's colorful language, 1 2.3586235167501186e-05
# soulmate seeing color au, 1 2.3586235167501186e-05
# warning: sandor's colorful language, 1 2.3586235167501186e-05
# white is the color of the day, 1 2.3586235167501186e-05
# true colors, 1 2.3586235167501186e-05
# color soulmate au, 1 2.3586235167501186e-05
# seeing color au, 1 2.3586235167501186e-05
# lesbian character of color, 2 4.717247033500237e-05
# character of color, 1 2.3586235167501186e-05
# her true colors will be revealed by the end, 1 2.3586235167501186e-05
# setting: late 1800's colorado, 1 2.3586235167501186e-05
# male character of color, 1 2.3586235167501186e-05
# bisexual female character of color, 3 7.075870550250356e-05
# eye color is important, 1 2.3586235167501186e-05
# characters of color, 1 2.3586235167501186e-05
# lgbtq character(s) of color, 1 2.3586235167501186e-05
# porn with traces of plot if you really squint but i promise its not really a plot at all, 1 2.3586235167501186e-05
# d&d are a disgrace to good writing, 1 2.3586235167501186e-05
# graceful thor, 1 2.3586235167501186e-05
# embrace, 1 2.3586235167501186e-05
# reference to race relations, 1 2.3586235167501186e-05
# thisby island (the scorpio races), 1 2.3586235167501186e-05
# racebending, 1 2.3586235167501186e-05
# i accept and embrace your hate, 1 2.3586235167501186e-05
# brace yourselves, 2 4.717247033500237e-05
# public disgrace, 1 2.3586235167501186e-05
# the amazing race - freeform, 1 2.3586235167501186e-05
# in which jaime lannister comes to terms with his past and embraces his future, 1 2.3586235167501186e-05
# different races, 1 2.3586235167501186e-05
# just embrace it, 1 2.3586235167501186e-05
# racer!sansa, 1 2.3586235167501186e-05
# race to the edge, 1 2.3586235167501186e-05
# may contain traces of plot, 1 2.3586235167501186e-05
# racer!jon, 1 2.3586235167501186e-05
# race, 1 2.3586235167501186e-05
# traces of angst, 1 2.3586235167501186e-05
# canoe races, 1 2.3586235167501186e-05
# jon embraces his inner targ, 1 2.3586235167501186e-05
# brace yourself - puns are coming, 1 2.3586235167501186e-05
# jon will eventually embrace his targaryen heritage, 1 2.3586235167501186e-05
# disgrace, 1 2.3586235167501186e-05
# motorcycle races, 1 2.3586235167501186e-05
# racey, 1 2.3586235167501186e-05
# alternate universe - race changes, 2 4.717247033500237e-05
# emergency contraceptives, 1 2.3586235167501186e-05
# race relations, 1 2.3586235167501186e-05
# just a little bit of valyrian racism, 1 2.3586235167501186e-05
# implied/referenced racism, 1 2.3586235167501186e-05
# magical racism, 1 2.3586235167501186e-05
# period-typical racism, 9 0.00021227611650751068
# racism, 7 0.0001651036461725083
# definite classism and a bit of racism, 1 2.3586235167501186e-05
# fantastic racism, 3 7.075870550250356e-05
# fantasy racism, 1 2.3586235167501186e-05
# racism allegory, 1 2.3586235167501186e-05
# vague cultural racism, 1 2.3586235167501186e-05
# canon-typical racism, 1 2.3586235167501186e-05
# the only two black people on this show and no one's writing any stories about them, 1 2.3586235167501186e-05
# gender neutral venom symbiote (marvel), 2 4.717247033500237e-05
# genderbending, 45 0.0010613805825375536
# genderswap, 24 0.0005660696440200285
# genderbent asoiaf, 1 2.3586235167501186e-05
# genderswapped asoiaf, 1 2.3586235167501186e-05
# alternate universe - gender changes, 85 0.002004829989237601
# gender roles, 18 0.00042455223301502136
# gender-neutral pronouns, 4 9.434494067000474e-05
# genderfluid character, 7 0.0001651036461725083
# gender equality, 2 4.717247033500237e-05
# genderqueer character, 2 4.717247033500237e-05
# genderqueer, 2 4.717247033500237e-05
# gender confusion (on author's part), 1 2.3586235167501186e-05
# transgender, 3 7.075870550250356e-05
# gender issues, 11 0.000259448586842513
# transgender teens, 1 2.3586235167501186e-05
# gender or sex swap, 20 0.00047172470335002376
# misgendering, 2 4.717247033500237e-05
# gender disguise, 2 4.717247033500237e-05
# gender identity, 2 4.717247033500237e-05
# gender confusion, 6 0.00014151741100500712
# reader has no specific gender, 1 2.3586235167501186e-05
# genderswap all the things, 1 2.3586235167501186e-05
# gender dysphoria, 5 0.00011793117583750594
# cos the reader can change gender and sex, 1 2.3586235167501186e-05
# dfab but gender neutral reader, 1 2.3586235167501186e-05
# gender fluidity, 1 2.3586235167501186e-05
# mentions of genderbend, 1 2.3586235167501186e-05
# genderswapped character, 2 4.717247033500237e-05
# gendered insults, 1 2.3586235167501186e-05
# genderplay, 8 0.00018868988134000949
# reversed gender roles, 1 2.3586235167501186e-05
# gender role reversal, 7 0.0001651036461725083
# canon genderbending, 1 2.3586235167501186e-05
# gender-neutral frisk, 1 2.3586235167501186e-05
# i like genderbends, 1 2.3586235167501186e-05
# genderbender, 1 2.3586235167501186e-05
# gender neutrality, 1 2.3586235167501186e-05
# gender neutral! reader - freeform, 1 2.3586235167501186e-05
# agender character, 1 2.3586235167501186e-05
# genderfuck, 2 4.717247033500237e-05
# also author has a/b/o genders confused, 1 2.3586235167501186e-05
# fuck gender roles, 1 2.3586235167501186e-05
# "reincarnated into new gender", 1 2.3586235167501186e-05
# genderbend, 1 2.3586235167501186e-05
# reincarnated into new gender, 1 2.3586235167501186e-05
# gender swap, 2 4.717247033500237e-05
# gender change, 1 2.3586235167501186e-05
# gender bender, 1 2.3586235167501186e-05
# arya is genderqueer, 1 2.3586235167501186e-05
# cersei and jaime are genderqueer, 1 2.3586235167501186e-05
# genderbending in the fourth life, 1 2.3586235167501186e-05
# masculine presenting gender neutral jon, 2 4.717247033500237e-05
# alternate universe - genderswap, 1 2.3586235167501186e-05
# oberyn gives zero fucks about your gendered shit, 1 2.3586235167501186e-05
# kirishima's wardrobe doesnt have a gender filter, 1 2.3586235167501186e-05
# genderfluid arya, 1 2.3586235167501186e-05
# single gender jotuns, 1 2.3586235167501186e-05
# hange is whatever gender you see them as, 1 2.3586235167501186e-05
# genderqueer jon, 1 2.3586235167501186e-05
# transgender toni stark, 1 2.3586235167501186e-05
# gender dynamics, 1 2.3586235167501186e-05
# gender role expectations, 1 2.3586235167501186e-05
# gender, 1 2.3586235167501186e-05
# canon queer character, 4 9.434494067000474e-05
# pov queer character, 2 4.717247033500237e-05
# canon queer character of color, 2 4.717247033500237e-05
# queer character, 6 0.00014151741100500712
# queer, 7 0.0001651036461725083
# genderqueer character, 2 4.717247033500237e-05
# genderqueer, 2 4.717247033500237e-05
# queer eye au, 1 2.3586235167501186e-05
# queer themes, 6 0.00014151741100500712
# queer queens, 2 4.717247033500237e-05
# queer youth, 2 4.717247033500237e-05
# arya is queer, 1 2.3586235167501186e-05
# everyone is queer, 2 4.717247033500237e-05
# queer identity, 1 2.3586235167501186e-05
# almost everyone is queer, 1 2.3586235167501186e-05
# queer friendships, 1 2.3586235167501186e-05
# queer daenerys, 1 2.3586235167501186e-05
# bisexual jaime is here and queer, 1 2.3586235167501186e-05
# arya is genderqueer, 1 2.3586235167501186e-05
# queer culture, 1 2.3586235167501186e-05
# original character is an autistic queer woman of colour, 1 2.3586235167501186e-05
# cersei and jaime are genderqueer, 1 2.3586235167501186e-05
# queer het, 4 9.434494067000474e-05
# genderqueer jon, 1 2.3586235167501186e-05
# queer characters, 1 2.3586235167501186e-05
# canon queer relationship, 1 2.3586235167501186e-05
# lesbian, 15 0.0003537935275125178
# lesbian character, 48 0.001132139288040057
# lesbian vampires, 1 2.3586235167501186e-05
# lesbian margaery tyrell, 20 0.00047172470335002376
# harold they're lesbians!, 1 2.3586235167501186e-05
# lesbian! asha, 1 2.3586235167501186e-05
# lesbian! brienne, 1 2.3586235167501186e-05
# lesbian! arya, 1 2.3586235167501186e-05
# also lexa is a useless lesbian, 1 2.3586235167501186e-05
# lesbian sex, 69 0.001627450226557582
# lesbian sansa stark, 49 0.001155725523207558
# lesbians, 6 0.00014151741100500712
# pov lesbian character, 7 0.0001651036461725083
# so be prepared for lesbian sex, 1 2.3586235167501186e-05
# lesbianism, 1 2.3586235167501186e-05
# lesbian relationship, 6 0.00014151741100500712
# canon lesbian character, 4 9.434494067000474e-05
# lesbian witch, 1 2.3586235167501186e-05
# no lesbians die, 1 2.3586235167501186e-05
# hints of lesbian love, 1 2.3586235167501186e-05
# lesbiansssssss, 1 2.3586235167501186e-05
# lesbian yara greyjoy, 1 2.3586235167501186e-05
# lesbian queens, 1 2.3586235167501186e-05
# lesbian susan pevensie, 1 2.3586235167501186e-05
# eventually lesbian relationship, 1 2.3586235167501186e-05
# bby lesbians, 1 2.3586235167501186e-05
# lesbian crush, 2 4.717247033500237e-05
# lesbian love, 1 2.3586235167501186e-05
# we out here being lesbians or whateva, 1 2.3586235167501186e-05
# lesbian smut, 1 2.3586235167501186e-05
# two shy lesbians, 1 2.3586235167501186e-05
# useless lesbians, 5 0.00011793117583750594
# lesbian arya stark, 3 7.075870550250356e-05
# meera is a big gay lesbian and i love her, 1 2.3586235167501186e-05
# lesbian prison sex, 1 2.3586235167501186e-05
# inspired by a song that makes me feel really lesbian, 1 2.3586235167501186e-05
# baby lesbians, 1 2.3586235167501186e-05
# lesbian joanna snow, 1 2.3586235167501186e-05
# evil lesbians are hot, 1 2.3586235167501186e-05
# lesbian character of color, 2 4.717247033500237e-05
# backround lesbianism, 1 2.3586235167501186e-05
# literally it's just lesbian porn, 1 2.3586235167501186e-05
# jaime and brienne are a lesbian couple and i will not hear arguments for otherwise, 1 2.3586235167501186e-05
# joanna is a lesbian, 1 2.3586235167501186e-05
# young lesbians - freeform, 1 2.3586235167501186e-05
# historical lesbians that's my shit that's my shit, 1 2.3586235167501186e-05
# yara is so fuckin lesbian, 1 2.3586235167501186e-05
# canon lesbian relationship, 4 9.434494067000474e-05
# lesbian bdsm, 3 7.075870550250356e-05
# some lesbian action in the future between the reader and another female character, 1 2.3586235167501186e-05
# peripheral power lesbians, 1 2.3586235167501186e-05
# lesbians run westeros more at 11, 2 4.717247033500237e-05
# not the lesbian don't worry, 1 2.3586235167501186e-05
# and margaery is the lesbian, 1 2.3586235167501186e-05
# i don't know why i always make margaery a lesbian??, 1 2.3586235167501186e-05
# time travelling lesbians, 2 4.717247033500237e-05
# also sansa is a lesbian ? its not important to this but i needed it said ok thanks, 1 2.3586235167501186e-05
# lesbian margaery, 2 4.717247033500237e-05
# arya and tyene are the self-proclaimed lesbian version of bonnie and clyde, 1 2.3586235167501186e-05
# lesbian daenerys targaryen, 2 4.717247033500237e-05
# lesbian medieval princesses, 1 2.3586235167501186e-05
# lesbian myrcella baratheon, 1 2.3586235167501186e-05
# lesbian orgy, 1 2.3586235167501186e-05
# lesbian lena luthor, 1 2.3586235167501186e-05
# lesbian threats, 1 2.3586235167501186e-05
# gay, 25 0.0005896558791875297
# gay sex, 48 0.001132139288040057
# gay keith (voltron), 2 4.717247033500237e-05
# gay male character, 14 0.0003302072923450166
# canon gay character, 28 0.0006604145846900332
# but gayer, 1 2.3586235167501186e-05
# canon gay relationship, 29 0.0006840008198575344
# gay bars, 1 2.3586235167501186e-05
# also arya is kind of gay, 1 2.3586235167501186e-05
# and gay, 1 2.3586235167501186e-05
# gay character, 4 9.434494067000474e-05
# my little gay and the asexual bear, 1 2.3586235167501186e-05
# medieval gays, 1 2.3586235167501186e-05
# first gay fanfiction, 1 2.3586235167501186e-05
# everyone is gay, 13 0.00030662105717751547
# release the gays, 1 2.3586235167501186e-05
# gay jon snow, 1 2.3586235167501186e-05
# i can only write straight love and i'm so gay, 1 2.3586235167501186e-05
# gay panic, 4 9.434494067000474e-05
# everyone is happy and gay (even when they're not), 1 2.3586235167501186e-05
# targayen! jon snow, 1 2.3586235167501186e-05
# sansa is gay and no one can tell me otherwise, 1 2.3586235167501186e-05
# gay smashing, 1 2.3586235167501186e-05
# gay arthur dayne, 1 2.3586235167501186e-05
# i made dan and phil's friend group all gay because it be like that sometimes, 1 2.3586235167501186e-05
# gay af, 1 2.3586235167501186e-05
# medieval but being gay is okay bc i'm not touching homophobia with a ten foot pole, 1 2.3586235167501186e-05
# sansa is not gay, 1 2.3586235167501186e-05
# the gays are here, 1 2.3586235167501186e-05
# sansa stark is a gay mess, 1 2.3586235167501186e-05
# this is really sad and gay, 1 2.3586235167501186e-05
# so it's gonna have gay stuff as well as straight stuff in it, 1 2.3586235167501186e-05
# sansa is still not gay, 1 2.3586235167501186e-05
# ...i'm doing the first meeting again for the third time i'm gay leave me alone, 1 2.3586235167501186e-05
# alternate universe - gay people actually exist at hogwarts, 2 4.717247033500237e-05
# he's not breaking his vows if he's gay, 1 2.3586235167501186e-05
# sansa & daenerys & margaery kill evil ppl and its gay, 1 2.3586235167501186e-05
# gay clubs, 1 2.3586235167501186e-05
# happy gay tyrells, 1 2.3586235167501186e-05
# house tyrell: gaying strong, 1 2.3586235167501186e-05
# rated g for gay, 2 4.717247033500237e-05
# happy girls are happy and also gay, 1 2.3586235167501186e-05
# theyre just very gay, 1 2.3586235167501186e-05
# a shit ton of gayness, 1 2.3586235167501186e-05
# very gay demon brothers, 1 2.3586235167501186e-05
# it's v gay, 1 2.3586235167501186e-05
# gay relationship, 1 2.3586235167501186e-05
# gay for the stay, 1 2.3586235167501186e-05
# meera is a big gay lesbian and i love her, 1 2.3586235167501186e-05
# gay marriage, 4 9.434494067000474e-05
# and then in true marvin gaye style, 1 2.3586235167501186e-05
# if jessica jones had gayer au this would be it, 1 2.3586235167501186e-05
# all of the tyrell children are gay i don't make the rules, 1 2.3586235167501186e-05
# also i'm useless for baby gays, 1 2.3586235167501186e-05
# gay character marries straight female, 1 2.3586235167501186e-05
# highgarden is a gay paradise, 1 2.3586235167501186e-05
# and stumbling across this piece of gay trash instead, 1 2.3586235167501186e-05
# canon gay characters, 1 2.3586235167501186e-05
# sansa is reluctantly gay, 1 2.3586235167501186e-05
# another gay story, 1 2.3586235167501186e-05
# willas is gay, 1 2.3586235167501186e-05
# brienne has a better gaydar than in canon, 1 2.3586235167501186e-05
# theyre gay!! and theyre happy! love that for them!, 1 2.3586235167501186e-05
# gay pride, 2 4.717247033500237e-05
# her big fat gay wedding, 1 2.3586235167501186e-05
# tfw you're both the gay sibling, 1 2.3586235167501186e-05
# alternate universe - gay people exist at hogwarts, 2 4.717247033500237e-05
# everyone at the wall is gay (not pictured), 1 2.3586235167501186e-05
# sansa is gay, 1 2.3586235167501186e-05
# sansa is a disaster gay, 1 2.3586235167501186e-05
# daenerys being a hopeless gay, 1 2.3586235167501186e-05
# this is really gay alright, 1 2.3586235167501186e-05
# gay pirates au, 1 2.3586235167501186e-05
# except for roxy who's gay, 1 2.3586235167501186e-05
# this whole fic: gay panic!!!!!!!!!!!!!!!1111, 1 2.3586235167501186e-05
# gregor's also gay, 1 2.3586235167501186e-05
# this is not gay smut i was disoriented guys pls appreciate the effort, 1 2.3586235167501186e-05
# gay robb, 1 2.3586235167501186e-05
# gay friendly, 1 2.3586235167501186e-05
# anyways switch out god for gays and ya, 1 2.3586235167501186e-05
# gay egg and gendry, 1 2.3586235167501186e-05
# theon and robb are two dumb gay dads, 1 2.3586235167501186e-05
# sansa is so gay, 1 2.3586235167501186e-05
# they're both super duper gay, 1 2.3586235167501186e-05
# brokeback mountain levels of gay cowboys, 1 2.3586235167501186e-05
# gay rights, 1 2.3586235167501186e-05
# this author hates the bury your gays trope, 1 2.3586235167501186e-05
# anygays tormund and jon are both soft as hell for each other im sick and tired, 1 2.3586235167501186e-05
# gregor's gay, 1 2.3586235167501186e-05
# gay love, 1 2.3586235167501186e-05
# gay parents, 2 4.717247033500237e-05
# y'all it is so gay, 1 2.3586235167501186e-05
# loras & theon are disaster gays, 1 2.3586235167501186e-05
# lots of gay, 1 2.3586235167501186e-05
# why are all the starks gay?, 1 2.3586235167501186e-05
# gay ending, 1 2.3586235167501186e-05
# gay ladies being in love, 1 2.3586235167501186e-05
# a song with gay dragons, 1 2.3586235167501186e-05
# gay hot pie, 1 2.3586235167501186e-05
# ramsay rhymes with supergay, 1 2.3586235167501186e-05
# lots of gay omega on omega sex, 1 2.3586235167501186e-05
# jean with gay feels, 1 2.3586235167501186e-05
# theon has a lot of gay thought repressing, 1 2.3586235167501186e-05
# gay jon, 1 2.3586235167501186e-05
# gay marriage in the middle ages, 1 2.3586235167501186e-05
# this is gay, 1 2.3586235167501186e-05
# im gay, 1 2.3586235167501186e-05
# everything is gay, 1 2.3586235167501186e-05
# because i love soft gays, 1 2.3586235167501186e-05
# hey you're my prisoner but you intimidated me and i'm gay so let's bang, 1 2.3586235167501186e-05
# lommy is forever fun & gay, 1 2.3586235167501186e-05
# all the gay, 1 2.3586235167501186e-05
# (but elia will probably feature later because i'm so gay for her), 1 2.3586235167501186e-05
# loras tyrell is a gay crab who's in love with a gay merman renly, 1 2.3586235167501186e-05
# it's gay, 1 2.3586235167501186e-05
# gay porn, 1 2.3586235167501186e-05
# arya is a little bit gay for margaery, 1 2.3586235167501186e-05
# uhhh idk this is gonna be really gay ok, 1 2.3586235167501186e-05
# knights sitting about doing nothing except being gay, 1 2.3586235167501186e-05
# gay bros theon and robb, 1 2.3586235167501186e-05
# basically everyone is a big gay mess, 1 2.3586235167501186e-05
# ymir and historia are gay, 1 2.3586235167501186e-05
# gay penguins, 1 2.3586235167501186e-05
# jean's a little gay for eren, 1 2.3586235167501186e-05
# there are gay people in here, 1 2.3586235167501186e-05
# so a lil gay, 1 2.3586235167501186e-05
# you know i had to add in some gayness, 1 2.3586235167501186e-05
# renly isn't gay here, 1 2.3586235167501186e-05
# rivengay, 1 2.3586235167501186e-05
# lommy is fun and gay, 1 2.3586235167501186e-05
# gay mess lena luthor, 1 2.3586235167501186e-05
# jimin is the knight of flowers and hella gay, 1 2.3586235167501186e-05
# rickon is gayyyyyyyy, 1 2.3586235167501186e-05
# gay village club, 1 2.3586235167501186e-05
# nonbinary character, 1 2.3586235167501186e-05
# nonbinary blanche, 1 2.3586235167501186e-05
# nonbinary arya, 1 2.3586235167501186e-05
# genderqueer character, 2 4.717247033500237e-05
# genderqueer, 2 4.717247033500237e-05
# arya is genderqueer, 1 2.3586235167501186e-05
# cersei and jaime are genderqueer, 1 2.3586235167501186e-05
# genderqueer jon, 1 2.3586235167501186e-05
# missandei deserved better, 4 9.434494067000474e-05
# dom!missandei is even better, 1 2.3586235167501186e-05
# daenerys targaryen/missandei - freeform, 1 2.3586235167501186e-05
# jorah/missandei friendship, 1 2.3586235167501186e-05
# omega!missandei, 1 2.3586235167501186e-05
# missandei lives, 2 4.717247033500237e-05
# mentions of missandei, 1 2.3586235167501186e-05
# missandei x greyworm if you squint, 1 2.3586235167501186e-05
# inspired by grey worm and missandei goodbye scene, 1 2.3586235167501186e-05
# dany and missandei give her advice, 1 2.3586235167501186e-05
# i haven't coped with missandei's death, 1 2.3586235167501186e-05
# jon learns about missandei's death, 1 2.3586235167501186e-05
# minor missandei/greyworm, 1 2.3586235167501186e-05
# dany's army now waiting for missandei's word, 1 2.3586235167501186e-05
# show!missandei, 1 2.3586235167501186e-05
# grieving missandei, 1 2.3586235167501186e-05
# missandei has a big-ass heart, 1 2.3586235167501186e-05
# missandei goes home to naath, 1 2.3586235167501186e-05
# daenerys and missandei have to say goodbye, 1 2.3586235167501186e-05
# a fix it fic because its what missandei deserves goddamnit, 1 2.3586235167501186e-05
# missandei is still alive, 1 2.3586235167501186e-05
# close friend! missandei, 1 2.3586235167501186e-05
# daenerys and jorah and missandei are all alive just because, 1 2.3586235167501186e-05
# missandei is an angel, 1 2.3586235167501186e-05
# mentions of robb/talisa arya/gendry and missandei/grey worm, 1 2.3586235167501186e-05
# brotp arya & missandei, 1 2.3586235167501186e-05
# jealous missandei, 1 2.3586235167501186e-05
# dany & missandei & grey worm sitting on a naathi beach, 1 2.3586235167501186e-05
# bisexual missandei, 1 2.3586235167501186e-05
# missandei is her therapist, 1 2.3586235167501186e-05
# minor daenerys targaryen/missandei, 1 2.3586235167501186e-05
# past missandei/dany if you squint, 1 2.3586235167501186e-05
# human!missandei, 1 2.3586235167501186e-05
# except grey and missandei, 1 2.3586235167501186e-05
# missandei is the friend that everyone needs, 1 2.3586235167501186e-05
# missandei is the best friend everyone wants and no one deserves, 1 2.3586235167501186e-05
# missandei is a precious angel who must be protected, 1 2.3586235167501186e-05
# familiar!grey worm, 1 2.3586235167501186e-05
# grey worm deserved better, 1 2.3586235167501186e-05
# inspired by grey worm and missandei goodbye scene, 1 2.3586235167501186e-05
# y'all need to write stories about the trauma grey worm is going through, 1 2.3586235167501186e-05
# grey worm died, 1 2.3586235167501186e-05
# mentions of robb/talisa arya/gendry and missandei/grey worm, 1 2.3586235167501186e-05
# dany & missandei & grey worm sitting on a naathi beach, 1 2.3586235167501186e-05
# grey worm is a dj, 1 2.3586235167501186e-05
# client!grey worm, 1 2.3586235167501186e-05
# dothraki, 32 0.0007547595253600379
# dothraki!eijun, 1 2.3586235167501186e-05
# with dothraki sprinkles, 1 2.3586235167501186e-05
# dothraki sea, 1 2.3586235167501186e-05
# dothraki wedding, 1 2.3586235167501186e-05
# the dothraki on an open field ned, 1 2.3586235167501186e-05
# there is a dothraki party, 1 2.3586235167501186e-05
# dothraki!blaine, 1 2.3586235167501186e-05
# dothraki!jiraiya, 1 2.3586235167501186e-05
# alsoooo lexa is half dothraki soon that's going to be fun, 1 2.3586235167501186e-05
# dothraki lunar parade, 1 2.3586235167501186e-05
# not dothraki friendly, 2 4.717247033500237e-05
# dothraki on an open field, 1 2.3586235167501186e-05
# a dothraki party, 1 2.3586235167501186e-05
# hoseok is a dothraki, 1 2.3586235167501186e-05
# some sexual practices are unknown to the dothraki, 1 2.3586235167501186e-05
# dothraki bloodriders, 1 2.3586235167501186e-05
# dothraki!pietro, 1 2.3586235167501186e-05
# khal!thorin, 1 2.3586235167501186e-05
# khaleesi!bilbo, 1 2.3586235167501186e-05
# khal thorin and khaleesi bilbo, 1 2.3586235167501186e-05
# khal thorin oakenshield, 1 2.3586235167501186e-05
# khaleesi bilbo baggins, 1 2.3586235167501186e-05
# khaleesi - freeform, 9 0.00021227611650751068
# minor khal drogo/daenerys targaryen, 6 0.00014151741100500712
# khaleesi lily has me feeling some type of way, 1 2.3586235167501186e-05
# khaleesi and jorah, 1 2.3586235167501186e-05
# khal derek, 1 2.3586235167501186e-05
# khal and khaleesi, 1 2.3586235167501186e-05
# khal crowley, 1 2.3586235167501186e-05
# khaleesi castiel, 1 2.3586235167501186e-05
# like dany and khal drogo, 1 2.3586235167501186e-05
# zayn is khaleesi/dany, 1 2.3586235167501186e-05
# liam is khal drogo, 1 2.3586235167501186e-05
# and thorin is khal drogo, 1 2.3586235167501186e-05
# khal drogo lives, 4 9.434494067000474e-05
# dean is khal drogo, 1 2.3586235167501186e-05
# castiel is khaleesi, 1 2.3586235167501186e-05
# implied khal drogo/myranda royce/margaery tyrell, 1 2.3586235167501186e-05
# khaleesi bilbo, 1 2.3586235167501186e-05
# khal thorin, 1 2.3586235167501186e-05
# khal drogo - freeform, 2 4.717247033500237e-05
# derek is khal drogo, 1 2.3586235167501186e-05
# khal heimdall, 1 2.3586235167501186e-05
# khaleesi loki, 1 2.3586235167501186e-05
# mentioned khal drogo, 1 2.3586235167501186e-05
# khal, 1 2.3586235167501186e-05
# foreign exchange student khal drogo, 1 2.3586235167501186e-05
# khal! kal-el, 1 2.3586235167501186e-05
# don't read this if you like khal drogo in either the books or the show, 1 2.3586235167501186e-05
# past khal drogo/daenerys targaryen - freeform, 1 2.3586235167501186e-05
# khal kurogane, 1 2.3586235167501186e-05
# fuck khal drogo, 1 2.3586235167501186e-05
# channeling khal drogo!thor here, 1 2.3586235167501186e-05
# unsubtle parallels with thorin dressed up as khal drogo and bilbo dressed up as daenery targaryen, 1 2.3586235167501186e-05
# khal hannibal, 1 2.3586235167501186e-05
# no khal drogo, 1 2.3586235167501186e-05
# no marriage with khal drogo, 1 2.3586235167501186e-05
# not an empress a khalee-i mean a jedi, 1 2.3586235167501186e-05
# background dany/khal moro, 1 2.3586235167501186e-05
# khal is now kal, 1 2.3586235167501186e-05
# khalasar au, 1 2.3586235167501186e-05
# khal!hux, 1 2.3586235167501186e-05
# khaleesi!ben, 1 2.3586235167501186e-05
# past daenerys targaryen/khal drogo - freeform, 2 4.717247033500237e-05
# there isnt a tag for bamf khal drogo bc he's a canon bamf, 1 2.3586235167501186e-05
# not healthy daenerys targaryen/khal drogo, 1 2.3586235167501186e-05
# relationship like khal drogo and daenerys, 1 2.3586235167501186e-05
# no marriage to khal drogo, 1 2.3586235167501186e-05
# pov khal drogo, 1 2.3586235167501186e-05
# slight body dysphoria, 1 2.3586235167501186e-05
# gender dysphoria, 5 0.00011793117583750594
# body dysphoria, 6 0.00014151741100500712
# identity dysphoria, 1 2.3586235167501186e-05
# mild body dysphoria, 1 2.3586235167501186e-05
# mild dysphoria, 1 2.3586235167501186e-05
# sexual slavery, 31 0.0007311732901925368
# slave - freeform, 1 2.3586235167501186e-05
# made a slave, 1 2.3586235167501186e-05
# master/slave, 32 0.0007547595253600379
# jung taekwoon | leo was a slave, 1 2.3586235167501186e-05
# slavery, 55 0.0012972429342125653
# slave stiles stilinski, 1 2.3586235167501186e-05
# slavers bay, 1 2.3586235167501186e-05
# sex slave, 1 2.3586235167501186e-05
# slaves, 2 4.717247033500237e-05
# non-sexual slavery, 1 2.3586235167501186e-05
# sex slaves, 1 2.3586235167501186e-05
# alternate universe - slavery, 5 0.00011793117583750594
# slave yuuri katsuki, 1 2.3586235167501186e-05
# implied/referenced slavery, 3 7.075870550250356e-05
# slave!jon, 1 2.3586235167501186e-05
# slavery warning, 1 2.3586235167501186e-05
# former slaves, 1 2.3586235167501186e-05
# sex slavery, 1 2.3586235167501186e-05
# rescued slave, 1 2.3586235167501186e-05
# slave auction, 2 4.717247033500237e-05
# amazon sex slave au, 1 2.3586235167501186e-05
# modern slavery au, 1 2.3586235167501186e-05
# slaver's bay, 2 4.717247033500237e-05
# jon is taken as a slave, 1 2.3586235167501186e-05
# and next thing i know i'm reading about how lys is famous for bed slaves, 1 2.3586235167501186e-05
# slavery abolition, 1 2.3586235167501186e-05
# slave trade, 4 9.434494067000474e-05
# slave fiction, 1 2.3586235167501186e-05
# (imagined) sex slavery, 1 2.3586235167501186e-05
# mention of sexual slavery, 1 2.3586235167501186e-05
# kihyun is a slave, 1 2.3586235167501186e-05
# non-romanticized slavery, 1 2.3586235167501186e-05
# mistress/slave, 1 2.3586235167501186e-05
# petyr is a sex slave (in the beginning), 1 2.3586235167501186e-05
# mistress and slave dynamics, 1 2.3586235167501186e-05
# master and slave dynamics, 1 2.3586235167501186e-05
# slave to wife, 1 2.3586235167501186e-05
# violation of slaves, 1 2.3586235167501186e-05
# domestic owner/slave, 1 2.3586235167501186e-05
# slave training, 1 2.3586235167501186e-05
# ex-slave, 1 2.3586235167501186e-05
# sex slave gabriel, 1 2.3586235167501186e-05
# drag queens, 2 4.717247033500237e-05
# she's going off to drag hot pie back, 1 2.3586235167501186e-05
# slight drag queen elements, 1 2.3586235167501186e-05
# slavery abolition, 1 2.3586235167501186e-05
# freedom, 7 0.0001651036461725083
# sexual freedom at camp lannister, 1 2.3586235167501186e-05
# sansa + freedom, 1 2.3586235167501186e-05
# freedom fighters, 2 4.717247033500237e-05
# there is no canon to diverge from anymore-freedom is now., 1 2.3586235167501186e-05
# revolutions, 1 2.3586235167501186e-05
# french revolution, 3 7.075870550250356e-05
# revolution, 11 0.000259448586842513
# revolutionaries, 1 2.3586235167501186e-05
# american revolution au, 1 2.3586235167501186e-05
# industrial revolution, 1 2.3586235167501186e-05
# american revolution, 1 2.3586235167501186e-05
# mexican revolution background, 1 2.3586235167501186e-05
# vive la revolution, 1 2.3586235167501186e-05
# revolutionist daenerys, 1 2.3586235167501186e-05
# rebellion, 19 0.0004481384681825226
# robert's rebellion, 85 0.002004829989237601
# no robert's rebellion, 13 0.00030662105717751547
# mage rebellion, 1 2.3586235167501186e-05
# robert's rebellion au, 1 2.3586235167501186e-05
# post-rebellion story, 2 4.717247033500237e-05
# robert's rebellion era, 1 2.3586235167501186e-05
# canon divergence - robert's rebellion, 30 0.0007075870550250356
# post-greyjoy rebellion, 3 7.075870550250356e-05
# pre - robert's rebellion, 17 0.0004009659978475202
# pre-robert's rebellion, 1 2.3586235167501186e-05
# failed rebellion, 1 2.3586235167501186e-05
# canon divergence - greyjoy rebellion, 1 2.3586235167501186e-05
# robert's rebellion kinda, 1 2.3586235167501186e-05
# my version of what went down before robert's rebellion, 1 2.3586235167501186e-05
# post-robert's rebellion, 2 4.717247033500237e-05
# after the rebellion, 1 2.3586235167501186e-05
# robert's rebellion was not built on a lie, 1 2.3586235167501186e-05
# teenage rebellion, 8 0.00018868988134000949
# greyjoy rebellion, 4 9.434494067000474e-05
# lack of rebellion, 1 2.3586235167501186e-05
# no blackfyre rebellion, 1 2.3586235167501186e-05
# alternate universe - blackfyre rebellion, 1 2.3586235167501186e-05
# robert's rebellion failed, 2 4.717247033500237e-05
# au - greyjoy rebellion, 1 2.3586235167501186e-05
# reyne-tarbeck rebellion, 1 2.3586235167501186e-05
# robert's rebellion (asoiaf) - freeform, 1 2.3586235167501186e-05
# the rebellion never happened, 1 2.3586235167501186e-05
# the blackfyre rebellion, 2 4.717247033500237e-05
# no robert rebellion, 1 2.3586235167501186e-05
# pre-rebellion story, 1 2.3586235167501186e-05
# teen rebellion, 1 2.3586235167501186e-05
# au: jaime left the kingsguard after the rebellion to live on bear island, 1 2.3586235167501186e-05
# rebellion still happened, 1 2.3586235167501186e-05
# alternate universe- no robert's rebellion, 1 2.3586235167501186e-05
# no rebellion, 2 4.717247033500237e-05
# canon divergence - robert's rebellion never happened, 1 2.3586235167501186e-05
# robert's rebellion happens, 1 2.3586235167501186e-05
# no greyjoy rebellion, 1 2.3586235167501186e-05
# au after robert's rebellion, 3 7.075870550250356e-05
# post robert's rebellion, 1 2.3586235167501186e-05
# rheagar deposed his father so no rebellion, 1 2.3586235167501186e-05
# joffery's rebellion, 1 2.3586235167501186e-05
# greyjoy rebellion 308ac, 1 2.3586235167501186e-05
# robert's rebellion with dragons, 1 2.3586235167501186e-05
# robert's rebellion 2.0, 2 4.717247033500237e-05
# alternate universe - robert's rebellion, 1 2.3586235167501186e-05
# no roberts rebellion, 1 2.3586235167501186e-05
# robb was not born yet after robert's rebellion ended, 1 2.3586235167501186e-05
# lyanna still dies but the rebellion never happened, 1 2.3586235167501186e-05
# au:ned becomes regent after the rebellion, 1 2.3586235167501186e-05
# robb's rebellion, 1 2.3586235167501186e-05
# a spin on robert's rebellion, 1 2.3586235167501186e-05
# trying to look at robert's rebellion through many eyes, 1 2.3586235167501186e-05
# rhaegar's rebellion - freeform, 1 2.3586235167501186e-05
# robert's rebellion happened later, 1 2.3586235167501186e-05
# roberts rebellion, 1 2.3586235167501186e-05
# before roberts rebellion, 1 2.3586235167501186e-05
# robert's rebellion era characters, 1 2.3586235167501186e-05
# rebellion-like ages, 1 2.3586235167501186e-05
# alternate end to the rebellion, 1 2.3586235167501186e-05
# robert's rebellion parallels, 1 2.3586235167501186e-05
# robert's rebellion never happened, 1 2.3586235167501186e-05
# robert's rebellion only happened a few years back, 1 2.3586235167501186e-05
# the rebellion still happens but things turn out differently, 1 2.3586235167501186e-05
# still a wolf and a dragon that sparks the rebellion, 1 2.3586235167501186e-05
# the greyjoy rebellion happened later than in canon, 1 2.3586235167501186e-05
# get some y'all, 1 2.3586235167501186e-05
# ned is alive and well i know y'all were wondering, 1 2.3586235167501186e-05
# im sorry y'all, 1 2.3586235167501186e-05
# poppin' bottles y'all, 1 2.3586235167501186e-05
# aegon and arya y'all, 1 2.3586235167501186e-05
# my heart still hurts y'all, 1 2.3586235167501186e-05
# 'cause i know y'all love some sansan, 1 2.3586235167501186e-05
# y'all can decide skin colour tho, 1 2.3586235167501186e-05
# jaime needs therapy y'all, 1 2.3586235167501186e-05
# #everybody was done so dirty y'all, 1 2.3586235167501186e-05
# y'all had two years and you still fucked it up, 1 2.3586235167501186e-05
# i'm doing this to cope y'all, 1 2.3586235167501186e-05
# no one dies on my watch y'all, 1 2.3586235167501186e-05
# but y'all know that, 1 2.3586235167501186e-05
# a weird obession with fire isn't healthy y'all, 1 2.3586235167501186e-05
# it's canon y'all, 1 2.3586235167501186e-05
# explicit description of consent because that's important y'all, 1 2.3586235167501186e-05
# i swear it's happy in the end y'all, 1 2.3586235167501186e-05
# i hope y'all like it, 1 2.3586235167501186e-05
# y'all already know what's up lmfao, 1 2.3586235167501186e-05
# y'all better believe lady is alive in this verse, 1 2.3586235167501186e-05
# y'all need to write stories about the trauma grey worm is going through, 1 2.3586235167501186e-05
# fuck y'all for teasing an alayne stone vale storyline, 1 2.3586235167501186e-05
# whew one more episode y'all here we go i guess, 1 2.3586235167501186e-05
# but i hope y'all enjoy anyway, 1 2.3586235167501186e-05
# hope y'all like it, 1 2.3586235167501186e-05
# i really don't know how to tag this but hope y'all like it, 1 2.3586235167501186e-05
# also can y'all believe we're finally canon, 1 2.3586235167501186e-05
# gendry has stamina y'all, 1 2.3586235167501186e-05
# jon sings barry manilow bc this is my world and y'all are just livin in it, 1 2.3586235167501186e-05
# peace out y'all, 1 2.3586235167501186e-05
# this ship deserves so much better y'all, 1 2.3586235167501186e-05
# cleaning the tag since y'all don't know how to behave, 1 2.3586235167501186e-05
# unless y'all like it, 1 2.3586235167501186e-05
# daenerys deserved better y'all, 1 2.3586235167501186e-05
# did y'all see that ish, 1 2.3586235167501186e-05
# shit tone of tropes y'all, 1 2.3586235167501186e-05
# i'll let y'all know if i ever run out of those quotes lmao, 1 2.3586235167501186e-05
# i'm like oprah giving out happy endings y'all, 1 2.3586235167501186e-05
# two epilogues for y'all, 1 2.3586235167501186e-05
# brush up on your pop culture y'all, 1 2.3586235167501186e-05
# y'all it is so gay, 1 2.3586235167501186e-05
# i'm in deep y'all, 1 2.3586235167501186e-05
# satan bless thramsay y'all, 1 2.3586235167501186e-05
# rhaegar had plans y'all, 1 2.3586235167501186e-05
# y'all i said i was gonna write it, 1 2.3586235167501186e-05
# this fic ends in a fade to black just so y'all know, 1 2.3586235167501186e-05
# two characters barely even appear but y'all know why i tagged them, 1 2.3586235167501186e-05
# i mean a lot y'all, 1 2.3586235167501186e-05
# y'all also i have never written smut before, 1 2.3586235167501186e-05
# sit down y'all this is gonna be a long ride, 1 2.3586235167501186e-05
# we've achieved lime y'all, 1 2.3586235167501186e-05
# see y'all in hell, 1 2.3586235167501186e-05
# yup its a three in one y'all, 1 2.3586235167501186e-05
# maybe three-shot if y'all like it, 1 2.3586235167501186e-05
# (see y'all in hell), 1 2.3586235167501186e-05
# there's smut from the first chapter so y'all don't have to wait!, 1 2.3586235167501186e-05
# i warned y'all if someone else didn't write it that i would, 1 2.3586235167501186e-05
# grrm made me wait three books before there were dragons so y'all can wait too, 1 2.3586235167501186e-05
# i really hate joffrey y'all, 1 2.3586235167501186e-05
# dubious consent, 321 0.007571181488767881
# mildly dubious consent, 102 0.0024057959870851207
# explicit consent, 20 0.00047172470335002376
# some mild dubious consent, 1 2.3586235167501186e-05
# consent issues, 11 0.000259448586842513
# extremely dubious consent, 39 0.0009198631715325463
# age of consent!sansa, 1 2.3586235167501186e-05
# age of consent, 1 2.3586235167501186e-05
# consent, 6 0.00014151741100500712
# given the circumstance from the very start - eugene is unable to consent to anything else, 1 2.3586235167501186e-05
# inability to consent, 1 2.3586235167501186e-05
# dubious consent due to identity issues, 4 9.434494067000474e-05
# consent play, 2 4.717247033500237e-05
# dubious wedding sex consent, 1 2.3586235167501186e-05
# jaime has a consent kink, 1 2.3586235167501186e-05
# comment on consent, 1 2.3586235167501186e-05
# consenting - freeform, 1 2.3586235167501186e-05
# at least sansa's consenting here, 1 2.3586235167501186e-05
# questionable consent, 1 2.3586235167501186e-05
# canon-typical age of consent, 2 4.717247033500237e-05
# enthusiastic consent, 8 0.00018868988134000949
# consentual sex, 2 4.717247033500237e-05
# consentacles, 2 4.717247033500237e-05
# explicit description of consent because that's important y'all, 1 2.3586235167501186e-05
# consent is sexy, 4 9.434494067000474e-05
# implied consent, 2 4.717247033500237e-05
# implied/referenced dubious consent, 6 0.00014151741100500712
# mildly dubious consent if you squint, 1 2.3586235167501186e-05
# slightly dubious consent, 2 4.717247033500237e-05
# everything is consented, 1 2.3586235167501186e-05
# technically we're all consenting adults here, 1 2.3586235167501186e-05
# consenting adults, 1 2.3586235167501186e-05
# borderline dubious consent, 1 2.3586235167501186e-05
# very confusing consent issues, 1 2.3586235167501186e-05
# so much consent, 1 2.3586235167501186e-05
# consensual non-consent, 4 9.434494067000474e-05
# the dubious consent in dany/drogo, 1 2.3586235167501186e-05
# look d&d you can't consent when you're that drunk, 1 2.3586235167501186e-05
# dubious consent due to intoxication, 1 2.3586235167501186e-05
# some mild uninformed consent, 1 2.3586235167501186e-05
# consent eventually becomes less dubious, 1 2.3586235167501186e-05
# consent is sexy kids, 1 2.3586235167501186e-05
# consent is v important folks, 1 2.3586235167501186e-05
# but everyone consents, 1 2.3586235167501186e-05
# translation, 20 0.00047172470335002376
# translation available, 7 0.0001651036461725083
# sexually transmitted diseases, 1 2.3586235167501186e-05
# okay we'll just call this a transition piece, 1 2.3586235167501186e-05
# animal transformation, 10 0.00023586235167501188
# i edited it to make it trans inclusive, 1 2.3586235167501186e-05
# full wolf transformation, 2 4.717247033500237e-05
# trans character, 13 0.00030662105717751547
# transgender, 3 7.075870550250356e-05
# trans female character, 4 9.434494067000474e-05
# trans daenerys, 1 2.3586235167501186e-05
# google translate, 1 2.3586235167501186e-05
# trans male character, 13 0.00030662105717751547
# perevod na russkii | translation in russian, 16 0.00037737976268001897
# french translation, 1 2.3586235167501186e-05
# translation somali, 1 2.3586235167501186e-05
# translated work, 1 2.3586235167501186e-05
# translation 4 me and yari, 1 2.3586235167501186e-05
# transcript, 1 2.3586235167501186e-05
# transgender teens, 1 2.3586235167501186e-05
# transgressive sex, 1 2.3586235167501186e-05
# zhong wen fan yi  | translation in chinese, 11 0.000259448586842513
# google-translated german, 1 2.3586235167501186e-05
# internalized transphobia, 2 4.717247033500237e-05
# prisoner transport, 1 2.3586235167501186e-05
# trans sam winchester, 1 2.3586235167501186e-05
# english translation of my previous fanfic, 1 2.3586235167501186e-05
# i completed the translation in two days, 1 2.3586235167501186e-05
# i might translate it if anyone comments, 1 2.3586235167501186e-05
# or just use google translate, 1 2.3586235167501186e-05
# jon is a trans man please stop telling me to tag this 'female jon snow', 1 2.3586235167501186e-05
# trans jon snow, 2 4.717247033500237e-05
# if you're going to read all the way to chapter 32 in order to be homophobic and transphobic trolls, 1 2.3586235167501186e-05
# bad public transportation, 1 2.3586235167501186e-05
# your sorrow will transform into sorrow of an entirely different kind, 1 2.3586235167501186e-05
# transformation, 5 0.00011793117583750594
# ubersetzung/translation, 2 4.717247033500237e-05
# transmisogyny, 1 2.3586235167501186e-05
# trans male kyoutani, 1 2.3586235167501186e-05
# transphobic language, 1 2.3586235167501186e-05
# i translated it into english, 1 2.3586235167501186e-05
# this is almost a transcription lol, 1 2.3586235167501186e-05
# alternate universe - trans, 1 2.3586235167501186e-05
# jon snow is trans, 1 2.3586235167501186e-05
# transformations, 1 2.3586235167501186e-05
# trans!arya stark, 1 2.3586235167501186e-05
# trans keith (voltron), 1 2.3586235167501186e-05
# trans loras, 1 2.3586235167501186e-05
# some valyrian but i'll try to translate it somehow, 1 2.3586235167501186e-05
# transformers - freeform, 1 2.3586235167501186e-05
# translation in english, 1 2.3586235167501186e-05
# translate to ukrainian, 1 2.3586235167501186e-05
# implied/referenced transphobia, 1 2.3586235167501186e-05
# transcendental romance, 1 2.3586235167501186e-05
# physical transformation, 1 2.3586235167501186e-05
# transformed, 1 2.3586235167501186e-05
# transformed into an animal, 1 2.3586235167501186e-05
# trans! margaery, 1 2.3586235167501186e-05
# trans john watson, 1 2.3586235167501186e-05
# trans!alleras, 1 2.3586235167501186e-05
# trans dipper pines, 1 2.3586235167501186e-05
# transgender toni stark, 1 2.3586235167501186e-05
# alternative universe: public transportation, 1 2.3586235167501186e-05
# public transportation, 1 2.3586235167501186e-05
# transformation magic, 1 2.3586235167501186e-05
# trans!jon snow, 1 2.3586235167501186e-05
# trans!tywin lannister, 1 2.3586235167501186e-05
# kaiju transformation, 1 2.3586235167501186e-05
# sassy! loras, 1 2.3586235167501186e-05
# loras tyrell & margaery tyrell are twins, 1 2.3586235167501186e-05
# pov loras tyrell, 1 2.3586235167501186e-05
# minor renly baratheon/loras tyrell, 17 0.0004009659978475202
# past renly baratheon/loras tyrell, 2 4.717247033500237e-05
# renly baratheon & loras tyrell friendship, 1 2.3586235167501186e-05
# loras doesn't get the recognition he deserves, 1 2.3586235167501186e-05
# if there's two things i ship loras with it's renly and vodka cranberries, 1 2.3586235167501186e-05
# loras!enjolras, 1 2.3586235167501186e-05
# loras and renly are in a student band together, 1 2.3586235167501186e-05
# sam/loras being nauseatingly cute, 1 2.3586235167501186e-05
# loras despairs, 1 2.3586235167501186e-05
# loras pov, 1 2.3586235167501186e-05
# loras!merlin, 1 2.3586235167501186e-05
# mention of past sexual intercourse between olyvar and loras, 1 2.3586235167501186e-05
# mentions of renly loras joffrey lyanna stark and rhaegar, 1 2.3586235167501186e-05
# basically little kid loras, 1 2.3586235167501186e-05
# community: renlylorasfest, 2 4.717247033500237e-05
# loras' pov, 1 2.3586235167501186e-05
# loras' so cute it hurts, 1 2.3586235167501186e-05
# mentions of kings landing since loras went up to the wall, 1 2.3586235167501186e-05
# back story of loras, 1 2.3586235167501186e-05
# mentions of renly/loras, 1 2.3586235167501186e-05
# loras and willas are soldiers, 1 2.3586235167501186e-05
# with supporting roles from gendry loras and yara, 1 2.3586235167501186e-05
# sassy loras, 1 2.3586235167501186e-05
# loras is an angry little bitch, 1 2.3586235167501186e-05
# this was not supposed to be as long as it is but loras held me hostage, 1 2.3586235167501186e-05
# loras is king of coming out parties, 1 2.3586235167501186e-05
# loras' dreams come true, 1 2.3586235167501186e-05
# ugly duckling!loras, 1 2.3586235167501186e-05
# loras is put on trial, 1 2.3586235167501186e-05
# loras is loud, 1 2.3586235167501186e-05
# petulant loras is petulant, 1 2.3586235167501186e-05
# loras is really just a lost puppy, 1 2.3586235167501186e-05
# loras in mourning, 1 2.3586235167501186e-05
# loras is a brat, 1 2.3586235167501186e-05
# (renloras is more a side pairing), 1 2.3586235167501186e-05
# loras tyrell mentioned, 1 2.3586235167501186e-05
# loras gets annoyed by girls, 1 2.3586235167501186e-05
# unexplained past loras/renly breakup, 1 2.3586235167501186e-05
# ballet dancer loras tyrell, 1 2.3586235167501186e-05
# trans loras, 1 2.3586235167501186e-05
# periods are tough on young men huh loras, 1 2.3586235167501186e-05
# renly and loras are bastards, 1 2.3586235167501186e-05
# loras survived the sept, 1 2.3586235167501186e-05
# loras is mistaken for a girl (easy mistake to make), 1 2.3586235167501186e-05
# loras & theon are disaster gays, 1 2.3586235167501186e-05
# margaery and loras pine together, 1 2.3586235167501186e-05
# margaery and loras are a great sibling duo, 1 2.3586235167501186e-05
# teen loras, 1 2.3586235167501186e-05
# robb and loras flirt with eachother a lot, 1 2.3586235167501186e-05
# fem!loras, 2 4.717247033500237e-05
# jealous!loras, 1 2.3586235167501186e-05
# loras tyrell is a gay crab who's in love with a gay merman renly, 1 2.3586235167501186e-05
# minor loras tyrell/renly baratheon - freeform, 1 2.3586235167501186e-05
# established renly/loras, 1 2.3586235167501186e-05
# by marrying sansa and loras, 1 2.3586235167501186e-05
# you know that tumblr post where margaery and loras switch bedrooms at night, 1 2.3586235167501186e-05
# loras tyrell is alive, 1 2.3586235167501186e-05
# margaery and loras are the best duo seriously i love writing them, 1 2.3586235167501186e-05
# and also i missed margaery and loras, 1 2.3586235167501186e-05
# background loras/renly - freeform, 1 2.3586235167501186e-05
# minor loras/petyr, 1 2.3586235167501186e-05
# margaery and loras are twins, 1 2.3586235167501186e-05
# alpha loras, 1 2.3586235167501186e-05
# yes loras is bisexual in this, 1 2.3586235167501186e-05
# sorry renly/loras shippers, 1 2.3586235167501186e-05
# renly and loras are alive and in love, 1 2.3586235167501186e-05
# loras says so, 1 2.3586235167501186e-05
# loras tries to be artsy, 1 2.3586235167501186e-05
# femdom, 48 0.001132139288040057
# femslash, 180 0.004245522330150214
# pov female character, 111 0.002618072103592632
# platonic female/male relationships, 10 0.00023586235167501188
# female characters, 12 0.00028303482201001424
# feminist themes, 21 0.0004953109385175249
# female protagonists, 5 0.00011793117583750594
# female protagonist, 40 0.0009434494067000475
# female-centric, 50 0.0011793117583750593
# female-male friendship, 13 0.00030662105717751547
# female homosexuality, 4 9.434494067000474e-05
# female anti-hero, 4 9.434494067000474e-05
# female antagonist, 3 7.075870550250356e-05
# female jon snow, 98 0.002311451046415116
# bisexual female character, 37 0.0008726907011975438
# female friendship, 73 0.0017217951672275867
# original female character(s) - freeform, 13 0.00030662105717751547
# female pronouns, 1 2.3586235167501186e-05
# female reader, 6 0.00014151741100500712
# community: femslash100, 23 0.0005424834088525273
# male reincarnated as a female, 1 2.3586235167501186e-05
# female reincarnated as a male, 1 2.3586235167501186e-05
# feminization, 15 0.0003537935275125178
# male-female friendship, 41 0.0009670356418675487
# strong female characters, 38 0.0008962769363650452
# female ejaculation, 7 0.0001651036461725083
# female solo, 1 2.3586235167501186e-05
# females of power, 1 2.3586235167501186e-05
# fem!ja'far, 1 2.3586235167501186e-05
# femslash february, 44 0.001037794347370052
# femslash february 2016, 1 2.3586235167501186e-05
# yara bangs the whole female campus, 1 2.3586235167501186e-05
# pov original female character, 5 0.00011793117583750594
# female harry potter, 24 0.0005660696440200285
# female character of color, 11 0.000259448586842513
# game of thrones femslash, 1 2.3586235167501186e-05
# lgbtq female character, 7 0.0001651036461725083
# favourite female heroine in the entirety of asioaf, 1 2.3586235167501186e-05
# female relationships, 14 0.0003302072923450166
# the 100 femslash, 1 2.3586235167501186e-05
# shieldmaidens (femmes guerrieres), 1 2.3586235167501186e-05
# original female character - freeform, 2 4.717247033500237e-05
# female bronn, 1 2.3586235167501186e-05
# r'hllor is female, 1 2.3586235167501186e-05
# femshlash prompts, 1 2.3586235167501186e-05
# feminist wives everywhere, 1 2.3586235167501186e-05
# alpha females wear corseted doublets, 1 2.3586235167501186e-05
# fem!agni, 1 2.3586235167501186e-05
# canon lgbtq female character, 1 2.3586235167501186e-05
# fake!fempreg, 2 4.717247033500237e-05
# fem!ramsay, 2 4.717247033500237e-05
# trans female character, 4 9.434494067000474e-05
# fem!jon snow, 6 0.00014151741100500712
# fem!slash, 1 2.3586235167501186e-05
# female masturbation, 3 7.075870550250356e-05
# rejtett femslash, 1 2.3586235167501186e-05
# fem!dwalin - freeform, 1 2.3586235167501186e-05
# fem!ori - freeform, 1 2.3586235167501186e-05
# femslash friday, 5 0.00011793117583750594
# femslash february 2018, 4 9.434494067000474e-05
# maledom/femsub, 4 9.434494067000474e-05
# femslash drabbletag 6, 1 2.3586235167501186e-05
# community: femslash11, 2 4.717247033500237e-05
# femslash february 2017, 4 9.434494067000474e-05
# female sexuality, 1 2.3586235167501186e-05
# minor female/male-relationships, 1 2.3586235167501186e-05
# female trevelyans are my weakness, 1 2.3586235167501186e-05
# female hange zoe, 1 2.3586235167501186e-05
# femslash yuletide, 1 2.3586235167501186e-05
# female pronouns for pidge | katie holt, 2 4.717247033500237e-05
# fem!hinata, 1 2.3586235167501186e-05
# female hinata shouyou, 1 2.3586235167501186e-05
# fem!kenma, 1 2.3586235167501186e-05
# female kozume kenma, 1 2.3586235167501186e-05
# fem!jack, 1 2.3586235167501186e-05
# female warriors, 1 2.3586235167501186e-05
# female rhaegar targaryen, 1 2.3586235167501186e-05
# female hand jobs, 1 2.3586235167501186e-05
# femslash100, 2 4.717247033500237e-05
# naked male clothed female, 3 7.075870550250356e-05
# female power, 1 2.3586235167501186e-05
# female!reader - freeform, 1 2.3586235167501186e-05
# femslash february trope bingo, 3 7.075870550250356e-05
# femme fatale sansa, 1 2.3586235167501186e-05
# male dominant/female submissive, 1 2.3586235167501186e-05
# female oc - freeform, 2 4.717247033500237e-05
# fem!jon, 6 0.00014151741100500712
# platonic female/female relationships, 5 0.00011793117583750594
# female gaze, 3 7.075870550250356e-05
# female jaime lannister, 3 7.075870550250356e-05
# femslash february 2019, 4 9.434494067000474e-05
# female jon, 5 0.00011793117583750594
# fem!stannis, 1 2.3586235167501186e-05
# fem!davos, 1 2.3586235167501186e-05
# reader is female, 1 2.3586235167501186e-05
# forced feminization, 2 4.717247033500237e-05
# female stannis baratheon, 1 2.3586235167501186e-05
# jon is a trans man please stop telling me to tag this 'female jon snow', 1 2.3586235167501186e-05
# pre-femslash, 7 0.0001651036461725083
# femlash, 2 4.717247033500237e-05
# femtrope bingo, 1 2.3586235167501186e-05
# light femdom, 1 2.3586235167501186e-05
# the night's watch as a female organization, 1 2.3586235167501186e-05
# female centric, 1 2.3586235167501186e-05
# the idealization of violence makes for shitty feminism, 1 2.3586235167501186e-05
# female viserys targaryen, 1 2.3586235167501186e-05
# female edward elric, 1 2.3586235167501186e-05
# au in which female characters have agency, 1 2.3586235167501186e-05
# community: femslashex, 1 2.3586235167501186e-05
# femsub, 3 7.075870550250356e-05
# butch/femme, 3 7.075870550250356e-05
# hard femme, 1 2.3586235167501186e-05
# fem-slash, 1 2.3586235167501186e-05
# femslash simmer, 1 2.3586235167501186e-05
# calling the show out on its overuse of female nudity, 1 2.3586235167501186e-05
# there is a female oc at one point, 1 2.3586235167501186e-05
# female will graham, 1 2.3586235167501186e-05
# fem!will, 1 2.3586235167501186e-05
# femharry potter - freeform, 2 4.717247033500237e-05
# female oberyn martell, 1 2.3586235167501186e-05
# fem!bilbo, 1 2.3586235167501186e-05
# female stark siblings, 2 4.717247033500237e-05
# female robb, 10 0.00023586235167501188
# femnaruto - freeform, 1 2.3586235167501186e-05
# fem! stannis baratheon, 1 2.3586235167501186e-05
# female stannis' name is ellyn, 1 2.3586235167501186e-05
# gentle femdom, 1 2.3586235167501186e-05
# fem!jaime, 2 4.717247033500237e-05
# fem slash, 1 2.3586235167501186e-05
# female badass bodyguards, 1 2.3586235167501186e-05
# female oral, 1 2.3586235167501186e-05
# female on top, 1 2.3586235167501186e-05
# feminism, 5 0.00011793117583750594
# female theon greyjoy - freeform, 1 2.3586235167501186e-05
# female character in command, 9 0.00021227611650751068
# strong female character, 1 2.3586235167501186e-05
# sansa and original female character friendship, 2 4.717247033500237e-05
# isolde-original female character, 2 4.717247033500237e-05
# implied femslash, 4 9.434494067000474e-05
# fem!jake - freeform, 1 2.3586235167501186e-05
# female tony stark, 1 2.3586235167501186e-05
# female harry potter is jenny of oldstones, 1 2.3586235167501186e-05
# gay character marries straight female, 1 2.3586235167501186e-05
# female ned stark, 5 0.00011793117583750594
# female friendships yo, 1 2.3586235167501186e-05
# fem harry, 1 2.3586235167501186e-05
# first female experience, 1 2.3586235167501186e-05
# jon snow/original female character - freeform, 1 2.3586235167501186e-05
# female!theon, 1 2.3586235167501186e-05
# female bonding, 2 4.717247033500237e-05
# fem!robb, 4 9.434494067000474e-05
# bamf female character, 1 2.3586235167501186e-05
# female monkey d. luffy, 1 2.3586235167501186e-05
# female eragon, 1 2.3586235167501186e-05
# there's not enough femslash here, 1 2.3586235167501186e-05
# g!p original female character(s), 1 2.3586235167501186e-05
# female empowerment, 1 2.3586235167501186e-05
# fem!renly, 2 4.717247033500237e-05
# female bran stark, 2 4.717247033500237e-05
# female rickon stark, 1 2.3586235167501186e-05
# sasuke wears feminine-ish clothes, 1 2.3586235167501186e-05
# female worship, 1 2.3586235167501186e-05
# femslash june 2015, 1 2.3586235167501186e-05
# tormund is my feminist, 1 2.3586235167501186e-05
# female alpha, 1 2.3586235167501186e-05
# some lesbian action in the future between the reader and another female character, 1 2.3586235167501186e-05
# fem!percy jackson - freeform, 1 2.3586235167501186e-05
# (female recieving), 1 2.3586235167501186e-05
# younger female/older male relationship, 1 2.3586235167501186e-05
# fem!ned, 1 2.3586235167501186e-05
# tyrion lannister is a feminist icon, 1 2.3586235167501186e-05
# community: femslashficlets, 3 7.075870550250356e-05
# femme sansa stark, 1 2.3586235167501186e-05
# female harry potter reborn as daenerys targaryen, 2 4.717247033500237e-05
# part 1 of my series female harry potter as daenerys targaryen, 1 2.3586235167501186e-05
# always female stiles stilinski, 1 2.3586235167501186e-05
# she anything counts for femslash feb so have this, 1 2.3586235167501186e-05
# feminism. idk., 1 2.3586235167501186e-05
# fem!sanji, 1 2.3586235167501186e-05
# female gladiator - why? because it's my story and i love brienne, 1 2.3586235167501186e-05
# female harry, 3 7.075870550250356e-05
# female castiel/female dean winchester, 2 4.717247033500237e-05
# female dean winchester, 1 2.3586235167501186e-05
# female castiel, 1 2.3586235167501186e-05
# female sam winchester, 2 4.717247033500237e-05
# my response to 'female characters can only have growth through physical pain, 1 2.3586235167501186e-05
# original female characters - freeform, 1 2.3586235167501186e-05
# lack of female rights, 1 2.3586235167501186e-05
# female friendships, 2 4.717247033500237e-05
# females having each others back, 1 2.3586235167501186e-05
# female robb stark, 1 2.3586235167501186e-05
# feminine draco malfoy, 1 2.3586235167501186e-05
# femjon is happier, 1 2.3586235167501186e-05
# temporarily female stiles stilinski, 1 2.3586235167501186e-05
# female drogo, 2 4.717247033500237e-05
# female jon snow is also autistic, 1 2.3586235167501186e-05
# between a minor character and unnamed female, 1 2.3586235167501186e-05
# feminization slurs, 1 2.3586235167501186e-05
# selwyn tarth is the feminist father westeros deserves, 1 2.3586235167501186e-05
# i wished lyanna had female friends in the books, 1 2.3586235167501186e-05
# fem!loras, 2 4.717247033500237e-05
# fem!tony, 1 2.3586235167501186e-05
# female dominance, 3 7.075870550250356e-05
# male/female violence, 1 2.3586235167501186e-05
# female!harry, 1 2.3586235167501186e-05
# (but female centric), 1 2.3586235167501186e-05
# femininity, 1 2.3586235167501186e-05
# background femslash, 1 2.3586235167501186e-05
# femme domme, 1 2.3586235167501186e-05
# femme, 1 2.3586235167501186e-05
# female frisk, 1 2.3586235167501186e-05
# part 2 of female harry potter as daenerys targaryen series, 1 2.3586235167501186e-05
# female ramsay bolton, 1 2.3586235167501186e-05
# female!jon snow, 1 2.3586235167501186e-05
# fem jon snow, 1 2.3586235167501186e-05
# female my unit | byleth, 1 2.3586235167501186e-05
# minor jon snow/literally almost every female character in this fic, 1 2.3586235167501186e-05
# because fuck d&d and their offending representation of female relationships, 1 2.3586235167501186e-05
# female infantcide, 1 2.3586235167501186e-05
# submissive female character, 2 4.717247033500237e-05
# dominant female character, 4 9.434494067000474e-05
# bisexual female character of color, 3 7.075870550250356e-05
# female version of tony stark gets blown up and lands in westeros, 1 2.3586235167501186e-05
# awesome female characters, 1 2.3586235167501186e-05
# weaponized femininity, 1 2.3586235167501186e-05
# female submissive, 1 2.3586235167501186e-05
# female bran, 1 2.3586235167501186e-05
# female rickon, 1 2.3586235167501186e-05
# female viserys, 1 2.3586235167501186e-05
# middle age feminism, 1 2.3586235167501186e-05
# jon snow and female harry potter are twins, 1 2.3586235167501186e-05
# community: femslashbb, 1 2.3586235167501186e-05
# fem!mormor, 1 2.3586235167501186e-05
# female-led relationship, 1 2.3586235167501186e-05
# male omega/female alpha, 1 2.3586235167501186e-05
# fem!jesse pinkman, 1 2.3586235167501186e-05
# fem!barry allen - freeform, 1 2.3586235167501186e-05
# fem!jamie reagan, 1 2.3586235167501186e-05
# female edmure, 1 2.3586235167501186e-05
# female tywin, 1 2.3586235167501186e-05
# multi-femslash, 1 2.3586235167501186e-05
# tgifemslash, 1 2.3586235167501186e-05
# all my heroes are female, 1 2.3586235167501186e-05
# sadistic female character, 1 2.3586235167501186e-05
# female harry potter is not lily and james' potter daughter, 1 2.3586235167501186e-05
# healthy femdom, 1 2.3586235167501186e-05
# female!harry potter - freeform, 2 4.717247033500237e-05
# female jon is alysanne, 1 2.3586235167501186e-05
# female jon is visenya, 1 2.3586235167501186e-05
# emasculation, 2 4.717247033500237e-05
# mascot, 1 2.3586235167501186e-05
# toxic masculinity, 1 2.3586235167501186e-05
# "i was thinking sansa was a mascot wearing a shark costume", 1 2.3586235167501186e-05
# masculine adventures, 1 2.3586235167501186e-05
# robb stark doesn't have time for your hypermasculine bullshit, 1 2.3586235167501186e-05
# because m as in makeup and mascara and uh...moisturiser!, 1 2.3586235167501186e-05
# masculine presenting gender neutral jon, 2 4.717247033500237e-05
# feminist themes, 21 0.0004953109385175249
# feminist wives everywhere, 1 2.3586235167501186e-05
# the idealization of violence makes for shitty feminism, 1 2.3586235167501186e-05
# feminism, 5 0.00011793117583750594
# tormund is my feminist, 1 2.3586235167501186e-05
# tyrion lannister is a feminist icon, 1 2.3586235167501186e-05
# feminism. idk., 1 2.3586235167501186e-05
# selwyn tarth is the feminist father westeros deserves, 1 2.3586235167501186e-05
# middle age feminism, 1 2.3586235167501186e-05
# everyone hates heteronormativity, 1 2.3586235167501186e-05
# autistic headcanons, 1 2.3586235167501186e-05
# autistic arya, 1 2.3586235167501186e-05
# autistic ned, 1 2.3586235167501186e-05
# autistic sansa too, 1 2.3586235167501186e-05
# autistic character, 2 4.717247033500237e-05
# autistic sansa implied...a fic should be coming soon !!, 1 2.3586235167501186e-05
# autistic lila barton, 1 2.3586235167501186e-05
# autistic sansa stark, 1 2.3586235167501186e-05
# autistic!stannis, 1 2.3586235167501186e-05
# autistic!ned, 1 2.3586235167501186e-05
# original character is an autistic queer woman of colour, 1 2.3586235167501186e-05
# autistic!melisandre, 1 2.3586235167501186e-05
# female jon snow is also autistic, 1 2.3586235167501186e-05
# jaime is autistic, 1 2.3586235167501186e-05
# sansa is autistic, 1 2.3586235167501186e-05
# autistic arthur dayne, 1 2.3586235167501186e-05

# %% [markdown]
# ## Extracting Fics that Use These Tags
#
# Using the tag list above, I will extract fics that use these tags to determine if I want to read the fics and reach out to the authors!
#
# Instead of putting all this information in the Jupyer Notebook, though, I will be putting it all in a Google Sheet where I will be keeping track of all this information
#
# These are the tags I am choosing to extract:
# - Missandei
# - Grey Worm
# - feminis (femism, femist)
#     - the idealization of violence makes for shitty feminism
#     - feminist themes
#     - feminism
# - trans!
# - nonbinary
#     - nonbinary character
#     - nonbinary arya
# - transge
# - femal
#     - my response to 'female characters can only have growth through physical pain
#     - female character in command
#     - female friendships yo
# - gay
# - bisex
# - LGBTQ
# - dothraki
# - heteronormativity
# - lesbian
# - dysphoria
#     - body dysphoria
# - gender
#     - genderqueer
#     - genderqueer jon
#     - genderqueer character
#     - genderfluid arya
#     - gender role expectations
#     - oberyn gives zero fucks about your gendered shit
#     - gender confusion
#     - genderbending
#     - misgenderin
# - abolition
#     - slavery abolition
# - of color
#     - canon character of color
#     - character(s) of color
#     - lgbtq character(s) of color
# - of colour
# - masc
# - queer
# - ' race' (put the space before race so it's not a word like 'trace')
#     - racebend
#     -
# - drag (specifically "drag " with a space at the end to eliminate dragons)
#     - drag queen
#
# Decided not to include:
# - racism, as this is usually a justification to include racism, claiming it is "canonical" or part of the world
# - consent, because most things that mention consent use the tag 'dubious consent.' There are some tags that emphasize the need for consent, but these are much more rare.
# - slash, as often slash is centered around two male characters, both erasing women and fetishizing gay men

# %%
def find_text(search_term):
    '''
    Simple function so I dont need to copy-and-paste over and over
    '''
    show = got_all[got_all['additional tags'].str.contains(search_term)]
    print(show)

# %%
Got_LGBTQ = merged_got[merged_got['additional tags'].str.contains("slash|lgbtq|feminis|drag |nonbinary|bisex|heteronormativity|trans!|transg|dysphoria|gay| bi |lesbian|genderqu|gender iden|gender neu|masc|queer", na=False)]
Got_LGBTQ.count()
# Out:
# Unnamed: 0         1011
# work_id            1011
# title              1011
# published          1011
# rating             1011
# relationship        982
# additional tags    1011
# category            986
# body               1011
# month              1011
# dtype: int64

# %%
GoT_race_AT = merged_got[merged_got['additional tags'].str.contains("missandei|grey worm|dothraki|abolition|of color|of colour| race|naath|meereen|oberyn|ellaria|dorne|coloni", na=False)]
GoT_race_AT.count()
# Out:
# Unnamed: 0         348
# work_id            348
# title              348
# published          348
# rating             348
# relationship       325
# additional tags    348
# category           323
# body               348
# month              348
# dtype: int64

# %%
def character_count(charactername,df):
    df_new = df[df['character'].str.contains(charactername, na=False)]
    print(charactername, df_new['work_id'].count())

character_count('jon snow', merged_got)
character_count('tyrion', merged_got)
character_count('arya', merged_got)
character_count('sansa stark', merged_got)
character_count('sandor', merged_got)
character_count('baelish', merged_got)
character_count('daenerys targaryen', merged_got)
character_count('brienne', merged_got)
character_count('margaery', merged_got)
character_count('jaime', merged_got)
character_count('loras', merged_got)
character_count('oberyn', merged_got)
character_count('missandei', merged_got)
character_count('grey worm', merged_got)
character_count('ellaria', merged_got)
character_count('bran', merged_got)
character_count('drogo', merged_got)
# Out:
# jon snow 12190
# tyrion 4393
# arya 8354
# sansa stark 13740
# sandor 2959
# baelish 2167
# daenerys targaryen 5550
# brienne 5013
# margaery 3173
# jaime 6351
# loras 1336
# oberyn 1080
# missandei 1018
# grey worm 621
# ellaria 395
# bran 4286
# drogo 731

# %%
GoT_race_REL = merged_got[merged_got['relationship'].str.contains("missandei|grey worm|khal|jhiqui|irri|qotho|rakharo|sallador saan|xaro|oberyn|ellaria", na=False)]
GoT_race_REL.count()
# Out:
# Unnamed: 0         1113
# work_id            1113
# title              1113
# published          1113
# rating             1112
# relationship       1113
# additional tags    1113
# category           1073
# body               1113
# month              1113
# dtype: int64

# %%
GoT_race_REL = merged_got[~merged_got['relationship'].str.contains("missandei|grey worm|khal|jhiqui|irri|qotho|rakharo|sallador saan|xaro|oberyn|ellaria", na=False)]
GoT_race_REL.count()
# Out:
# Unnamed: 0         28784
# work_id            28784
# title              28784
# published          28784
# rating             28784
# character          27833
# relationship       26620
# additional tags    26096
# category           27399
# body               28784
# month              28784
# dtype: int64

# %%
GoT_chr_REL = merged_got[merged_got['character'].str.contains("missandei|grey worm|khal|jhiqui|irri|qotho|rakharo|sallador saan|xaro|oberyn|ellaria", na=False)]
GoT_chr_REL.count()
# Out:
# Unnamed: 0         2508
# work_id            2508
# title              2508
# published          2508
# rating             2507
# character          2508
# relationship       2368
# additional tags    2302
# category           2386
# body               2508
# month              2508
# dtype: int64

# %%
#did not include slavery because sometimes slavery is used in a sexual connotation, not in the historic and politic and violent way

GOT_woke = merged_got[merged_got['additional tags'].str.contains("lgbtq|missandei|grey worm|femal|feminis|drag |bisex|heteronormativity|trans!|transg|dysphoria|consent|gay|nonbinary|dothraki|lesbian|gender|abolition|of color|of colour|naath|meereen|oberyn|ellaria|dorne|coloni|masc|queer| race", na=False)]
GOT_woke
# Out:
#       Unnamed: 0   work_id                                    title  \
# 8              8   5387489                 game of thrones fusion,
# 11            11  15928970                game of thrones stories,
# 38            38  10423077             otherwhen: game of thrones,
# 57            57  18996928       game of thrones femslash ficlets,
# 73            73  19479925  game of heroes: my thrones university,
# ...          ...       ...                                      ...
# 1866        1866  11841501                           boys of snow,
# 1868        1868  19463911                       bits of stuff ii,
# 1873        1873  17779256                                 zenith,
# 1874        1874   3509540                  alpha/omega one-shots,
# 1876        1876  10685394                        endless wonders,
#
#        published                   rating  \
# 8     2015-12-09               explicit,
# 11    2018-09-08  teen and up audiences,
# 38    2017-03-24      general audiences,
# 57    2019-05-28               explicit,
# 73    2019-07-05                 mature,
# ...          ...                      ...
# 1866  2017-08-18                 mature,
# 1868  2019-07-03               explicit,
# 1873  2019-02-20      general audiences,
# 1874  2015-03-09  teen and up audiences,
# 1876  2017-04-21      general audiences,
#
#                                            relationship  \
# 8     castiel/dean winchester, castiel/john winchest...
# 11    various/reader, robb stark/reader, sansa stark...
# 38    talisa maegyr/robb stark, catelyn stark/ned st...
# 57    sansa stark/margaery tyrell, myrcella baratheo...
# 73                                jon snow/robb stark,
# ...                                                 ...
# 1866  jon snow/robb stark, jon snow/jojen reed, jon ...
# 1868  tormund giantsbane/jon snow, derek hale/pack, ...
# 1873                                                NaN
# 1874  dean winchester/reader, sherlock holmes/ reade...
# 1876  regulus black/harry potter, reid garwin/harry ...
#
#                                         additional tags  \
# 8     wipadoptions, work up for adoption, alternate ...
# 11    fluff, angst, smut, sexual activity, rough sex...
# 38    what-if, other additional tags to be added, ta...
# 57    alternate universe - canon divergence, alterna...
# 73    lots of characters, my hero academia verse, al...
# ...                                                 ...
# 1866  other additional tags to be added, smut, i wri...
# 1868  alternate universe - modern setting, establish...
# 1873  action, action/adventure, adventure, affection...
# 1874  ofc - freeform, omega verse, alpha dean, alpha...
# 1876  prompt fill, random & short, slash, het, cross...
#
#                          category  \
# 8                           m/m,
# 11         f/f, f/m, m/m, multi,
# 38                     gen, f/m,
# 57                   f/f, multi,
# 73                          m/m,
# ...                           ...
# 1866                        m/m,
# 1868          m/m, multi, other,
# 1873                        gen,
# 1874                        f/m,
# 1876  f/m, gen, m/m, f/f, multi,
#
#                                                    body    month
# 8     i did some very necessary research on misha co...  2015-12
# 11    (y/n) lannister is the twin to tyrion, but unl...  2018-09
# 38    robb gets a raven from riverrun letting him kn...  2017-03
# 57    femslash fictlets involving characters in game...  2019-05
# 73    so i only started watching game of thrones thi...  2019-07
# ...                                                 ...      ...
# 1866  "you're such a tease." robb's voice broke the ...  2017-08
# 1868  \n"oi," tormund hollered after slamming the fr...  2019-07
# 1873  zenith\n\nauthor's note: titled after the zeni...  2019-02
# 1874  something was wrong.\n\nwell...not wrong but d...  2015-03
# 1876  \n          (see the end of the chapter for  n...  2017-04
#
# [2014 rows x 10 columns]

# %%
GOT_maybeWokeIDK = merged_got[merged_got['additional tags'].str.contains("lgbtq|missandei|grey worm|femal|feminis|drag |bisex|heteronormativity|trans!|transg|dysphoria|consent|gay|dothraki|lesbian|gender|abolition|of color|of colour|naath|meereen|oberyn|ellaria|dorne|coloni|masc|queer| race")==False]
GOT_maybeWokeIDK
# Out:
# Unnamed: 0         27885
# work_id            27885
# title              27885
# published          27885
# rating             27884
# relationship       25821
# additional tags    27885
# category           26546
# body               27885
# month              27885
# dtype: int64

# %%
korra_all[korra_all['additional tags'].str.contains("rans!",  na=False)]
# Out:
#       Unnamed: 0   work_id                                       title  \
# 193          193   3979267                     The Prince of the South
# 204          204  13544514                               Promises Kept
# 2421        2421   5680369  Helpless to the Bass and the Fadiing Light
# 2791        2791   5003569                                   Who Am I?
#
#         rating         category                   fandom  \
# 193     Mature  F/F, F/M, Other  Avatar: Legend of Korra
# 204   Explicit              F/F  Avatar: Legend of Korra
# 2421  Explicit         F/F, F/M  Avatar: Legend of Korra
# 2791  Explicit              F/M  Avatar: Legend of Korra
#
#                                relationship  \
# 193             Korrasami, Korra/Asami Sato
# 204                        Korra/Asami Sato
# 2421  Korra/Asami Sato, Bolin/Opal (Avatar)
# 2791                       Korra/Asami Sato
#
#                                               character  \
# 193   Korra (Avatar), Asami Sato, Tonraq, Senna, Hir...
# 204                   Korra (Avatar), Korra, Asami Sato
# 2421  Korra (Avatar), Asami Sato, Bolin (Avatar), Op...
# 2791          Korra (Avatar), Asami Sato, Mako (Avatar)
#
#                                         additional tags language  ...  \
# 193   Trans!KorraXAsami, Korrasami - Freeform, Korra...  English  ...
# 204   Omegaverse, Alpha!Korra, Omega!Asami, Sex, Pen...  English  ...
# 2421  New Year's Eve, Clubbing, Alcohol, Trans Male ...  English  ...
# 2791  Trans!Korra, Transphobia, Angst, Hurt/Comfort,...  English  ...
#
#          status status date  words  chapters comments  kudos  bookmarks  \
# 193     Updated  2018-02-03  99119      13/?    180.0  574.0       58.0
# 204   Completed  2018-02-01   3710       1/1     46.0  494.0       29.0
# 2421  Completed  2016-01-09     51       1/1      4.0   12.0        1.0
# 2791  Completed  2015-10-15   8544       1/1     19.0  316.0       38.0
#
#         hits                                               body    month
# 193   8519.0   \nThe Prince of the South- \n \n \n \nAvatar ...  2015-05
# 204   8561.0   \nKorra tore down the long drive to the Sato ...  2018-02
# 2421  1405.0  Opal sighed for the millionth time as they fin...  2016-01
# 2791  6853.0  It was six weeks after they've returned from t...  2015-10
#
# [4 rows x 21 columns]
